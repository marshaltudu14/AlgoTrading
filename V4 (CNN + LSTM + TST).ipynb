# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install pyotp mplfinance pandas_ta fyers_apiv3 pygame stable-baselines3 gymnasium
# Out:
# Requirement already satisfied: pyotp in /usr/local/lib/python3.11/dist-packages (2.9.0)
# Requirement already satisfied: mplfinance in /usr/local/lib/python3.11/dist-packages (0.12.10b0)
# Requirement already satisfied: pandas_ta in /usr/local/lib/python3.11/dist-packages (0.3.14b0)
# Requirement already satisfied: fyers_apiv3 in /usr/local/lib/python3.11/dist-packages (3.1.5)
# Requirement already satisfied: pygame in /usr/local/lib/python3.11/dist-packages (2.6.1)
# Requirement already satisfied: stable-baselines3 in /usr/local/lib/python3.11/dist-packages (2.5.0)
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.11/dist-packages (1.0.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from mplfinance) (3.10.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from mplfinance) (2.2.2)
# Requirement already satisfied: requests==2.31.0 in /usr/local/lib/python3.11/dist-packages (from fyers_apiv3) (2.31.0)
# Requirement already satisfied: asyncio==3.4.3 in /usr/local/lib/python3.11/dist-packages (from fyers_apiv3) (3.4.3)
# Requirement already satisfied: aiohttp==3.9.3 in /usr/local/lib/python3.11/dist-packages (from fyers_apiv3) (3.9.3)
# Requirement already satisfied: aws_lambda_powertools==1.25.5 in /usr/local/lib/python3.11/dist-packages (from fyers_apiv3) (1.25.5)
# Requirement already satisfied: websocket-client==1.6.1 in /usr/local/lib/python3.11/dist-packages (from fyers_apiv3) (1.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp==3.9.3->fyers_apiv3) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp==3.9.3->fyers_apiv3) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp==3.9.3->fyers_apiv3) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp==3.9.3->fyers_apiv3) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp==3.9.3->fyers_apiv3) (1.18.3)
# Requirement already satisfied: aws-xray-sdk<3.0.0,>=2.8.0 in /usr/local/lib/python3.11/dist-packages (from aws_lambda_powertools==1.25.5->fyers_apiv3) (2.14.0)
# Requirement already satisfied: boto3<2.0,>=1.18 in /usr/local/lib/python3.11/dist-packages (from aws_lambda_powertools==1.25.5->fyers_apiv3) (1.36.26)
# Requirement already satisfied: fastjsonschema<3.0.0,>=2.14.5 in /usr/local/lib/python3.11/dist-packages (from aws_lambda_powertools==1.25.5->fyers_apiv3) (2.21.1)
# Requirement already satisfied: jmespath<0.11.0,>=0.10.0 in /usr/local/lib/python3.11/dist-packages (from aws_lambda_powertools==1.25.5->fyers_apiv3) (0.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests==2.31.0->fyers_apiv3) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests==2.31.0->fyers_apiv3) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests==2.31.0->fyers_apiv3) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests==2.31.0->fyers_apiv3) (2025.1.31)
# Requirement already satisfied: numpy<3.0,>=1.20 in /usr/local/lib/python3.11/dist-packages (from stable-baselines3) (1.26.4)
# Requirement already satisfied: torch<3.0,>=2.3 in /usr/local/lib/python3.11/dist-packages (from stable-baselines3) (2.4.1+cu121)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from stable-baselines3) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (0.0.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.17.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (2025.2.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch<3.0,>=2.3->stable-baselines3) (12.1.105)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mplfinance) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mplfinance) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mplfinance) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mplfinance) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mplfinance) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mplfinance) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mplfinance) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mplfinance) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->mplfinance) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->mplfinance) (2025.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from aws-xray-sdk<3.0.0,>=2.8.0->aws_lambda_powertools==1.25.5->fyers_apiv3) (1.17.2)
# Requirement already satisfied: botocore>=1.11.3 in /usr/local/lib/python3.11/dist-packages (from aws-xray-sdk<3.0.0,>=2.8.0->aws_lambda_powertools==1.25.5->fyers_apiv3) (1.36.26)
# Requirement already satisfied: s3transfer<0.12.0,>=0.11.0 in /usr/local/lib/python3.11/dist-packages (from boto3<2.0,>=1.18->aws_lambda_powertools==1.25.5->fyers_apiv3) (0.11.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->mplfinance) (1.17.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from yarl<2.0,>=1.0->aiohttp==3.9.3->fyers_apiv3) (0.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch<3.0,>=2.3->stable-baselines3) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->torch<3.0,>=2.3->stable-baselines3) (1.3.0)

# %%
# !pip install torch==2.4.1 torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
# !pip install torch_xla==2.4 -f https://storage.googleapis.com/pytorch-xla-releases/wheels/tpuvm/
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu121
# Requirement already satisfied: torch==2.4.1 in /usr/local/lib/python3.11/dist-packages (2.4.1+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (0.19.1+cu121)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.11/dist-packages (2.4.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch==2.4.1) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch==2.4.1) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from torch==2.4.1) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch==2.4.1) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch==2.4.1) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch==2.4.1) (2025.2.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch==2.4.1) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch==2.4.1) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch==2.4.1) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch==2.4.1) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.11/dist-packages (from torch==2.4.1) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.11/dist-packages (from torch==2.4.1) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.11/dist-packages (from torch==2.4.1) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.11/dist-packages (from torch==2.4.1) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.11/dist-packages (from torch==2.4.1) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.11/dist-packages (from torch==2.4.1) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch==2.4.1) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in /usr/local/lib/python3.11/dist-packages (from torch==2.4.1) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.4.1) (12.1.105)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision) (11.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch==2.4.1) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->torch==2.4.1) (1.3.0)

# %%
# !pip uninstall -y tensorflow
# !pip install tensorflow-cpu

# %%
import torch
import torch_xla.core.xla_model as xm

# Check GPU availability
print("GPU Available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("CUDA Version:", torch.version.cuda)
    print("GPU Device:", torch.cuda.current_device())

# Check TPU availability
try:
    tpu_device = xm.xla_device()
    print("TPU Device:", tpu_device)
except Exception as e:
    print("TPU not available:", e)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import torch
# ----> 2 import torch_xla.core.xla_model as xm
#       4 # Check GPU availability
#       5 print("GPU Available:", torch.cuda.is_available())
#
# ModuleNotFoundError: No module named 'torch_xla'

# %%
import requests
import base64
from datetime import datetime, timedelta, date
from datetime import time as dt_time
import time
import threading
import pyotp
from pytz import timezone
import pandas as pd
import numpy as np
from numba import njit, prange
from urllib.parse import urlparse, parse_qs
import matplotlib.pyplot as plt
import mplfinance as mpf
import pandas_ta as ta
import pygame
import pytz
import os
import json
import sys
import gc

import gymnasium as gym
from gymnasium import spaces
from IPython.display import display, clear_output
from tqdm import tqdm

from fyers_apiv3 import fyersModel
from fyers_apiv3.FyersWebsocket import data_ws

from scipy.signal import argrelextrema
import tensorflow as tf
from collections import deque
from sklearn.preprocessing import StandardScaler
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.11.9)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
app_id = "TS79V3NXK1-100"
secret_key = "KQCPB0FJ74"
redirect_uri = "https://google.com"
fyers_user = "XM22383"
fyers_pin = "4628"
fyers_totp = "EAQD6K4IUYOEGPJNVE6BMPTUSDCWIOHW"
response_type = "code"
state = "sample_state"
grant_type = "authorization_code"

fyers = None
fyers_socket = None

ist_timezone = pytz.timezone("Asia/Kolkata")

# Initialize the mixer
#pygame.mixer.init()

# Load the sound file
#pygame.mixer.music.load('sounds/alert.mp3')

#Variables
ce_ltp = 0
pe_ltp = 0
index_ltp = 0
buy_sell_checked = False
ce_strike = None
pe_strike = None
ce_symbol = None
pe_symbol = None

fixed_ltp = 0
fixed_index_ltp = 0
prev_ltp = 0
target_inside = 0
target_index_inside = 0
trailing_sl_inside = 0
trailing_index_inside = 0

active_order = False

sl_hit_condition = False
total_loss = 0
total_profit = 0
overall_win = 0
overall_loss = 0
total_points = 0

unsubscribe_done = False

active_order_sleep = 1

# %%
session = fyersModel.SessionModel(
    client_id=app_id,
    secret_key=secret_key,
    redirect_uri=redirect_uri,
    response_type=response_type,
    grant_type=grant_type
)

def getEncodedString(string):
    string = str(string)
    base64_bytes = base64.b64encode(string.encode("ascii"))
    return base64_bytes.decode("ascii")

if session is not None:
    session.generate_authcode()

    url_send_login_otp = "https://api-t2.fyers.in/vagator/v2/send_login_otp_v2"
    res = requests.post(url=url_send_login_otp, json={"fy_id": getEncodedString(fyers_user), "app_id": "2"}).json()

    if datetime.now().second % 30 > 27:
        time.sleep(5)

    url_verify_otp = "https://api-t2.fyers.in/vagator/v2/verify_otp"
    res2 = requests.post(url=url_verify_otp, json={"request_key": res["request_key"], "otp": pyotp.TOTP(fyers_totp).now()}).json()

    ses = requests.Session()
    url_verify_otp2 = "https://api-t2.fyers.in/vagator/v2/verify_pin_v2"
    payload2 = {"request_key": res2["request_key"], "identity_type": "pin", "identifier": getEncodedString(fyers_pin)}
    res3 = ses.post(url=url_verify_otp2, json=payload2).json()

    ses.headers.update({'authorization': f"Bearer {res3['data']['access_token']}"})

    tokenurl = "https://api-t1.fyers.in/api/v3/token"
    payload3 = {
        "fyers_id": fyers_user,
        "app_id": app_id[:-4],
        "redirect_uri": redirect_uri,
        "appType": "100",
        "code_challenge": "",
        "state": "None",
        "scope": "",
        "nonce": "",
        "response_type": "code",
        "create_cookie": True
    }

    res3 = ses.post(url=tokenurl, json=payload3).json()

    url = res3['Url']
    parsed = urlparse(url)
    auth_code = parse_qs(parsed.query)['auth_code'][0]

    session.set_token(auth_code)

    auth_response = session.generate_token()
    access_token = auth_response["access_token"]

    fyers = fyersModel.FyersModel(client_id=app_id, token=access_token)

    ws_token = app_id + ":" + access_token
    fyers_socket = data_ws.FyersDataSocket(access_token=ws_token, log_path="")

pd.DataFrame(fyers.get_profile())
# Out:
#                   s  code message  \
# fy_id            ok   200
# name             ok   200
# image            ok   200
# display_name     ok   200
# pin_change_date  ok   200
# email_id         ok   200
# pwd_change_date  ok   200
# PAN              ok   200
# mobile_number    ok   200
# totp             ok   200
# pwd_to_expire    ok   200
# ddpi_enabled     ok   200
# mtf_enabled      ok   200
#
#                                                               data
# fy_id                                                      XM22383
# name                                                  MARSHAL TUDU
# image            https://myaccount-docs-prod.fyers.in/Profile_P...
# display_name                                                  None
# pin_change_date                                25-09-2023 17:16:16
# email_id                                    iammarshal22@gmail.com
# pwd_change_date                                01-06-2022 20:36:31
# PAN                                                      ---------
# mobile_number                                           8458060663
# totp                                                          True
# pwd_to_expire                                                 -851
# ddpi_enabled                                                 False
# mtf_enabled                                                  False

# %%
def fetch_candle_data(number, index_symbol, interval_minutes):
    while True:
        try:
            today = date.today()
            yesterday = today - timedelta(number)

            data = {
                "symbol": index_symbol,
                "resolution": interval_minutes,
                "date_format": "1",
                "range_from": yesterday,
                "range_to": today,
                "cont_flag": "1"
            }

            result = fyers.history(data=data)

            if result is not None:
                train_df = pd.DataFrame(result['candles'], columns=['datetime', 'open', 'high', 'low', 'close', 'volume'])
                return train_df
        except Exception as e:
            print(f"Error fetching Candle Data: {e}")
            time.sleep(active_order_sleep)

# %%
def fetch_train_candle_data(days_count, index_symbol, interval_minutes):
    train_df = pd.DataFrame()

    while True:
        try:
            date_increment = 100
            for i in range(days_count):
                today = date.today() - timedelta(date_increment)
                yesterday = today - timedelta(100)

                data = {
                    "symbol": index_symbol,
                    "resolution": interval_minutes,
                    "date_format": "1",
                    "range_from": yesterday,
                    "range_to": today,
                    "cont_flag": "1"
                }

                result = fyers.history(data=data)

                if result is not None:
                    temp_df = pd.DataFrame(result['candles'], columns=['datetime', 'open', 'high', 'low', 'close', 'volume'])
                    train_df = pd.concat([temp_df, train_df], ignore_index=True)

                date_increment += 100

            if train_df is not None:
                return train_df

        except Exception as e:
            print(f"Error fetching Candle Data: {e}")
            time.sleep(active_order_sleep)

# %%
index_mapping = {
    # Indices
    "Nifty": {
        "symbol": "NSE:NIFTY50-INDEX",
        "quantity": 75
    },
    "Bank_Nifty": {
        "symbol": "NSE:NIFTYBANK-INDEX",
        "quantity": 30
    },
    "Finnifty": {
        "symbol": "NSE:FINNIFTY-INDEX",
        "quantity": 40
    },
    "Sensex": {
        "symbol": "BSE:SENSEX-INDEX",
        "quantity": 20
    },
    "Bankex": {
        "symbol": "BSE:BANKEX-INDEX",
        "quantity": 15
    },

    # Complete Nifty 50 Stocks

    "Adani_Enterprises_Ltd": {
        "symbol": "NSE:ADANIENT-EQ",
        "quantity": 10
    },
    "Adani_Ports__SEZ_Ltd": {
        "symbol": "NSE:ADANIPORTS-EQ",
        "quantity": 10
    },
    "Apollo_Hospitals_Enterprise_Ltd": {
        "symbol": "NSE:APOLLOHOSP-EQ",
        "quantity": 10
    },
    "Asian_Paints_Ltd": {
        "symbol": "NSE:ASIANPAINT-EQ",
        "quantity": 10
    },
    "Axis_Bank_Ltd": {
        "symbol": "NSE:AXISBANK-EQ",
        "quantity": 10
    },
    "Bajaj_Auto_Ltd": {
        "symbol": "NSE:BAJAJ-AUTO-EQ",
        "quantity": 10
    },
    "Bajaj_Finance_Ltd": {
        "symbol": "NSE:BAJFINANCE-EQ",
        "quantity": 10
    },
    "Bajaj_Finserv_Ltd": {
        "symbol": "NSE:BAJAJFINSV-EQ",
        "quantity": 10
    },
    "Bharat_Electronics_Ltd": {
        "symbol": "NSE:BEL-EQ",
        "quantity": 10
    },
    "Bharti_Airtel_Ltd": {
        "symbol": "NSE:BHARTIARTL-EQ",
        "quantity": 10
    },
    "BPCL_Ltd": {
        "symbol": "NSE:BPCL-EQ",
        "quantity": 10
    },
    "Cipla_Ltd": {
        "symbol": "NSE:CIPLA-EQ",
        "quantity": 10
    },
    "Coal_India_Ltd": {
        "symbol": "NSE:COALINDIA-EQ",
        "quantity": 10
    },
    "Dr_Reddys_Laboratories_Ltd": {
        "symbol": "NSE:DRREDDY-EQ",
        "quantity": 10
    },
    "Eicher_Motors_Ltd": {
        "symbol": "NSE:EICHERMOT-EQ",
        "quantity": 10
    },
    "Grasim_Industries_Ltd": {
        "symbol": "NSE:GRASIM-EQ",
        "quantity": 10
    },
    "HCL_Technologies_Ltd": {
        "symbol": "NSE:HCLTECH-EQ",
        "quantity": 10
    },
    "HDFC_Bank_Ltd": {
        "symbol": "NSE:HDFCBANK-EQ",
        "quantity": 10
    },
    "HDFC_Life_Insurance_Company_Ltd": {
        "symbol": "NSE:HDFCLIFE-EQ",
        "quantity": 10
    },
    "Hero_MotoCorp_Ltd": {
        "symbol": "NSE:HEROMOTOCO-EQ",
        "quantity": 10
    },
    "Hindalco_Industries_Ltd": {
        "symbol": "NSE:HINDALCO-EQ",
        "quantity": 10
    },
    "Hindustan_Unilever_Ltd": {
        "symbol": "NSE:HINDUNILVR-EQ",
        "quantity": 10
    },
    "ICICI_Bank_Ltd": {
        "symbol": "NSE:ICICIBANK-EQ",
        "quantity": 10
    },
    "IndusInd_Bank_Ltd": {
        "symbol": "NSE:INDUSINDBK-EQ",
        "quantity": 10
    },
    "Infosys_Ltd": {
        "symbol": "NSE:INFY-EQ",
        "quantity": 10
    },
    "Indian_Oil_Corporation_Ltd": {
        "symbol": "NSE:IOC-EQ",
        "quantity": 10
    },
    "JSW_Steel_Ltd": {
        "symbol": "NSE:JSWSTEEL-EQ",
        "quantity": 10
    },
    "Kotak_Mahindra_Bank_Ltd": {
        "symbol": "NSE:KOTAKBANK-EQ",
        "quantity": 10
    },
    "Larsen__Toubro_Ltd": {
        "symbol": "NSE:LT-EQ",
        "quantity": 10
    },
    "Mahindra__Mahindra_Ltd": {
        "symbol": "NSE:M&M-EQ",
        "quantity": 10
    },
    "Maruti_Suzuki_India_Ltd": {
        "symbol": "NSE:MARUTI-EQ",
        "quantity": 10
    },
    "Nestle_India_Ltd": {
        "symbol": "NSE:NESTLEIND-EQ",
        "quantity": 10
    },
    "NTPC_Ltd": {
        "symbol": "NSE:NTPC-EQ",
        "quantity": 10
    },
    "ONGC_Ltd": {
        "symbol": "NSE:ONGC-EQ",
        "quantity": 10
    },
    "Power_Grid_Corporation_of_India_Ltd": {
        "symbol": "NSE:POWERGRID-EQ",
        "quantity": 10
    },
    "Reliance_Industries_Ltd": {
        "symbol": "NSE:RELIANCE-EQ",
        "quantity": 10
    },
    "State_Bank_of_India_(SBI)_Ltd": {
        "symbol": "NSE:SBIN-EQ",
        "quantity": 10
    },
    "SBI_Life_Insurance_Company_Ltd": {
        "symbol": "NSE:SBILIFE-EQ",
        "quantity": 10
    },
    "Sun_Pharmaceutical_Industries_Ltd": {
        "symbol": "NSE:SUNPHARMA-EQ",
        "quantity": 10
    },
    "Tata_Consumer_Products_Ltd": {
        "symbol": "NSE:TATACONSUM-EQ",
        "quantity": 10
    },
    "Tata_Motors_Ltd": {
        "symbol": "NSE:TATAMOTORS-EQ",
        "quantity": 10
    },
    "Tata_Steel_Ltd": {
        "symbol": "NSE:TATASTEEL-EQ",
        "quantity": 10
    },
    "TCS_Ltd": {
        "symbol": "NSE:TCS-EQ",
        "quantity": 10
    },
    "Tech_Mahindra_Ltd": {
        "symbol": "NSE:TECHM-EQ",
        "quantity": 10
    },
    "Titan_Company_Ltd": {
        "symbol": "NSE:TITAN-EQ",
        "quantity": 10
    },
    "Trent_Ltd": {
        "symbol": "NSE:TRENT-EQ",
        "quantity": 10
    },
    "UltraTech_Cement_Ltd": {
        "symbol": "NSE:ULTRACEMCO-EQ",
        "quantity": 10
    },
    "Wipro_Ltd": {
        "symbol": "NSE:WIPRO-EQ",
        "quantity": 10
    }
}

# %%
# Historical config for fetching and saving raw data
history_config = {
    "timeframes": [2, 3, 5, 10, 15, 20, 30, 45, 60, 120, 180, 240],
    "colab_folder_path": "/content/drive/MyDrive/historical_data",
    "colab_folder_path_processed": "processed_data",
    "local_folder_path": "historical_data",
    "local_folder_path_processed": "C:\\Users\\gs002\\OneDrive\\Desktop\\Marshal",
    "bar_limit": 15  # parameter for fetch_train_candle_data
}

# %%
if "google.colab" in sys.modules:
    folder_path = history_config["colab_folder_path"]
else:
    folder_path = history_config["local_folder_path"]

# %%
# Ensure the folder exists
if not os.path.exists(folder_path):
    os.makedirs(folder_path)

# %%
# Main loop to fetch and save data
for instrument_name, info in index_mapping.items():
    for tf in history_config["timeframes"]:
        file_name = f"{instrument_name}_{tf}.csv"
        file_path = os.path.join(folder_path, file_name)

        # Skip if file already exists
        if os.path.exists(file_path):
            print(f"File already exists for {instrument_name} timeframe {tf}. Skipping.")
            continue

        # Fetch data for given bar_limit, symbol, and timeframe
        df = fetch_train_candle_data(history_config["bar_limit"], info["symbol"], tf)

        # Save if data is not empty
        if not df.empty:
            df.to_csv(file_path, index=False)
            print(f"Saved data for {instrument_name} timeframe {tf} at {file_path}")
        else:
            print(f"No data returned for {instrument_name} timeframe {tf}.")
# Out:
# File already exists for Nifty timeframe 2. Skipping.
# File already exists for Nifty timeframe 3. Skipping.
# File already exists for Nifty timeframe 5. Skipping.
# File already exists for Nifty timeframe 10. Skipping.
# File already exists for Nifty timeframe 15. Skipping.
# File already exists for Nifty timeframe 20. Skipping.
# File already exists for Nifty timeframe 30. Skipping.
# File already exists for Nifty timeframe 45. Skipping.
# File already exists for Nifty timeframe 60. Skipping.
# File already exists for Nifty timeframe 120. Skipping.
# File already exists for Nifty timeframe 180. Skipping.
# File already exists for Nifty timeframe 240. Skipping.
# File already exists for Bank_Nifty timeframe 2. Skipping.
# File already exists for Bank_Nifty timeframe 3. Skipping.
# File already exists for Bank_Nifty timeframe 5. Skipping.
# File already exists for Bank_Nifty timeframe 10. Skipping.
# File already exists for Bank_Nifty timeframe 15. Skipping.
# File already exists for Bank_Nifty timeframe 20. Skipping.
# File already exists for Bank_Nifty timeframe 30. Skipping.
# File already exists for Bank_Nifty timeframe 45. Skipping.
# File already exists for Bank_Nifty timeframe 60. Skipping.
# File already exists for Bank_Nifty timeframe 120. Skipping.
# File already exists for Bank_Nifty timeframe 180. Skipping.
# File already exists for Bank_Nifty timeframe 240. Skipping.
# File already exists for Finnifty timeframe 2. Skipping.
# File already exists for Finnifty timeframe 3. Skipping.
# File already exists for Finnifty timeframe 5. Skipping.
# File already exists for Finnifty timeframe 10. Skipping.
# File already exists for Finnifty timeframe 15. Skipping.
# File already exists for Finnifty timeframe 20. Skipping.
# File already exists for Finnifty timeframe 30. Skipping.
# File already exists for Finnifty timeframe 45. Skipping.
# File already exists for Finnifty timeframe 60. Skipping.
# File already exists for Finnifty timeframe 120. Skipping.
# File already exists for Finnifty timeframe 180. Skipping.
# File already exists for Finnifty timeframe 240. Skipping.
# File already exists for Sensex timeframe 2. Skipping.
# File already exists for Sensex timeframe 3. Skipping.
# File already exists for Sensex timeframe 5. Skipping.
# File already exists for Sensex timeframe 10. Skipping.
# File already exists for Sensex timeframe 15. Skipping.
# File already exists for Sensex timeframe 20. Skipping.
# File already exists for Sensex timeframe 30. Skipping.
# File already exists for Sensex timeframe 45. Skipping.
# File already exists for Sensex timeframe 60. Skipping.
# File already exists for Sensex timeframe 120. Skipping.
# File already exists for Sensex timeframe 180. Skipping.
# File already exists for Sensex timeframe 240. Skipping.
# File already exists for Bankex timeframe 2. Skipping.
# File already exists for Bankex timeframe 3. Skipping.
# File already exists for Bankex timeframe 5. Skipping.
# File already exists for Bankex timeframe 10. Skipping.
# File already exists for Bankex timeframe 15. Skipping.
# File already exists for Bankex timeframe 20. Skipping.
# File already exists for Bankex timeframe 30. Skipping.
# File already exists for Bankex timeframe 45. Skipping.
# File already exists for Bankex timeframe 60. Skipping.
# File already exists for Bankex timeframe 120. Skipping.
# File already exists for Bankex timeframe 180. Skipping.
# File already exists for Bankex timeframe 240. Skipping.
# File already exists for Adani_Enterprises_Ltd timeframe 2. Skipping.
# File already exists for Adani_Enterprises_Ltd timeframe 3. Skipping.
# File already exists for Adani_Enterprises_Ltd timeframe 5. Skipping.
# File already exists for Adani_Enterprises_Ltd timeframe 10. Skipping.
# File already exists for Adani_Enterprises_Ltd timeframe 15. Skipping.
# File already exists for Adani_Enterprises_Ltd timeframe 20. Skipping.
# File already exists for Adani_Enterprises_Ltd timeframe 30. Skipping.
# File already exists for Adani_Enterprises_Ltd timeframe 45. Skipping.
# File already exists for Adani_Enterprises_Ltd timeframe 60. Skipping.
# File already exists for Adani_Enterprises_Ltd timeframe 120. Skipping.
# File already exists for Adani_Enterprises_Ltd timeframe 180. Skipping.
# File already exists for Adani_Enterprises_Ltd timeframe 240. Skipping.
# File already exists for Adani_Ports__SEZ_Ltd timeframe 2. Skipping.
# File already exists for Adani_Ports__SEZ_Ltd timeframe 3. Skipping.
# File already exists for Adani_Ports__SEZ_Ltd timeframe 5. Skipping.
# File already exists for Adani_Ports__SEZ_Ltd timeframe 10. Skipping.
# File already exists for Adani_Ports__SEZ_Ltd timeframe 15. Skipping.
# File already exists for Adani_Ports__SEZ_Ltd timeframe 20. Skipping.
# File already exists for Adani_Ports__SEZ_Ltd timeframe 30. Skipping.
# File already exists for Adani_Ports__SEZ_Ltd timeframe 45. Skipping.
# File already exists for Adani_Ports__SEZ_Ltd timeframe 60. Skipping.
# File already exists for Adani_Ports__SEZ_Ltd timeframe 120. Skipping.
# File already exists for Adani_Ports__SEZ_Ltd timeframe 180. Skipping.
# File already exists for Adani_Ports__SEZ_Ltd timeframe 240. Skipping.
# File already exists for Apollo_Hospitals_Enterprise_Ltd timeframe 2. Skipping.
# File already exists for Apollo_Hospitals_Enterprise_Ltd timeframe 3. Skipping.
# File already exists for Apollo_Hospitals_Enterprise_Ltd timeframe 5. Skipping.
# File already exists for Apollo_Hospitals_Enterprise_Ltd timeframe 10. Skipping.
# File already exists for Apollo_Hospitals_Enterprise_Ltd timeframe 15. Skipping.
# File already exists for Apollo_Hospitals_Enterprise_Ltd timeframe 20. Skipping.
# File already exists for Apollo_Hospitals_Enterprise_Ltd timeframe 30. Skipping.
# File already exists for Apollo_Hospitals_Enterprise_Ltd timeframe 45. Skipping.
# File already exists for Apollo_Hospitals_Enterprise_Ltd timeframe 60. Skipping.
# File already exists for Apollo_Hospitals_Enterprise_Ltd timeframe 120. Skipping.
# File already exists for Apollo_Hospitals_Enterprise_Ltd timeframe 180. Skipping.
# File already exists for Apollo_Hospitals_Enterprise_Ltd timeframe 240. Skipping.
# File already exists for Asian_Paints_Ltd timeframe 2. Skipping.
# File already exists for Asian_Paints_Ltd timeframe 3. Skipping.
# File already exists for Asian_Paints_Ltd timeframe 5. Skipping.
# File already exists for Asian_Paints_Ltd timeframe 10. Skipping.
# File already exists for Asian_Paints_Ltd timeframe 15. Skipping.
# File already exists for Asian_Paints_Ltd timeframe 20. Skipping.
# File already exists for Asian_Paints_Ltd timeframe 30. Skipping.
# File already exists for Asian_Paints_Ltd timeframe 45. Skipping.
# File already exists for Asian_Paints_Ltd timeframe 60. Skipping.
# File already exists for Asian_Paints_Ltd timeframe 120. Skipping.
# File already exists for Asian_Paints_Ltd timeframe 180. Skipping.
# File already exists for Asian_Paints_Ltd timeframe 240. Skipping.
# File already exists for Axis_Bank_Ltd timeframe 2. Skipping.
# File already exists for Axis_Bank_Ltd timeframe 3. Skipping.
# File already exists for Axis_Bank_Ltd timeframe 5. Skipping.
# File already exists for Axis_Bank_Ltd timeframe 10. Skipping.
# File already exists for Axis_Bank_Ltd timeframe 15. Skipping.
# File already exists for Axis_Bank_Ltd timeframe 20. Skipping.
# File already exists for Axis_Bank_Ltd timeframe 30. Skipping.
# File already exists for Axis_Bank_Ltd timeframe 45. Skipping.
# File already exists for Axis_Bank_Ltd timeframe 60. Skipping.
# File already exists for Axis_Bank_Ltd timeframe 120. Skipping.
# File already exists for Axis_Bank_Ltd timeframe 180. Skipping.
# File already exists for Axis_Bank_Ltd timeframe 240. Skipping.
# File already exists for Bajaj_Auto_Ltd timeframe 2. Skipping.
# File already exists for Bajaj_Auto_Ltd timeframe 3. Skipping.
# File already exists for Bajaj_Auto_Ltd timeframe 5. Skipping.
# File already exists for Bajaj_Auto_Ltd timeframe 10. Skipping.
# File already exists for Bajaj_Auto_Ltd timeframe 15. Skipping.
# File already exists for Bajaj_Auto_Ltd timeframe 20. Skipping.
# File already exists for Bajaj_Auto_Ltd timeframe 30. Skipping.
# File already exists for Bajaj_Auto_Ltd timeframe 45. Skipping.
# File already exists for Bajaj_Auto_Ltd timeframe 60. Skipping.
# File already exists for Bajaj_Auto_Ltd timeframe 120. Skipping.
# File already exists for Bajaj_Auto_Ltd timeframe 180. Skipping.
# File already exists for Bajaj_Auto_Ltd timeframe 240. Skipping.
# File already exists for Bajaj_Finance_Ltd timeframe 2. Skipping.
# File already exists for Bajaj_Finance_Ltd timeframe 3. Skipping.
# File already exists for Bajaj_Finance_Ltd timeframe 5. Skipping.
# File already exists for Bajaj_Finance_Ltd timeframe 10. Skipping.
# File already exists for Bajaj_Finance_Ltd timeframe 15. Skipping.
# File already exists for Bajaj_Finance_Ltd timeframe 20. Skipping.
# File already exists for Bajaj_Finance_Ltd timeframe 30. Skipping.
# File already exists for Bajaj_Finance_Ltd timeframe 45. Skipping.
# File already exists for Bajaj_Finance_Ltd timeframe 60. Skipping.
# File already exists for Bajaj_Finance_Ltd timeframe 120. Skipping.
# File already exists for Bajaj_Finance_Ltd timeframe 180. Skipping.
# File already exists for Bajaj_Finance_Ltd timeframe 240. Skipping.
# File already exists for Bajaj_Finserv_Ltd timeframe 2. Skipping.
# File already exists for Bajaj_Finserv_Ltd timeframe 3. Skipping.
# File already exists for Bajaj_Finserv_Ltd timeframe 5. Skipping.
# File already exists for Bajaj_Finserv_Ltd timeframe 10. Skipping.
# File already exists for Bajaj_Finserv_Ltd timeframe 15. Skipping.
# File already exists for Bajaj_Finserv_Ltd timeframe 20. Skipping.
# File already exists for Bajaj_Finserv_Ltd timeframe 30. Skipping.
# File already exists for Bajaj_Finserv_Ltd timeframe 45. Skipping.
# File already exists for Bajaj_Finserv_Ltd timeframe 60. Skipping.
# File already exists for Bajaj_Finserv_Ltd timeframe 120. Skipping.
# File already exists for Bajaj_Finserv_Ltd timeframe 180. Skipping.
# File already exists for Bajaj_Finserv_Ltd timeframe 240. Skipping.
# File already exists for Bharat_Electronics_Ltd timeframe 2. Skipping.
# File already exists for Bharat_Electronics_Ltd timeframe 3. Skipping.
# File already exists for Bharat_Electronics_Ltd timeframe 5. Skipping.
# File already exists for Bharat_Electronics_Ltd timeframe 10. Skipping.
# File already exists for Bharat_Electronics_Ltd timeframe 15. Skipping.
# File already exists for Bharat_Electronics_Ltd timeframe 20. Skipping.
# File already exists for Bharat_Electronics_Ltd timeframe 30. Skipping.
# File already exists for Bharat_Electronics_Ltd timeframe 45. Skipping.
# File already exists for Bharat_Electronics_Ltd timeframe 60. Skipping.
# File already exists for Bharat_Electronics_Ltd timeframe 120. Skipping.
# File already exists for Bharat_Electronics_Ltd timeframe 180. Skipping.
# File already exists for Bharat_Electronics_Ltd timeframe 240. Skipping.
# File already exists for Bharti_Airtel_Ltd timeframe 2. Skipping.
# File already exists for Bharti_Airtel_Ltd timeframe 3. Skipping.
# File already exists for Bharti_Airtel_Ltd timeframe 5. Skipping.
# File already exists for Bharti_Airtel_Ltd timeframe 10. Skipping.
# File already exists for Bharti_Airtel_Ltd timeframe 15. Skipping.
# File already exists for Bharti_Airtel_Ltd timeframe 20. Skipping.
# File already exists for Bharti_Airtel_Ltd timeframe 30. Skipping.
# File already exists for Bharti_Airtel_Ltd timeframe 45. Skipping.
# File already exists for Bharti_Airtel_Ltd timeframe 60. Skipping.
# File already exists for Bharti_Airtel_Ltd timeframe 120. Skipping.
# File already exists for Bharti_Airtel_Ltd timeframe 180. Skipping.
# File already exists for Bharti_Airtel_Ltd timeframe 240. Skipping.
# File already exists for BPCL_Ltd timeframe 2. Skipping.
# File already exists for BPCL_Ltd timeframe 3. Skipping.
# File already exists for BPCL_Ltd timeframe 5. Skipping.
# File already exists for BPCL_Ltd timeframe 10. Skipping.
# File already exists for BPCL_Ltd timeframe 15. Skipping.
# File already exists for BPCL_Ltd timeframe 20. Skipping.
# File already exists for BPCL_Ltd timeframe 30. Skipping.
# File already exists for BPCL_Ltd timeframe 45. Skipping.
# File already exists for BPCL_Ltd timeframe 60. Skipping.
# File already exists for BPCL_Ltd timeframe 120. Skipping.
# File already exists for BPCL_Ltd timeframe 180. Skipping.
# File already exists for BPCL_Ltd timeframe 240. Skipping.
# File already exists for Cipla_Ltd timeframe 2. Skipping.
# File already exists for Cipla_Ltd timeframe 3. Skipping.
# File already exists for Cipla_Ltd timeframe 5. Skipping.
# File already exists for Cipla_Ltd timeframe 10. Skipping.
# File already exists for Cipla_Ltd timeframe 15. Skipping.
# File already exists for Cipla_Ltd timeframe 20. Skipping.
# File already exists for Cipla_Ltd timeframe 30. Skipping.
# File already exists for Cipla_Ltd timeframe 45. Skipping.
# File already exists for Cipla_Ltd timeframe 60. Skipping.
# File already exists for Cipla_Ltd timeframe 120. Skipping.
# File already exists for Cipla_Ltd timeframe 180. Skipping.
# File already exists for Cipla_Ltd timeframe 240. Skipping.
# File already exists for Coal_India_Ltd timeframe 2. Skipping.
# File already exists for Coal_India_Ltd timeframe 3. Skipping.
# File already exists for Coal_India_Ltd timeframe 5. Skipping.
# File already exists for Coal_India_Ltd timeframe 10. Skipping.
# File already exists for Coal_India_Ltd timeframe 15. Skipping.
# File already exists for Coal_India_Ltd timeframe 20. Skipping.
# File already exists for Coal_India_Ltd timeframe 30. Skipping.
# File already exists for Coal_India_Ltd timeframe 45. Skipping.
# File already exists for Coal_India_Ltd timeframe 60. Skipping.
# File already exists for Coal_India_Ltd timeframe 120. Skipping.
# File already exists for Coal_India_Ltd timeframe 180. Skipping.
# File already exists for Coal_India_Ltd timeframe 240. Skipping.
# File already exists for Dr_Reddys_Laboratories_Ltd timeframe 2. Skipping.
# File already exists for Dr_Reddys_Laboratories_Ltd timeframe 3. Skipping.
# File already exists for Dr_Reddys_Laboratories_Ltd timeframe 5. Skipping.
# File already exists for Dr_Reddys_Laboratories_Ltd timeframe 10. Skipping.
# File already exists for Dr_Reddys_Laboratories_Ltd timeframe 15. Skipping.
# File already exists for Dr_Reddys_Laboratories_Ltd timeframe 20. Skipping.
# File already exists for Dr_Reddys_Laboratories_Ltd timeframe 30. Skipping.
# File already exists for Dr_Reddys_Laboratories_Ltd timeframe 45. Skipping.
# File already exists for Dr_Reddys_Laboratories_Ltd timeframe 60. Skipping.
# File already exists for Dr_Reddys_Laboratories_Ltd timeframe 120. Skipping.
# File already exists for Dr_Reddys_Laboratories_Ltd timeframe 180. Skipping.
# File already exists for Dr_Reddys_Laboratories_Ltd timeframe 240. Skipping.
# File already exists for Eicher_Motors_Ltd timeframe 2. Skipping.
# File already exists for Eicher_Motors_Ltd timeframe 3. Skipping.
# File already exists for Eicher_Motors_Ltd timeframe 5. Skipping.
# File already exists for Eicher_Motors_Ltd timeframe 10. Skipping.
# File already exists for Eicher_Motors_Ltd timeframe 15. Skipping.
# File already exists for Eicher_Motors_Ltd timeframe 20. Skipping.
# File already exists for Eicher_Motors_Ltd timeframe 30. Skipping.
# File already exists for Eicher_Motors_Ltd timeframe 45. Skipping.
# File already exists for Eicher_Motors_Ltd timeframe 60. Skipping.
# File already exists for Eicher_Motors_Ltd timeframe 120. Skipping.
# File already exists for Eicher_Motors_Ltd timeframe 180. Skipping.
# File already exists for Eicher_Motors_Ltd timeframe 240. Skipping.
# File already exists for Grasim_Industries_Ltd timeframe 2. Skipping.
# File already exists for Grasim_Industries_Ltd timeframe 3. Skipping.
# File already exists for Grasim_Industries_Ltd timeframe 5. Skipping.
# File already exists for Grasim_Industries_Ltd timeframe 10. Skipping.
# File already exists for Grasim_Industries_Ltd timeframe 15. Skipping.
# File already exists for Grasim_Industries_Ltd timeframe 20. Skipping.
# File already exists for Grasim_Industries_Ltd timeframe 30. Skipping.
# File already exists for Grasim_Industries_Ltd timeframe 45. Skipping.
# File already exists for Grasim_Industries_Ltd timeframe 60. Skipping.
# File already exists for Grasim_Industries_Ltd timeframe 120. Skipping.
# File already exists for Grasim_Industries_Ltd timeframe 180. Skipping.
# File already exists for Grasim_Industries_Ltd timeframe 240. Skipping.
# File already exists for HCL_Technologies_Ltd timeframe 2. Skipping.
# File already exists for HCL_Technologies_Ltd timeframe 3. Skipping.
# File already exists for HCL_Technologies_Ltd timeframe 5. Skipping.
# File already exists for HCL_Technologies_Ltd timeframe 10. Skipping.
# File already exists for HCL_Technologies_Ltd timeframe 15. Skipping.
# File already exists for HCL_Technologies_Ltd timeframe 20. Skipping.
# File already exists for HCL_Technologies_Ltd timeframe 30. Skipping.
# File already exists for HCL_Technologies_Ltd timeframe 45. Skipping.
# File already exists for HCL_Technologies_Ltd timeframe 60. Skipping.
# File already exists for HCL_Technologies_Ltd timeframe 120. Skipping.
# File already exists for HCL_Technologies_Ltd timeframe 180. Skipping.
# File already exists for HCL_Technologies_Ltd timeframe 240. Skipping.
# File already exists for HDFC_Bank_Ltd timeframe 2. Skipping.
# File already exists for HDFC_Bank_Ltd timeframe 3. Skipping.
# File already exists for HDFC_Bank_Ltd timeframe 5. Skipping.
# File already exists for HDFC_Bank_Ltd timeframe 10. Skipping.
# File already exists for HDFC_Bank_Ltd timeframe 15. Skipping.
# File already exists for HDFC_Bank_Ltd timeframe 20. Skipping.
# File already exists for HDFC_Bank_Ltd timeframe 30. Skipping.
# File already exists for HDFC_Bank_Ltd timeframe 45. Skipping.
# File already exists for HDFC_Bank_Ltd timeframe 60. Skipping.
# File already exists for HDFC_Bank_Ltd timeframe 120. Skipping.
# File already exists for HDFC_Bank_Ltd timeframe 180. Skipping.
# File already exists for HDFC_Bank_Ltd timeframe 240. Skipping.
# File already exists for HDFC_Life_Insurance_Company_Ltd timeframe 2. Skipping.
# File already exists for HDFC_Life_Insurance_Company_Ltd timeframe 3. Skipping.
# File already exists for HDFC_Life_Insurance_Company_Ltd timeframe 5. Skipping.
# File already exists for HDFC_Life_Insurance_Company_Ltd timeframe 10. Skipping.
# File already exists for HDFC_Life_Insurance_Company_Ltd timeframe 15. Skipping.
# File already exists for HDFC_Life_Insurance_Company_Ltd timeframe 20. Skipping.
# File already exists for HDFC_Life_Insurance_Company_Ltd timeframe 30. Skipping.
# File already exists for HDFC_Life_Insurance_Company_Ltd timeframe 45. Skipping.
# File already exists for HDFC_Life_Insurance_Company_Ltd timeframe 60. Skipping.
# File already exists for HDFC_Life_Insurance_Company_Ltd timeframe 120. Skipping.
# File already exists for HDFC_Life_Insurance_Company_Ltd timeframe 180. Skipping.
# File already exists for HDFC_Life_Insurance_Company_Ltd timeframe 240. Skipping.
# File already exists for Hero_MotoCorp_Ltd timeframe 2. Skipping.
# File already exists for Hero_MotoCorp_Ltd timeframe 3. Skipping.
# File already exists for Hero_MotoCorp_Ltd timeframe 5. Skipping.
# File already exists for Hero_MotoCorp_Ltd timeframe 10. Skipping.
# File already exists for Hero_MotoCorp_Ltd timeframe 15. Skipping.
# File already exists for Hero_MotoCorp_Ltd timeframe 20. Skipping.
# File already exists for Hero_MotoCorp_Ltd timeframe 30. Skipping.
# File already exists for Hero_MotoCorp_Ltd timeframe 45. Skipping.
# File already exists for Hero_MotoCorp_Ltd timeframe 60. Skipping.
# File already exists for Hero_MotoCorp_Ltd timeframe 120. Skipping.
# File already exists for Hero_MotoCorp_Ltd timeframe 180. Skipping.
# File already exists for Hero_MotoCorp_Ltd timeframe 240. Skipping.
# File already exists for Hindalco_Industries_Ltd timeframe 2. Skipping.
# File already exists for Hindalco_Industries_Ltd timeframe 3. Skipping.
# File already exists for Hindalco_Industries_Ltd timeframe 5. Skipping.
# File already exists for Hindalco_Industries_Ltd timeframe 10. Skipping.
# File already exists for Hindalco_Industries_Ltd timeframe 15. Skipping.
# File already exists for Hindalco_Industries_Ltd timeframe 20. Skipping.
# File already exists for Hindalco_Industries_Ltd timeframe 30. Skipping.
# File already exists for Hindalco_Industries_Ltd timeframe 45. Skipping.
# File already exists for Hindalco_Industries_Ltd timeframe 60. Skipping.
# File already exists for Hindalco_Industries_Ltd timeframe 120. Skipping.
# File already exists for Hindalco_Industries_Ltd timeframe 180. Skipping.
# File already exists for Hindalco_Industries_Ltd timeframe 240. Skipping.
# File already exists for Hindustan_Unilever_Ltd timeframe 2. Skipping.
# File already exists for Hindustan_Unilever_Ltd timeframe 3. Skipping.
# File already exists for Hindustan_Unilever_Ltd timeframe 5. Skipping.
# File already exists for Hindustan_Unilever_Ltd timeframe 10. Skipping.
# File already exists for Hindustan_Unilever_Ltd timeframe 15. Skipping.
# File already exists for Hindustan_Unilever_Ltd timeframe 20. Skipping.
# File already exists for Hindustan_Unilever_Ltd timeframe 30. Skipping.
# File already exists for Hindustan_Unilever_Ltd timeframe 45. Skipping.
# File already exists for Hindustan_Unilever_Ltd timeframe 60. Skipping.
# File already exists for Hindustan_Unilever_Ltd timeframe 120. Skipping.
# File already exists for Hindustan_Unilever_Ltd timeframe 180. Skipping.
# File already exists for Hindustan_Unilever_Ltd timeframe 240. Skipping.
# File already exists for ICICI_Bank_Ltd timeframe 2. Skipping.
# File already exists for ICICI_Bank_Ltd timeframe 3. Skipping.
# File already exists for ICICI_Bank_Ltd timeframe 5. Skipping.
# File already exists for ICICI_Bank_Ltd timeframe 10. Skipping.
# File already exists for ICICI_Bank_Ltd timeframe 15. Skipping.
# File already exists for ICICI_Bank_Ltd timeframe 20. Skipping.
# File already exists for ICICI_Bank_Ltd timeframe 30. Skipping.
# File already exists for ICICI_Bank_Ltd timeframe 45. Skipping.
# File already exists for ICICI_Bank_Ltd timeframe 60. Skipping.
# File already exists for ICICI_Bank_Ltd timeframe 120. Skipping.
# File already exists for ICICI_Bank_Ltd timeframe 180. Skipping.
# File already exists for ICICI_Bank_Ltd timeframe 240. Skipping.
# File already exists for IndusInd_Bank_Ltd timeframe 2. Skipping.
# File already exists for IndusInd_Bank_Ltd timeframe 3. Skipping.
# File already exists for IndusInd_Bank_Ltd timeframe 5. Skipping.
# File already exists for IndusInd_Bank_Ltd timeframe 10. Skipping.
# File already exists for IndusInd_Bank_Ltd timeframe 15. Skipping.
# File already exists for IndusInd_Bank_Ltd timeframe 20. Skipping.
# File already exists for IndusInd_Bank_Ltd timeframe 30. Skipping.
# File already exists for IndusInd_Bank_Ltd timeframe 45. Skipping.
# File already exists for IndusInd_Bank_Ltd timeframe 60. Skipping.
# File already exists for IndusInd_Bank_Ltd timeframe 120. Skipping.
# File already exists for IndusInd_Bank_Ltd timeframe 180. Skipping.
# File already exists for IndusInd_Bank_Ltd timeframe 240. Skipping.
# File already exists for Infosys_Ltd timeframe 2. Skipping.
# File already exists for Infosys_Ltd timeframe 3. Skipping.
# File already exists for Infosys_Ltd timeframe 5. Skipping.
# File already exists for Infosys_Ltd timeframe 10. Skipping.
# File already exists for Infosys_Ltd timeframe 15. Skipping.
# File already exists for Infosys_Ltd timeframe 20. Skipping.
# File already exists for Infosys_Ltd timeframe 30. Skipping.
# File already exists for Infosys_Ltd timeframe 45. Skipping.
# File already exists for Infosys_Ltd timeframe 60. Skipping.
# File already exists for Infosys_Ltd timeframe 120. Skipping.
# File already exists for Infosys_Ltd timeframe 180. Skipping.
# File already exists for Infosys_Ltd timeframe 240. Skipping.
# File already exists for Indian_Oil_Corporation_Ltd timeframe 2. Skipping.
# File already exists for Indian_Oil_Corporation_Ltd timeframe 3. Skipping.
# File already exists for Indian_Oil_Corporation_Ltd timeframe 5. Skipping.
# File already exists for Indian_Oil_Corporation_Ltd timeframe 10. Skipping.
# File already exists for Indian_Oil_Corporation_Ltd timeframe 15. Skipping.
# File already exists for Indian_Oil_Corporation_Ltd timeframe 20. Skipping.
# File already exists for Indian_Oil_Corporation_Ltd timeframe 30. Skipping.
# File already exists for Indian_Oil_Corporation_Ltd timeframe 45. Skipping.
# File already exists for Indian_Oil_Corporation_Ltd timeframe 60. Skipping.
# File already exists for Indian_Oil_Corporation_Ltd timeframe 120. Skipping.
# File already exists for Indian_Oil_Corporation_Ltd timeframe 180. Skipping.
# File already exists for Indian_Oil_Corporation_Ltd timeframe 240. Skipping.
# File already exists for JSW_Steel_Ltd timeframe 2. Skipping.
# File already exists for JSW_Steel_Ltd timeframe 3. Skipping.
# File already exists for JSW_Steel_Ltd timeframe 5. Skipping.
# File already exists for JSW_Steel_Ltd timeframe 10. Skipping.
# File already exists for JSW_Steel_Ltd timeframe 15. Skipping.
# File already exists for JSW_Steel_Ltd timeframe 20. Skipping.
# File already exists for JSW_Steel_Ltd timeframe 30. Skipping.
# File already exists for JSW_Steel_Ltd timeframe 45. Skipping.
# File already exists for JSW_Steel_Ltd timeframe 60. Skipping.
# File already exists for JSW_Steel_Ltd timeframe 120. Skipping.
# File already exists for JSW_Steel_Ltd timeframe 180. Skipping.
# File already exists for JSW_Steel_Ltd timeframe 240. Skipping.
# File already exists for Kotak_Mahindra_Bank_Ltd timeframe 2. Skipping.
# File already exists for Kotak_Mahindra_Bank_Ltd timeframe 3. Skipping.
# File already exists for Kotak_Mahindra_Bank_Ltd timeframe 5. Skipping.
# File already exists for Kotak_Mahindra_Bank_Ltd timeframe 10. Skipping.
# File already exists for Kotak_Mahindra_Bank_Ltd timeframe 15. Skipping.
# File already exists for Kotak_Mahindra_Bank_Ltd timeframe 20. Skipping.
# File already exists for Kotak_Mahindra_Bank_Ltd timeframe 30. Skipping.
# File already exists for Kotak_Mahindra_Bank_Ltd timeframe 45. Skipping.
# File already exists for Kotak_Mahindra_Bank_Ltd timeframe 60. Skipping.
# File already exists for Kotak_Mahindra_Bank_Ltd timeframe 120. Skipping.
# File already exists for Kotak_Mahindra_Bank_Ltd timeframe 180. Skipping.
# File already exists for Kotak_Mahindra_Bank_Ltd timeframe 240. Skipping.
# File already exists for Larsen__Toubro_Ltd timeframe 2. Skipping.
# File already exists for Larsen__Toubro_Ltd timeframe 3. Skipping.
# File already exists for Larsen__Toubro_Ltd timeframe 5. Skipping.
# File already exists for Larsen__Toubro_Ltd timeframe 10. Skipping.
# File already exists for Larsen__Toubro_Ltd timeframe 15. Skipping.
# File already exists for Larsen__Toubro_Ltd timeframe 20. Skipping.
# File already exists for Larsen__Toubro_Ltd timeframe 30. Skipping.
# File already exists for Larsen__Toubro_Ltd timeframe 45. Skipping.
# File already exists for Larsen__Toubro_Ltd timeframe 60. Skipping.
# File already exists for Larsen__Toubro_Ltd timeframe 120. Skipping.
# File already exists for Larsen__Toubro_Ltd timeframe 180. Skipping.
# File already exists for Larsen__Toubro_Ltd timeframe 240. Skipping.
# File already exists for Mahindra__Mahindra_Ltd timeframe 2. Skipping.
# File already exists for Mahindra__Mahindra_Ltd timeframe 3. Skipping.
# File already exists for Mahindra__Mahindra_Ltd timeframe 5. Skipping.
# File already exists for Mahindra__Mahindra_Ltd timeframe 10. Skipping.
# File already exists for Mahindra__Mahindra_Ltd timeframe 15. Skipping.
# File already exists for Mahindra__Mahindra_Ltd timeframe 20. Skipping.
# File already exists for Mahindra__Mahindra_Ltd timeframe 30. Skipping.
# File already exists for Mahindra__Mahindra_Ltd timeframe 45. Skipping.
# File already exists for Mahindra__Mahindra_Ltd timeframe 60. Skipping.
# File already exists for Mahindra__Mahindra_Ltd timeframe 120. Skipping.
# File already exists for Mahindra__Mahindra_Ltd timeframe 180. Skipping.
# File already exists for Mahindra__Mahindra_Ltd timeframe 240. Skipping.
# File already exists for Maruti_Suzuki_India_Ltd timeframe 2. Skipping.
# File already exists for Maruti_Suzuki_India_Ltd timeframe 3. Skipping.
# File already exists for Maruti_Suzuki_India_Ltd timeframe 5. Skipping.
# File already exists for Maruti_Suzuki_India_Ltd timeframe 10. Skipping.
# File already exists for Maruti_Suzuki_India_Ltd timeframe 15. Skipping.
# File already exists for Maruti_Suzuki_India_Ltd timeframe 20. Skipping.
# File already exists for Maruti_Suzuki_India_Ltd timeframe 30. Skipping.
# File already exists for Maruti_Suzuki_India_Ltd timeframe 45. Skipping.
# File already exists for Maruti_Suzuki_India_Ltd timeframe 60. Skipping.
# File already exists for Maruti_Suzuki_India_Ltd timeframe 120. Skipping.
# File already exists for Maruti_Suzuki_India_Ltd timeframe 180. Skipping.
# File already exists for Maruti_Suzuki_India_Ltd timeframe 240. Skipping.
# File already exists for Nestle_India_Ltd timeframe 2. Skipping.
# File already exists for Nestle_India_Ltd timeframe 3. Skipping.
# File already exists for Nestle_India_Ltd timeframe 5. Skipping.
# File already exists for Nestle_India_Ltd timeframe 10. Skipping.
# File already exists for Nestle_India_Ltd timeframe 15. Skipping.
# File already exists for Nestle_India_Ltd timeframe 20. Skipping.
# File already exists for Nestle_India_Ltd timeframe 30. Skipping.
# File already exists for Nestle_India_Ltd timeframe 45. Skipping.
# File already exists for Nestle_India_Ltd timeframe 60. Skipping.
# File already exists for Nestle_India_Ltd timeframe 120. Skipping.
# File already exists for Nestle_India_Ltd timeframe 180. Skipping.
# File already exists for Nestle_India_Ltd timeframe 240. Skipping.
# File already exists for NTPC_Ltd timeframe 2. Skipping.
# File already exists for NTPC_Ltd timeframe 3. Skipping.
# File already exists for NTPC_Ltd timeframe 5. Skipping.
# File already exists for NTPC_Ltd timeframe 10. Skipping.
# File already exists for NTPC_Ltd timeframe 15. Skipping.
# File already exists for NTPC_Ltd timeframe 20. Skipping.
# File already exists for NTPC_Ltd timeframe 30. Skipping.
# File already exists for NTPC_Ltd timeframe 45. Skipping.
# File already exists for NTPC_Ltd timeframe 60. Skipping.
# File already exists for NTPC_Ltd timeframe 120. Skipping.
# File already exists for NTPC_Ltd timeframe 180. Skipping.
# File already exists for NTPC_Ltd timeframe 240. Skipping.
# File already exists for ONGC_Ltd timeframe 2. Skipping.
# File already exists for ONGC_Ltd timeframe 3. Skipping.
# File already exists for ONGC_Ltd timeframe 5. Skipping.
# File already exists for ONGC_Ltd timeframe 10. Skipping.
# File already exists for ONGC_Ltd timeframe 15. Skipping.
# File already exists for ONGC_Ltd timeframe 20. Skipping.
# File already exists for ONGC_Ltd timeframe 30. Skipping.
# File already exists for ONGC_Ltd timeframe 45. Skipping.
# File already exists for ONGC_Ltd timeframe 60. Skipping.
# File already exists for ONGC_Ltd timeframe 120. Skipping.
# File already exists for ONGC_Ltd timeframe 180. Skipping.
# File already exists for ONGC_Ltd timeframe 240. Skipping.
# File already exists for Power_Grid_Corporation_of_India_Ltd timeframe 2. Skipping.
# File already exists for Power_Grid_Corporation_of_India_Ltd timeframe 3. Skipping.
# File already exists for Power_Grid_Corporation_of_India_Ltd timeframe 5. Skipping.
# File already exists for Power_Grid_Corporation_of_India_Ltd timeframe 10. Skipping.
# File already exists for Power_Grid_Corporation_of_India_Ltd timeframe 15. Skipping.
# File already exists for Power_Grid_Corporation_of_India_Ltd timeframe 20. Skipping.
# File already exists for Power_Grid_Corporation_of_India_Ltd timeframe 30. Skipping.
# File already exists for Power_Grid_Corporation_of_India_Ltd timeframe 45. Skipping.
# File already exists for Power_Grid_Corporation_of_India_Ltd timeframe 60. Skipping.
# File already exists for Power_Grid_Corporation_of_India_Ltd timeframe 120. Skipping.
# File already exists for Power_Grid_Corporation_of_India_Ltd timeframe 180. Skipping.
# File already exists for Power_Grid_Corporation_of_India_Ltd timeframe 240. Skipping.
# File already exists for Reliance_Industries_Ltd timeframe 2. Skipping.
# File already exists for Reliance_Industries_Ltd timeframe 3. Skipping.
# File already exists for Reliance_Industries_Ltd timeframe 5. Skipping.
# File already exists for Reliance_Industries_Ltd timeframe 10. Skipping.
# File already exists for Reliance_Industries_Ltd timeframe 15. Skipping.
# File already exists for Reliance_Industries_Ltd timeframe 20. Skipping.
# File already exists for Reliance_Industries_Ltd timeframe 30. Skipping.
# File already exists for Reliance_Industries_Ltd timeframe 45. Skipping.
# File already exists for Reliance_Industries_Ltd timeframe 60. Skipping.
# File already exists for Reliance_Industries_Ltd timeframe 120. Skipping.
# File already exists for Reliance_Industries_Ltd timeframe 180. Skipping.
# File already exists for Reliance_Industries_Ltd timeframe 240. Skipping.
# File already exists for State_Bank_of_India_(SBI)_Ltd timeframe 2. Skipping.
# File already exists for State_Bank_of_India_(SBI)_Ltd timeframe 3. Skipping.
# File already exists for State_Bank_of_India_(SBI)_Ltd timeframe 5. Skipping.
# File already exists for State_Bank_of_India_(SBI)_Ltd timeframe 10. Skipping.
# File already exists for State_Bank_of_India_(SBI)_Ltd timeframe 15. Skipping.
# File already exists for State_Bank_of_India_(SBI)_Ltd timeframe 20. Skipping.
# File already exists for State_Bank_of_India_(SBI)_Ltd timeframe 30. Skipping.
# File already exists for State_Bank_of_India_(SBI)_Ltd timeframe 45. Skipping.
# File already exists for State_Bank_of_India_(SBI)_Ltd timeframe 60. Skipping.
# File already exists for State_Bank_of_India_(SBI)_Ltd timeframe 120. Skipping.
# File already exists for State_Bank_of_India_(SBI)_Ltd timeframe 180. Skipping.
# File already exists for State_Bank_of_India_(SBI)_Ltd timeframe 240. Skipping.
# File already exists for SBI_Life_Insurance_Company_Ltd timeframe 2. Skipping.
# File already exists for SBI_Life_Insurance_Company_Ltd timeframe 3. Skipping.
# File already exists for SBI_Life_Insurance_Company_Ltd timeframe 5. Skipping.
# File already exists for SBI_Life_Insurance_Company_Ltd timeframe 10. Skipping.
# File already exists for SBI_Life_Insurance_Company_Ltd timeframe 15. Skipping.
# File already exists for SBI_Life_Insurance_Company_Ltd timeframe 20. Skipping.
# File already exists for SBI_Life_Insurance_Company_Ltd timeframe 30. Skipping.
# File already exists for SBI_Life_Insurance_Company_Ltd timeframe 45. Skipping.
# File already exists for SBI_Life_Insurance_Company_Ltd timeframe 60. Skipping.
# File already exists for SBI_Life_Insurance_Company_Ltd timeframe 120. Skipping.
# File already exists for SBI_Life_Insurance_Company_Ltd timeframe 180. Skipping.
# File already exists for SBI_Life_Insurance_Company_Ltd timeframe 240. Skipping.
# File already exists for Sun_Pharmaceutical_Industries_Ltd timeframe 2. Skipping.
# File already exists for Sun_Pharmaceutical_Industries_Ltd timeframe 3. Skipping.
# File already exists for Sun_Pharmaceutical_Industries_Ltd timeframe 5. Skipping.
# File already exists for Sun_Pharmaceutical_Industries_Ltd timeframe 10. Skipping.
# File already exists for Sun_Pharmaceutical_Industries_Ltd timeframe 15. Skipping.
# File already exists for Sun_Pharmaceutical_Industries_Ltd timeframe 20. Skipping.
# File already exists for Sun_Pharmaceutical_Industries_Ltd timeframe 30. Skipping.
# File already exists for Sun_Pharmaceutical_Industries_Ltd timeframe 45. Skipping.
# File already exists for Sun_Pharmaceutical_Industries_Ltd timeframe 60. Skipping.
# File already exists for Sun_Pharmaceutical_Industries_Ltd timeframe 120. Skipping.
# File already exists for Sun_Pharmaceutical_Industries_Ltd timeframe 180. Skipping.
# File already exists for Sun_Pharmaceutical_Industries_Ltd timeframe 240. Skipping.
# File already exists for Tata_Consumer_Products_Ltd timeframe 2. Skipping.
# File already exists for Tata_Consumer_Products_Ltd timeframe 3. Skipping.
# File already exists for Tata_Consumer_Products_Ltd timeframe 5. Skipping.
# File already exists for Tata_Consumer_Products_Ltd timeframe 10. Skipping.
# File already exists for Tata_Consumer_Products_Ltd timeframe 15. Skipping.
# File already exists for Tata_Consumer_Products_Ltd timeframe 20. Skipping.
# File already exists for Tata_Consumer_Products_Ltd timeframe 30. Skipping.
# File already exists for Tata_Consumer_Products_Ltd timeframe 45. Skipping.
# File already exists for Tata_Consumer_Products_Ltd timeframe 60. Skipping.
# File already exists for Tata_Consumer_Products_Ltd timeframe 120. Skipping.
# File already exists for Tata_Consumer_Products_Ltd timeframe 180. Skipping.
# File already exists for Tata_Consumer_Products_Ltd timeframe 240. Skipping.
# File already exists for Tata_Motors_Ltd timeframe 2. Skipping.
# File already exists for Tata_Motors_Ltd timeframe 3. Skipping.
# File already exists for Tata_Motors_Ltd timeframe 5. Skipping.
# File already exists for Tata_Motors_Ltd timeframe 10. Skipping.
# File already exists for Tata_Motors_Ltd timeframe 15. Skipping.
# File already exists for Tata_Motors_Ltd timeframe 20. Skipping.
# File already exists for Tata_Motors_Ltd timeframe 30. Skipping.
# File already exists for Tata_Motors_Ltd timeframe 45. Skipping.
# File already exists for Tata_Motors_Ltd timeframe 60. Skipping.
# File already exists for Tata_Motors_Ltd timeframe 120. Skipping.
# File already exists for Tata_Motors_Ltd timeframe 180. Skipping.
# File already exists for Tata_Motors_Ltd timeframe 240. Skipping.
# File already exists for Tata_Steel_Ltd timeframe 2. Skipping.
# File already exists for Tata_Steel_Ltd timeframe 3. Skipping.
# File already exists for Tata_Steel_Ltd timeframe 5. Skipping.
# File already exists for Tata_Steel_Ltd timeframe 10. Skipping.
# File already exists for Tata_Steel_Ltd timeframe 15. Skipping.
# File already exists for Tata_Steel_Ltd timeframe 20. Skipping.
# File already exists for Tata_Steel_Ltd timeframe 30. Skipping.
# File already exists for Tata_Steel_Ltd timeframe 45. Skipping.
# File already exists for Tata_Steel_Ltd timeframe 60. Skipping.
# File already exists for Tata_Steel_Ltd timeframe 120. Skipping.
# File already exists for Tata_Steel_Ltd timeframe 180. Skipping.
# File already exists for Tata_Steel_Ltd timeframe 240. Skipping.
# File already exists for TCS_Ltd timeframe 2. Skipping.
# File already exists for TCS_Ltd timeframe 3. Skipping.
# File already exists for TCS_Ltd timeframe 5. Skipping.
# File already exists for TCS_Ltd timeframe 10. Skipping.
# File already exists for TCS_Ltd timeframe 15. Skipping.
# File already exists for TCS_Ltd timeframe 20. Skipping.
# File already exists for TCS_Ltd timeframe 30. Skipping.
# File already exists for TCS_Ltd timeframe 45. Skipping.
# File already exists for TCS_Ltd timeframe 60. Skipping.
# File already exists for TCS_Ltd timeframe 120. Skipping.
# File already exists for TCS_Ltd timeframe 180. Skipping.
# File already exists for TCS_Ltd timeframe 240. Skipping.
# File already exists for Tech_Mahindra_Ltd timeframe 2. Skipping.
# File already exists for Tech_Mahindra_Ltd timeframe 3. Skipping.
# File already exists for Tech_Mahindra_Ltd timeframe 5. Skipping.
# File already exists for Tech_Mahindra_Ltd timeframe 10. Skipping.
# File already exists for Tech_Mahindra_Ltd timeframe 15. Skipping.
# File already exists for Tech_Mahindra_Ltd timeframe 20. Skipping.
# File already exists for Tech_Mahindra_Ltd timeframe 30. Skipping.
# File already exists for Tech_Mahindra_Ltd timeframe 45. Skipping.
# File already exists for Tech_Mahindra_Ltd timeframe 60. Skipping.
# File already exists for Tech_Mahindra_Ltd timeframe 120. Skipping.
# File already exists for Tech_Mahindra_Ltd timeframe 180. Skipping.
# File already exists for Tech_Mahindra_Ltd timeframe 240. Skipping.
# File already exists for Titan_Company_Ltd timeframe 2. Skipping.
# File already exists for Titan_Company_Ltd timeframe 3. Skipping.
# File already exists for Titan_Company_Ltd timeframe 5. Skipping.
# File already exists for Titan_Company_Ltd timeframe 10. Skipping.
# File already exists for Titan_Company_Ltd timeframe 15. Skipping.
# File already exists for Titan_Company_Ltd timeframe 20. Skipping.
# File already exists for Titan_Company_Ltd timeframe 30. Skipping.
# File already exists for Titan_Company_Ltd timeframe 45. Skipping.
# File already exists for Titan_Company_Ltd timeframe 60. Skipping.
# File already exists for Titan_Company_Ltd timeframe 120. Skipping.
# File already exists for Titan_Company_Ltd timeframe 180. Skipping.
# File already exists for Titan_Company_Ltd timeframe 240. Skipping.
# File already exists for Trent_Ltd timeframe 2. Skipping.
# File already exists for Trent_Ltd timeframe 3. Skipping.
# File already exists for Trent_Ltd timeframe 5. Skipping.
# File already exists for Trent_Ltd timeframe 10. Skipping.
# File already exists for Trent_Ltd timeframe 15. Skipping.
# File already exists for Trent_Ltd timeframe 20. Skipping.
# File already exists for Trent_Ltd timeframe 30. Skipping.
# File already exists for Trent_Ltd timeframe 45. Skipping.
# File already exists for Trent_Ltd timeframe 60. Skipping.
# File already exists for Trent_Ltd timeframe 120. Skipping.
# File already exists for Trent_Ltd timeframe 180. Skipping.
# File already exists for Trent_Ltd timeframe 240. Skipping.
# File already exists for UltraTech_Cement_Ltd timeframe 2. Skipping.
# File already exists for UltraTech_Cement_Ltd timeframe 3. Skipping.
# File already exists for UltraTech_Cement_Ltd timeframe 5. Skipping.
# File already exists for UltraTech_Cement_Ltd timeframe 10. Skipping.
# File already exists for UltraTech_Cement_Ltd timeframe 15. Skipping.
# File already exists for UltraTech_Cement_Ltd timeframe 20. Skipping.
# File already exists for UltraTech_Cement_Ltd timeframe 30. Skipping.
# File already exists for UltraTech_Cement_Ltd timeframe 45. Skipping.
# File already exists for UltraTech_Cement_Ltd timeframe 60. Skipping.
# File already exists for UltraTech_Cement_Ltd timeframe 120. Skipping.
# File already exists for UltraTech_Cement_Ltd timeframe 180. Skipping.
# File already exists for UltraTech_Cement_Ltd timeframe 240. Skipping.
# File already exists for Wipro_Ltd timeframe 2. Skipping.
# File already exists for Wipro_Ltd timeframe 3. Skipping.
# File already exists for Wipro_Ltd timeframe 5. Skipping.
# File already exists for Wipro_Ltd timeframe 10. Skipping.
# File already exists for Wipro_Ltd timeframe 15. Skipping.
# File already exists for Wipro_Ltd timeframe 20. Skipping.
# File already exists for Wipro_Ltd timeframe 30. Skipping.
# File already exists for Wipro_Ltd timeframe 45. Skipping.
# File already exists for Wipro_Ltd timeframe 60. Skipping.
# File already exists for Wipro_Ltd timeframe 120. Skipping.
# File already exists for Wipro_Ltd timeframe 180. Skipping.
# File already exists for Wipro_Ltd timeframe 240. Skipping.

# %%
# cell to identify and delete files not matching any instrument_name_timeframe.csv naming
import os

# build a set of valid filenames based on index_mapping keys and the timeframes
valid_filenames = set()
for instr_name in index_mapping.keys():
    for tf in history_config["timeframes"]:
        valid_filenames.add(f"{instr_name}_{tf}.csv")

# list all files in the folder, check which ones are not in the valid set, and delete them
for file in os.listdir(folder_path):
    # skip directories
    if os.path.isdir(os.path.join(folder_path, file)):
        continue
    if file not in valid_filenames:
        file_path = os.path.join(folder_path, file)
        os.remove(file_path)
        print(f"Deleted: {file}")

# %%
@njit
def label_signals_jit(close_arr, high_arr, low_arr, target_arr, stoploss_arr):
    n = len(close_arr)
    signals = np.zeros(n, dtype=np.float32)
    entry_prices = np.zeros(n, dtype=np.float32)
    exit_prices = np.zeros(n, dtype=np.float32)
    candles_to_profit = np.zeros(n, dtype=np.float32)
    candles_to_loss = np.zeros(n, dtype=np.float32)

    for i in range(n - 1):
        entry_price = close_arr[i]
        target = target_arr[i]
        stop_loss = stoploss_arr[i]

        buy_target_price = entry_price + target
        buy_sl_price = entry_price - stop_loss
        sell_target_price = entry_price - target
        sell_sl_price = entry_price + stop_loss

        signal_found = False
        for offset in range(i + 1, n):
            future_high = high_arr[offset]
            future_low = low_arr[offset]

            triggers = []
            # Check Buy triggers
            if future_high >= buy_target_price:
                triggers.append((1, offset - i))  # buy target
            if future_low <= buy_sl_price:
                triggers.append((2, offset - i))  # buy stoploss
            # Check Sell triggers
            if future_low <= sell_target_price:
                triggers.append((3, offset - i))  # sell target
            if future_high >= sell_sl_price:
                triggers.append((4, offset - i))  # sell stoploss

            # If any triggers fired, pick the first based on priority (1,2,3,4)
            if triggers:
                triggers.sort(key=lambda x: x[0])
                first_trigger, candle_count = triggers[0]

                signals[i] = float(first_trigger)
                entry_prices[i] = entry_price

                if first_trigger == 1:  # buy target
                    exit_prices[i] = buy_target_price
                    candles_to_profit[i] = float(candle_count)
                elif first_trigger == 2:  # buy stoploss
                    exit_prices[i] = buy_sl_price
                    candles_to_loss[i] = float(candle_count)
                elif first_trigger == 3:  # sell target
                    exit_prices[i] = sell_target_price
                    candles_to_profit[i] = float(candle_count)
                elif first_trigger == 4:  # sell stoploss
                    exit_prices[i] = sell_sl_price
                    candles_to_loss[i] = float(candle_count)

                signal_found = True
                break

        if not signal_found:
            signals[i] = 0
            entry_prices[i] = entry_price

    return signals, entry_prices, exit_prices, candles_to_profit, candles_to_loss


class FullFeaturePipeline:
    def __init__(self, df: pd.DataFrame):
        # df must have columns: [datetime, open, high, low, close, (volume optional)]
        self.df = df.copy()

    def preprocess_datetime(self):
        # Convert Unix timestamp to local time (Asia/Kolkata)
        ist = timezone('Asia/Kolkata')
        self.df['datetime'] = (
            pd.to_datetime(self.df['datetime'], unit='s')
            .dt.tz_localize('UTC')
            .dt.tz_convert(ist)
            .dt.tz_localize(None)
        )

        # Check for duplicates or missing
        if self.df['datetime'].duplicated().any() or self.df['datetime'].isnull().any():
            raise ValueError("The 'datetime' column contains duplicates or missing values.")

        # Sort and set as index
        self.df.sort_values('datetime', inplace=True)
        self.df.set_index('datetime', inplace=True)
        return self

    def clean_data(self):
        #if 'volume' in self.df.columns:
        #   vol_condition = self.df['volume'].isnull() | (self.df['volume'] <= 0)
        #    if vol_condition.any():
        #        self.df.drop('volume', axis=1, inplace=True)

        self.df.drop('volume', axis=1, inplace=True)

        return self

    def add_indicator_features(self):
        # ATR
        self.df['atr_14'] = ta.atr(
            high=self.df['high'],
            low=self.df['low'],
            close=self.df['close'],
            length=14
        ).astype(np.float32).round(2)

        # RSI
        self.df['rsi_14'] = ta.rsi(
            close=self.df['close'],
            length=14
        ).astype(np.float32).round(2)

        # Stoch
        stoch = ta.stoch(
            high=self.df['high'],
            low=self.df['low'],
            close=self.df['close'],
            k=14,
            d=3
        ).astype(np.float32).round(2)
        self.df = self.df.join(stoch)

        # MACD
        macd = ta.macd(
            close=self.df['close'],
            fast=12,
            slow=26,
            signal=9
        ).astype(np.float32).round(2)
        self.df = self.df.join(macd)

        # ADX
        adx = ta.adx(
            high=self.df['high'],
            low=self.df['low'],
            close=self.df['close'],
            length=14
        ).astype(np.float32).round(2)
        self.df = self.df.join(adx[['ADX_14']])
        self.df.rename(columns={'ADX_14': 'adx_14'}, inplace=True)

        # EMAs
        self.df['ema_50'] = ta.ema(self.df['close'], length=50).astype(np.float32).round(2)
        self.df['ema_200'] = ta.ema(self.df['close'], length=200).astype(np.float32).round(2)

        # SMA
        self.df['sma_20'] = ta.sma(self.df['close'], length=20).astype(np.float32).round(2)

        # Keltner Channels
        kc = ta.kc(
            high=self.df['high'],
            low=self.df['low'],
            close=self.df['close'],
            length=20
        ).astype(np.float32).round(2)
        self.df = self.df.join(kc)


        # Price Action Features
        self.df['price_range'] = (self.df['high'] - self.df['low']).astype(np.float32).round(2)
        self.df['body_size'] = (self.df['close'] - self.df['open']).abs().astype(np.float32).round(2)
        self.df['upper_wick'] = (
            self.df['high'] - self.df[['open', 'close']].max(axis=1)
        ).astype(np.float32).round(2)
        self.df['lower_wick'] = (
            self.df[['open', 'close']].min(axis=1) - self.df['low']
        ).astype(np.float32).round(2)

        return self

    def add_time_features(self):
        # Hour, day_of_week, month
        self.df['hour'] = self.df.index.hour.astype(np.int32)
        self.df['day_of_week'] = self.df.index.dayofweek.astype(np.int32)
        self.df['month'] = self.df.index.month.astype(np.int32)
        return self

    def add_adaptive_targets_and_stops(self):
        # ATR-based target and stoploss
        self.df['Target'] = (2.0 * self.df['atr_14']).astype(np.float32).round(2)
        self.df['StopLoss'] = (1.0 * self.df['atr_14']).astype(np.float32).round(2)
        return self

    def label_signals(self):
        from __main__ import label_signals_jit  # or from the same notebook cell, as needed

        close_arr = self.df['close'].values
        high_arr = self.df['high'].values
        low_arr = self.df['low'].values
        target_arr = self.df['Target'].values
        stoploss_arr = self.df['StopLoss'].values

        signals, entry_prices, exit_prices, ctp, ctl = label_signals_jit(
            close_arr,
            high_arr,
            low_arr,
            target_arr,
            stoploss_arr
        )
        self.df['Signal'] = signals.astype(np.float32)
        self.df['Entry Price'] = entry_prices.astype(np.float32).round(2)
        self.df['Exit Price'] = exit_prices.astype(np.float32).round(2)
        self.df['candles_to_profit'] = ctp.astype(np.float32)
        self.df['candles_to_loss'] = ctl.astype(np.float32)

        return self

    def run_pipeline(self):
        (self.preprocess_datetime()
             .clean_data()
             .add_indicator_features()
             .add_time_features()
             .add_adaptive_targets_and_stops()
             .label_signals())
        return self

    def get_processed_df(self):
        # Drop rows with any NaN
        self.df.dropna(axis=0, how='any', inplace=True)

        # Remove Entry/Exit Price columns if you don't need them
        if 'Entry Price' in self.df.columns:
            self.df.drop('Entry Price', axis=1, inplace=True)
        if 'Exit Price' in self.df.columns:
            self.df.drop('Exit Price', axis=1, inplace=True)

        return self.df

# %%
if "google.colab" in sys.modules:
    processed_folder_path = history_config["colab_folder_path_processed"]
else:
    processed_folder_path = history_config["local_folder_path_processed"]

if not os.path.exists(processed_folder_path):
    os.makedirs(processed_folder_path)

# %%
# We'll store (instrument_name, timeframe, processed_df) tuples in this list
temp_data_list = []

for file in os.listdir(folder_path):
    if file.endswith(".csv"):
        file_path = os.path.join(folder_path, file)

        # Split the filename on the last underscore to accommodate multiple underscores in the instrument name
        instrument_name, timeframe_str = file.replace(".csv", "").rsplit("_", 1)
        timeframe = int(timeframe_str)

        processed_file_name = f"{instrument_name}_{timeframe}_processed.csv"
        processed_file_path = os.path.join(processed_folder_path, processed_file_name)

        # If processed file exists, skip reprocessing
        if os.path.exists(processed_file_path):
            print(f"Processed file already exists for {instrument_name} {timeframe}M. Skipping.")
        else:
            # Process it once, then drop from memory
            raw_df = pd.read_csv(file_path).drop_duplicates(subset='datetime', keep='first')
            pipeline = FullFeaturePipeline(raw_df)
            pipeline.run_pipeline()
            processed_df = pipeline.get_processed_df()

            processed_df.to_csv(processed_file_path, index=True, index_label='datetime')
            print(f"Processed and saved data for {instrument_name} {timeframe}M at {processed_file_path}")

            # Cleanup to free memory
            del raw_df
            del processed_df
            gc.collect()

        # We always add the path so we know it exists (either newly processed or previously)
        temp_data_list.append((instrument_name, timeframe, processed_file_path))
# Out:
# Processed file already exists for Adani_Enterprises_Ltd 10M. Skipping.
# Processed file already exists for Adani_Enterprises_Ltd 120M. Skipping.
# Processed file already exists for Adani_Enterprises_Ltd 15M. Skipping.
# Processed file already exists for Adani_Enterprises_Ltd 180M. Skipping.
# Processed file already exists for Adani_Enterprises_Ltd 2M. Skipping.
# Processed file already exists for Adani_Enterprises_Ltd 20M. Skipping.
# Processed file already exists for Adani_Enterprises_Ltd 240M. Skipping.
# Processed file already exists for Adani_Enterprises_Ltd 3M. Skipping.
# Processed file already exists for Adani_Enterprises_Ltd 30M. Skipping.
# Processed file already exists for Adani_Enterprises_Ltd 45M. Skipping.
# Processed file already exists for Adani_Enterprises_Ltd 5M. Skipping.
# Processed file already exists for Adani_Enterprises_Ltd 60M. Skipping.
# Processed file already exists for Adani_Ports__SEZ_Ltd 10M. Skipping.
# Processed file already exists for Adani_Ports__SEZ_Ltd 120M. Skipping.
# Processed file already exists for Adani_Ports__SEZ_Ltd 15M. Skipping.
# Processed file already exists for Adani_Ports__SEZ_Ltd 180M. Skipping.
# Processed file already exists for Adani_Ports__SEZ_Ltd 2M. Skipping.
# Processed file already exists for Adani_Ports__SEZ_Ltd 20M. Skipping.
# Processed file already exists for Adani_Ports__SEZ_Ltd 240M. Skipping.
# Processed file already exists for Adani_Ports__SEZ_Ltd 3M. Skipping.
# Processed file already exists for Adani_Ports__SEZ_Ltd 30M. Skipping.
# Processed file already exists for Adani_Ports__SEZ_Ltd 45M. Skipping.
# Processed file already exists for Adani_Ports__SEZ_Ltd 5M. Skipping.
# Processed file already exists for Adani_Ports__SEZ_Ltd 60M. Skipping.
# Processed file already exists for Apollo_Hospitals_Enterprise_Ltd 10M. Skipping.
# Processed file already exists for Apollo_Hospitals_Enterprise_Ltd 120M. Skipping.
# Processed file already exists for Apollo_Hospitals_Enterprise_Ltd 15M. Skipping.
# Processed file already exists for Apollo_Hospitals_Enterprise_Ltd 180M. Skipping.
# Processed file already exists for Apollo_Hospitals_Enterprise_Ltd 2M. Skipping.
# Processed file already exists for Apollo_Hospitals_Enterprise_Ltd 20M. Skipping.
# Processed file already exists for Apollo_Hospitals_Enterprise_Ltd 240M. Skipping.
# Processed file already exists for Apollo_Hospitals_Enterprise_Ltd 3M. Skipping.
# Processed file already exists for Apollo_Hospitals_Enterprise_Ltd 30M. Skipping.
# Processed file already exists for Apollo_Hospitals_Enterprise_Ltd 45M. Skipping.
# Processed file already exists for Apollo_Hospitals_Enterprise_Ltd 5M. Skipping.
# Processed file already exists for Apollo_Hospitals_Enterprise_Ltd 60M. Skipping.
# Processed file already exists for Asian_Paints_Ltd 10M. Skipping.
# Processed file already exists for Asian_Paints_Ltd 120M. Skipping.
# Processed file already exists for Asian_Paints_Ltd 15M. Skipping.
# Processed file already exists for Asian_Paints_Ltd 180M. Skipping.
# Processed file already exists for Asian_Paints_Ltd 2M. Skipping.
# Processed file already exists for Asian_Paints_Ltd 20M. Skipping.
# Processed file already exists for Asian_Paints_Ltd 240M. Skipping.
# Processed file already exists for Asian_Paints_Ltd 3M. Skipping.
# Processed file already exists for Asian_Paints_Ltd 30M. Skipping.
# Processed file already exists for Asian_Paints_Ltd 45M. Skipping.
# Processed file already exists for Asian_Paints_Ltd 5M. Skipping.
# Processed file already exists for Asian_Paints_Ltd 60M. Skipping.
# Processed file already exists for Axis_Bank_Ltd 10M. Skipping.
# Processed file already exists for Axis_Bank_Ltd 120M. Skipping.
# Processed file already exists for Axis_Bank_Ltd 15M. Skipping.
# Processed file already exists for Axis_Bank_Ltd 180M. Skipping.
# Processed file already exists for Axis_Bank_Ltd 2M. Skipping.
# Processed file already exists for Axis_Bank_Ltd 20M. Skipping.
# Processed file already exists for Axis_Bank_Ltd 240M. Skipping.
# Processed file already exists for Axis_Bank_Ltd 3M. Skipping.
# Processed file already exists for Axis_Bank_Ltd 30M. Skipping.
# Processed file already exists for Axis_Bank_Ltd 45M. Skipping.
# Processed file already exists for Axis_Bank_Ltd 5M. Skipping.
# Processed file already exists for Axis_Bank_Ltd 60M. Skipping.
# Processed file already exists for Bajaj_Auto_Ltd 10M. Skipping.
# Processed file already exists for Bajaj_Auto_Ltd 120M. Skipping.
# Processed file already exists for Bajaj_Auto_Ltd 15M. Skipping.
# Processed file already exists for Bajaj_Auto_Ltd 180M. Skipping.
# Processed file already exists for Bajaj_Auto_Ltd 2M. Skipping.
# Processed file already exists for Bajaj_Auto_Ltd 20M. Skipping.
# Processed file already exists for Bajaj_Auto_Ltd 240M. Skipping.
# Processed file already exists for Bajaj_Auto_Ltd 3M. Skipping.
# Processed file already exists for Bajaj_Auto_Ltd 30M. Skipping.
# Processed file already exists for Bajaj_Auto_Ltd 45M. Skipping.
# Processed file already exists for Bajaj_Auto_Ltd 5M. Skipping.
# Processed file already exists for Bajaj_Auto_Ltd 60M. Skipping.
# Processed file already exists for Bajaj_Finance_Ltd 10M. Skipping.
# Processed file already exists for Bajaj_Finance_Ltd 120M. Skipping.
# Processed file already exists for Bajaj_Finance_Ltd 15M. Skipping.
# Processed file already exists for Bajaj_Finance_Ltd 180M. Skipping.
# Processed file already exists for Bajaj_Finance_Ltd 2M. Skipping.
# Processed file already exists for Bajaj_Finance_Ltd 20M. Skipping.
# Processed file already exists for Bajaj_Finance_Ltd 240M. Skipping.
# Processed file already exists for Bajaj_Finance_Ltd 3M. Skipping.
# Processed file already exists for Bajaj_Finance_Ltd 30M. Skipping.
# Processed file already exists for Bajaj_Finance_Ltd 45M. Skipping.
# Processed file already exists for Bajaj_Finance_Ltd 5M. Skipping.
# Processed file already exists for Bajaj_Finance_Ltd 60M. Skipping.
# Processed file already exists for Bajaj_Finserv_Ltd 10M. Skipping.
# Processed file already exists for Bajaj_Finserv_Ltd 120M. Skipping.
# Processed file already exists for Bajaj_Finserv_Ltd 15M. Skipping.
# Processed file already exists for Bajaj_Finserv_Ltd 180M. Skipping.
# Processed file already exists for Bajaj_Finserv_Ltd 2M. Skipping.
# Processed file already exists for Bajaj_Finserv_Ltd 20M. Skipping.
# Processed file already exists for Bajaj_Finserv_Ltd 240M. Skipping.
# Processed file already exists for Bajaj_Finserv_Ltd 3M. Skipping.
# Processed file already exists for Bajaj_Finserv_Ltd 30M. Skipping.
# Processed file already exists for Bajaj_Finserv_Ltd 45M. Skipping.
# Processed file already exists for Bajaj_Finserv_Ltd 5M. Skipping.
# Processed file already exists for Bajaj_Finserv_Ltd 60M. Skipping.
# Processed file already exists for Bankex 10M. Skipping.
# Processed file already exists for Bankex 120M. Skipping.
# Processed file already exists for Bankex 15M. Skipping.
# Processed file already exists for Bankex 180M. Skipping.
# Processed file already exists for Bankex 2M. Skipping.
# Processed file already exists for Bankex 20M. Skipping.
# Processed file already exists for Bankex 240M. Skipping.
# Processed file already exists for Bankex 3M. Skipping.
# Processed file already exists for Bankex 30M. Skipping.
# Processed file already exists for Bankex 45M. Skipping.
# Processed file already exists for Bankex 5M. Skipping.
# Processed file already exists for Bankex 60M. Skipping.
# Processed file already exists for Bank_Nifty 10M. Skipping.
# Processed file already exists for Bank_Nifty 120M. Skipping.
# Processed file already exists for Bank_Nifty 15M. Skipping.
# Processed file already exists for Bank_Nifty 180M. Skipping.
# Processed file already exists for Bank_Nifty 2M. Skipping.
# Processed file already exists for Bank_Nifty 20M. Skipping.
# Processed file already exists for Bank_Nifty 240M. Skipping.
# Processed file already exists for Bank_Nifty 3M. Skipping.
# Processed file already exists for Bank_Nifty 30M. Skipping.
# Processed file already exists for Bank_Nifty 45M. Skipping.
# Processed file already exists for Bank_Nifty 5M. Skipping.
# Processed file already exists for Bank_Nifty 60M. Skipping.
# Processed file already exists for Bharat_Electronics_Ltd 10M. Skipping.
# Processed file already exists for Bharat_Electronics_Ltd 120M. Skipping.
# Processed file already exists for Bharat_Electronics_Ltd 15M. Skipping.
# Processed file already exists for Bharat_Electronics_Ltd 180M. Skipping.
# Processed file already exists for Bharat_Electronics_Ltd 2M. Skipping.
# Processed file already exists for Bharat_Electronics_Ltd 20M. Skipping.
# Processed file already exists for Bharat_Electronics_Ltd 240M. Skipping.
# Processed file already exists for Bharat_Electronics_Ltd 3M. Skipping.
# Processed file already exists for Bharat_Electronics_Ltd 30M. Skipping.
# Processed file already exists for Bharat_Electronics_Ltd 45M. Skipping.
# Processed file already exists for Bharat_Electronics_Ltd 5M. Skipping.
# Processed file already exists for Bharat_Electronics_Ltd 60M. Skipping.
# Processed file already exists for Bharti_Airtel_Ltd 10M. Skipping.
# Processed file already exists for Bharti_Airtel_Ltd 120M. Skipping.
# Processed file already exists for Bharti_Airtel_Ltd 15M. Skipping.
# Processed file already exists for Bharti_Airtel_Ltd 180M. Skipping.
# Processed file already exists for Bharti_Airtel_Ltd 2M. Skipping.
# Processed file already exists for Bharti_Airtel_Ltd 20M. Skipping.
# Processed file already exists for Bharti_Airtel_Ltd 240M. Skipping.
# Processed file already exists for Bharti_Airtel_Ltd 3M. Skipping.
# Processed file already exists for Bharti_Airtel_Ltd 30M. Skipping.
# Processed file already exists for Bharti_Airtel_Ltd 45M. Skipping.
# Processed file already exists for Bharti_Airtel_Ltd 5M. Skipping.
# Processed file already exists for Bharti_Airtel_Ltd 60M. Skipping.
# Processed file already exists for BPCL_Ltd 10M. Skipping.
# Processed file already exists for BPCL_Ltd 120M. Skipping.
# Processed file already exists for BPCL_Ltd 15M. Skipping.
# Processed file already exists for BPCL_Ltd 180M. Skipping.
# Processed file already exists for BPCL_Ltd 2M. Skipping.
# Processed file already exists for BPCL_Ltd 20M. Skipping.
# Processed file already exists for BPCL_Ltd 240M. Skipping.
# Processed file already exists for BPCL_Ltd 3M. Skipping.
# Processed file already exists for BPCL_Ltd 30M. Skipping.
# Processed file already exists for BPCL_Ltd 45M. Skipping.
# Processed file already exists for BPCL_Ltd 5M. Skipping.
# Processed file already exists for BPCL_Ltd 60M. Skipping.
# Processed file already exists for Cipla_Ltd 10M. Skipping.
# Processed file already exists for Cipla_Ltd 120M. Skipping.
# Processed file already exists for Cipla_Ltd 15M. Skipping.
# Processed file already exists for Cipla_Ltd 180M. Skipping.
# Processed file already exists for Cipla_Ltd 2M. Skipping.
# Processed file already exists for Cipla_Ltd 20M. Skipping.
# Processed file already exists for Cipla_Ltd 240M. Skipping.
# Processed file already exists for Cipla_Ltd 3M. Skipping.
# Processed file already exists for Cipla_Ltd 30M. Skipping.
# Processed file already exists for Cipla_Ltd 45M. Skipping.
# Processed file already exists for Cipla_Ltd 5M. Skipping.
# Processed file already exists for Cipla_Ltd 60M. Skipping.
# Processed file already exists for Coal_India_Ltd 10M. Skipping.
# Processed file already exists for Coal_India_Ltd 120M. Skipping.
# Processed file already exists for Coal_India_Ltd 15M. Skipping.
# Processed file already exists for Coal_India_Ltd 180M. Skipping.
# Processed file already exists for Coal_India_Ltd 2M. Skipping.
# Processed file already exists for Coal_India_Ltd 20M. Skipping.
# Processed file already exists for Coal_India_Ltd 240M. Skipping.
# Processed file already exists for Coal_India_Ltd 3M. Skipping.
# Processed file already exists for Coal_India_Ltd 30M. Skipping.
# Processed file already exists for Coal_India_Ltd 45M. Skipping.
# Processed file already exists for Coal_India_Ltd 5M. Skipping.
# Processed file already exists for Coal_India_Ltd 60M. Skipping.
# Processed file already exists for Dr_Reddys_Laboratories_Ltd 10M. Skipping.
# Processed file already exists for Dr_Reddys_Laboratories_Ltd 120M. Skipping.
# Processed file already exists for Dr_Reddys_Laboratories_Ltd 15M. Skipping.
# Processed file already exists for Dr_Reddys_Laboratories_Ltd 180M. Skipping.
# Processed file already exists for Dr_Reddys_Laboratories_Ltd 2M. Skipping.
# Processed file already exists for Dr_Reddys_Laboratories_Ltd 20M. Skipping.
# Processed file already exists for Dr_Reddys_Laboratories_Ltd 240M. Skipping.
# Processed file already exists for Dr_Reddys_Laboratories_Ltd 3M. Skipping.
# Processed file already exists for Dr_Reddys_Laboratories_Ltd 30M. Skipping.
# Processed file already exists for Dr_Reddys_Laboratories_Ltd 45M. Skipping.
# Processed file already exists for Dr_Reddys_Laboratories_Ltd 5M. Skipping.
# Processed file already exists for Dr_Reddys_Laboratories_Ltd 60M. Skipping.
# Processed file already exists for Eicher_Motors_Ltd 10M. Skipping.
# Processed file already exists for Eicher_Motors_Ltd 120M. Skipping.
# Processed file already exists for Eicher_Motors_Ltd 15M. Skipping.
# Processed file already exists for Eicher_Motors_Ltd 180M. Skipping.
# Processed file already exists for Eicher_Motors_Ltd 2M. Skipping.
# Processed file already exists for Eicher_Motors_Ltd 20M. Skipping.
# Processed file already exists for Eicher_Motors_Ltd 240M. Skipping.
# Processed file already exists for Eicher_Motors_Ltd 3M. Skipping.
# Processed file already exists for Eicher_Motors_Ltd 30M. Skipping.
# Processed file already exists for Eicher_Motors_Ltd 45M. Skipping.
# Processed file already exists for Eicher_Motors_Ltd 5M. Skipping.
# Processed file already exists for Eicher_Motors_Ltd 60M. Skipping.
# Processed file already exists for Finnifty 10M. Skipping.
# Processed file already exists for Finnifty 120M. Skipping.
# Processed file already exists for Finnifty 15M. Skipping.
# Processed file already exists for Finnifty 180M. Skipping.
# Processed file already exists for Finnifty 2M. Skipping.
# Processed file already exists for Finnifty 20M. Skipping.
# Processed file already exists for Finnifty 240M. Skipping.
# Processed file already exists for Finnifty 3M. Skipping.
# Processed file already exists for Finnifty 30M. Skipping.
# Processed file already exists for Finnifty 45M. Skipping.
# Processed file already exists for Finnifty 5M. Skipping.
# Processed file already exists for Finnifty 60M. Skipping.
# Processed file already exists for Grasim_Industries_Ltd 10M. Skipping.
# Processed file already exists for Grasim_Industries_Ltd 120M. Skipping.
# Processed file already exists for Grasim_Industries_Ltd 15M. Skipping.
# Processed file already exists for Grasim_Industries_Ltd 180M. Skipping.
# Processed file already exists for Grasim_Industries_Ltd 2M. Skipping.
# Processed file already exists for Grasim_Industries_Ltd 20M. Skipping.
# Processed file already exists for Grasim_Industries_Ltd 240M. Skipping.
# Processed file already exists for Grasim_Industries_Ltd 3M. Skipping.
# Processed file already exists for Grasim_Industries_Ltd 30M. Skipping.
# Processed file already exists for Grasim_Industries_Ltd 45M. Skipping.
# Processed file already exists for Grasim_Industries_Ltd 5M. Skipping.
# Processed file already exists for Grasim_Industries_Ltd 60M. Skipping.
# Processed file already exists for HCL_Technologies_Ltd 10M. Skipping.
# Processed file already exists for HCL_Technologies_Ltd 120M. Skipping.
# Processed file already exists for HCL_Technologies_Ltd 15M. Skipping.
# Processed file already exists for HCL_Technologies_Ltd 180M. Skipping.
# Processed file already exists for HCL_Technologies_Ltd 2M. Skipping.
# Processed file already exists for HCL_Technologies_Ltd 20M. Skipping.
# Processed file already exists for HCL_Technologies_Ltd 240M. Skipping.
# Processed file already exists for HCL_Technologies_Ltd 3M. Skipping.
# Processed file already exists for HCL_Technologies_Ltd 30M. Skipping.
# Processed file already exists for HCL_Technologies_Ltd 45M. Skipping.
# Processed file already exists for HCL_Technologies_Ltd 5M. Skipping.
# Processed file already exists for HCL_Technologies_Ltd 60M. Skipping.
# Processed file already exists for HDFC_Bank_Ltd 10M. Skipping.
# Processed file already exists for HDFC_Bank_Ltd 120M. Skipping.
# Processed file already exists for HDFC_Bank_Ltd 15M. Skipping.
# Processed file already exists for HDFC_Bank_Ltd 180M. Skipping.
# Processed file already exists for HDFC_Bank_Ltd 2M. Skipping.
# Processed file already exists for HDFC_Bank_Ltd 20M. Skipping.
# Processed file already exists for HDFC_Bank_Ltd 240M. Skipping.
# Processed file already exists for HDFC_Bank_Ltd 3M. Skipping.
# Processed file already exists for HDFC_Bank_Ltd 30M. Skipping.
# Processed file already exists for HDFC_Bank_Ltd 45M. Skipping.
# Processed file already exists for HDFC_Bank_Ltd 5M. Skipping.
# Processed file already exists for HDFC_Bank_Ltd 60M. Skipping.
# Processed file already exists for HDFC_Life_Insurance_Company_Ltd 10M. Skipping.
# Processed file already exists for HDFC_Life_Insurance_Company_Ltd 120M. Skipping.
# Processed file already exists for HDFC_Life_Insurance_Company_Ltd 15M. Skipping.
# Processed file already exists for HDFC_Life_Insurance_Company_Ltd 180M. Skipping.
# Processed file already exists for HDFC_Life_Insurance_Company_Ltd 2M. Skipping.
# Processed file already exists for HDFC_Life_Insurance_Company_Ltd 20M. Skipping.
# Processed file already exists for HDFC_Life_Insurance_Company_Ltd 240M. Skipping.
# Processed file already exists for HDFC_Life_Insurance_Company_Ltd 3M. Skipping.
# Processed file already exists for HDFC_Life_Insurance_Company_Ltd 30M. Skipping.
# Processed file already exists for HDFC_Life_Insurance_Company_Ltd 45M. Skipping.
# Processed file already exists for HDFC_Life_Insurance_Company_Ltd 5M. Skipping.
# Processed file already exists for HDFC_Life_Insurance_Company_Ltd 60M. Skipping.
# Processed file already exists for Hero_MotoCorp_Ltd 10M. Skipping.
# Processed file already exists for Hero_MotoCorp_Ltd 120M. Skipping.
# Processed file already exists for Hero_MotoCorp_Ltd 15M. Skipping.
# Processed file already exists for Hero_MotoCorp_Ltd 180M. Skipping.
# Processed file already exists for Hero_MotoCorp_Ltd 2M. Skipping.
# Processed file already exists for Hero_MotoCorp_Ltd 20M. Skipping.
# Processed file already exists for Hero_MotoCorp_Ltd 240M. Skipping.
# Processed file already exists for Hero_MotoCorp_Ltd 3M. Skipping.
# Processed file already exists for Hero_MotoCorp_Ltd 30M. Skipping.
# Processed file already exists for Hero_MotoCorp_Ltd 45M. Skipping.
# Processed file already exists for Hero_MotoCorp_Ltd 5M. Skipping.
# Processed file already exists for Hero_MotoCorp_Ltd 60M. Skipping.
# Processed file already exists for Hindalco_Industries_Ltd 10M. Skipping.
# Processed file already exists for Hindalco_Industries_Ltd 120M. Skipping.
# Processed file already exists for Hindalco_Industries_Ltd 15M. Skipping.
# Processed file already exists for Hindalco_Industries_Ltd 180M. Skipping.
# Processed file already exists for Hindalco_Industries_Ltd 2M. Skipping.
# Processed file already exists for Hindalco_Industries_Ltd 20M. Skipping.
# Processed file already exists for Hindalco_Industries_Ltd 240M. Skipping.
# Processed file already exists for Hindalco_Industries_Ltd 3M. Skipping.
# Processed file already exists for Hindalco_Industries_Ltd 30M. Skipping.
# Processed file already exists for Hindalco_Industries_Ltd 45M. Skipping.
# Processed file already exists for Hindalco_Industries_Ltd 5M. Skipping.
# Processed file already exists for Hindalco_Industries_Ltd 60M. Skipping.
# Processed file already exists for Hindustan_Unilever_Ltd 10M. Skipping.
# Processed file already exists for Hindustan_Unilever_Ltd 120M. Skipping.
# Processed file already exists for Hindustan_Unilever_Ltd 15M. Skipping.
# Processed file already exists for Hindustan_Unilever_Ltd 180M. Skipping.
# Processed file already exists for Hindustan_Unilever_Ltd 2M. Skipping.
# Processed file already exists for Hindustan_Unilever_Ltd 20M. Skipping.
# Processed file already exists for Hindustan_Unilever_Ltd 240M. Skipping.
# Processed file already exists for Hindustan_Unilever_Ltd 3M. Skipping.
# Processed file already exists for Hindustan_Unilever_Ltd 30M. Skipping.
# Processed file already exists for Hindustan_Unilever_Ltd 45M. Skipping.
# Processed file already exists for Hindustan_Unilever_Ltd 5M. Skipping.
# Processed file already exists for Hindustan_Unilever_Ltd 60M. Skipping.
# Processed file already exists for ICICI_Bank_Ltd 10M. Skipping.
# Processed file already exists for ICICI_Bank_Ltd 120M. Skipping.
# Processed file already exists for ICICI_Bank_Ltd 15M. Skipping.
# Processed file already exists for ICICI_Bank_Ltd 180M. Skipping.
# Processed file already exists for ICICI_Bank_Ltd 2M. Skipping.
# Processed file already exists for ICICI_Bank_Ltd 20M. Skipping.
# Processed file already exists for ICICI_Bank_Ltd 240M. Skipping.
# Processed file already exists for ICICI_Bank_Ltd 3M. Skipping.
# Processed file already exists for ICICI_Bank_Ltd 30M. Skipping.
# Processed file already exists for ICICI_Bank_Ltd 45M. Skipping.
# Processed file already exists for ICICI_Bank_Ltd 5M. Skipping.
# Processed file already exists for ICICI_Bank_Ltd 60M. Skipping.
# Processed file already exists for Indian_Oil_Corporation_Ltd 10M. Skipping.
# Processed file already exists for Indian_Oil_Corporation_Ltd 120M. Skipping.
# Processed file already exists for Indian_Oil_Corporation_Ltd 15M. Skipping.
# Processed file already exists for Indian_Oil_Corporation_Ltd 180M. Skipping.
# Processed file already exists for Indian_Oil_Corporation_Ltd 2M. Skipping.
# Processed file already exists for Indian_Oil_Corporation_Ltd 20M. Skipping.
# Processed file already exists for Indian_Oil_Corporation_Ltd 240M. Skipping.
# Processed file already exists for Indian_Oil_Corporation_Ltd 3M. Skipping.
# Processed file already exists for Indian_Oil_Corporation_Ltd 30M. Skipping.
# Processed file already exists for Indian_Oil_Corporation_Ltd 45M. Skipping.
# Processed file already exists for Indian_Oil_Corporation_Ltd 5M. Skipping.
# Processed file already exists for Indian_Oil_Corporation_Ltd 60M. Skipping.
# Processed file already exists for IndusInd_Bank_Ltd 10M. Skipping.
# Processed file already exists for IndusInd_Bank_Ltd 120M. Skipping.
# Processed file already exists for IndusInd_Bank_Ltd 15M. Skipping.
# Processed file already exists for IndusInd_Bank_Ltd 180M. Skipping.
# Processed file already exists for IndusInd_Bank_Ltd 2M. Skipping.
# Processed file already exists for IndusInd_Bank_Ltd 20M. Skipping.
# Processed file already exists for IndusInd_Bank_Ltd 240M. Skipping.
# Processed file already exists for IndusInd_Bank_Ltd 3M. Skipping.
# Processed file already exists for IndusInd_Bank_Ltd 30M. Skipping.
# Processed file already exists for IndusInd_Bank_Ltd 45M. Skipping.
# Processed file already exists for IndusInd_Bank_Ltd 5M. Skipping.
# Processed file already exists for IndusInd_Bank_Ltd 60M. Skipping.
# Processed file already exists for Infosys_Ltd 10M. Skipping.
# Processed file already exists for Infosys_Ltd 120M. Skipping.
# Processed file already exists for Infosys_Ltd 15M. Skipping.
# Processed file already exists for Infosys_Ltd 180M. Skipping.
# Processed file already exists for Infosys_Ltd 2M. Skipping.
# Processed file already exists for Infosys_Ltd 20M. Skipping.
# Processed file already exists for Infosys_Ltd 240M. Skipping.
# Processed file already exists for Infosys_Ltd 3M. Skipping.
# Processed file already exists for Infosys_Ltd 30M. Skipping.
# Processed file already exists for Infosys_Ltd 45M. Skipping.
# Processed file already exists for Infosys_Ltd 5M. Skipping.
# Processed file already exists for Infosys_Ltd 60M. Skipping.
# Processed file already exists for JSW_Steel_Ltd 10M. Skipping.
# Processed file already exists for JSW_Steel_Ltd 120M. Skipping.
# Processed file already exists for JSW_Steel_Ltd 15M. Skipping.
# Processed file already exists for JSW_Steel_Ltd 180M. Skipping.
# Processed file already exists for JSW_Steel_Ltd 2M. Skipping.
# Processed file already exists for JSW_Steel_Ltd 20M. Skipping.
# Processed file already exists for JSW_Steel_Ltd 240M. Skipping.
# Processed file already exists for JSW_Steel_Ltd 3M. Skipping.
# Processed file already exists for JSW_Steel_Ltd 30M. Skipping.
# Processed file already exists for JSW_Steel_Ltd 45M. Skipping.
# Processed file already exists for JSW_Steel_Ltd 5M. Skipping.
# Processed file already exists for JSW_Steel_Ltd 60M. Skipping.
# Processed file already exists for Kotak_Mahindra_Bank_Ltd 10M. Skipping.
# Processed file already exists for Kotak_Mahindra_Bank_Ltd 120M. Skipping.
# Processed file already exists for Kotak_Mahindra_Bank_Ltd 15M. Skipping.
# Processed file already exists for Kotak_Mahindra_Bank_Ltd 180M. Skipping.
# Processed file already exists for Kotak_Mahindra_Bank_Ltd 2M. Skipping.
# Processed file already exists for Kotak_Mahindra_Bank_Ltd 20M. Skipping.
# Processed file already exists for Kotak_Mahindra_Bank_Ltd 240M. Skipping.
# Processed file already exists for Kotak_Mahindra_Bank_Ltd 3M. Skipping.
# Processed file already exists for Kotak_Mahindra_Bank_Ltd 30M. Skipping.
# Processed file already exists for Kotak_Mahindra_Bank_Ltd 45M. Skipping.
# Processed file already exists for Kotak_Mahindra_Bank_Ltd 5M. Skipping.
# Processed file already exists for Kotak_Mahindra_Bank_Ltd 60M. Skipping.
# Processed file already exists for Larsen__Toubro_Ltd 10M. Skipping.
# Processed file already exists for Larsen__Toubro_Ltd 120M. Skipping.
# Processed file already exists for Larsen__Toubro_Ltd 15M. Skipping.
# Processed file already exists for Larsen__Toubro_Ltd 180M. Skipping.
# Processed file already exists for Larsen__Toubro_Ltd 2M. Skipping.
# Processed file already exists for Larsen__Toubro_Ltd 20M. Skipping.
# Processed file already exists for Larsen__Toubro_Ltd 240M. Skipping.
# Processed file already exists for Larsen__Toubro_Ltd 3M. Skipping.
# Processed file already exists for Larsen__Toubro_Ltd 30M. Skipping.
# Processed file already exists for Larsen__Toubro_Ltd 45M. Skipping.
# Processed file already exists for Larsen__Toubro_Ltd 5M. Skipping.
# Processed file already exists for Larsen__Toubro_Ltd 60M. Skipping.
# Processed file already exists for Mahindra__Mahindra_Ltd 10M. Skipping.
# Processed file already exists for Mahindra__Mahindra_Ltd 120M. Skipping.
# Processed file already exists for Mahindra__Mahindra_Ltd 15M. Skipping.
# Processed file already exists for Mahindra__Mahindra_Ltd 180M. Skipping.
# Processed file already exists for Mahindra__Mahindra_Ltd 2M. Skipping.
# Processed file already exists for Mahindra__Mahindra_Ltd 20M. Skipping.
# Processed file already exists for Mahindra__Mahindra_Ltd 240M. Skipping.
# Processed file already exists for Mahindra__Mahindra_Ltd 3M. Skipping.
# Processed file already exists for Mahindra__Mahindra_Ltd 30M. Skipping.
# Processed file already exists for Mahindra__Mahindra_Ltd 45M. Skipping.
# Processed file already exists for Mahindra__Mahindra_Ltd 5M. Skipping.
# Processed file already exists for Mahindra__Mahindra_Ltd 60M. Skipping.
# Processed file already exists for Maruti_Suzuki_India_Ltd 10M. Skipping.
# Processed file already exists for Maruti_Suzuki_India_Ltd 120M. Skipping.
# Processed file already exists for Maruti_Suzuki_India_Ltd 15M. Skipping.
# Processed file already exists for Maruti_Suzuki_India_Ltd 180M. Skipping.
# Processed file already exists for Maruti_Suzuki_India_Ltd 2M. Skipping.
# Processed file already exists for Maruti_Suzuki_India_Ltd 20M. Skipping.
# Processed file already exists for Maruti_Suzuki_India_Ltd 240M. Skipping.
# Processed file already exists for Maruti_Suzuki_India_Ltd 3M. Skipping.
# Processed file already exists for Maruti_Suzuki_India_Ltd 30M. Skipping.
# Processed file already exists for Maruti_Suzuki_India_Ltd 45M. Skipping.
# Processed file already exists for Maruti_Suzuki_India_Ltd 5M. Skipping.
# Processed file already exists for Maruti_Suzuki_India_Ltd 60M. Skipping.
# Processed file already exists for Nestle_India_Ltd 10M. Skipping.
# Processed file already exists for Nestle_India_Ltd 120M. Skipping.
# Processed file already exists for Nestle_India_Ltd 15M. Skipping.
# Processed file already exists for Nestle_India_Ltd 180M. Skipping.
# Processed file already exists for Nestle_India_Ltd 2M. Skipping.
# Processed file already exists for Nestle_India_Ltd 20M. Skipping.
# Processed file already exists for Nestle_India_Ltd 240M. Skipping.
# Processed file already exists for Nestle_India_Ltd 3M. Skipping.
# Processed file already exists for Nestle_India_Ltd 30M. Skipping.
# Processed file already exists for Nestle_India_Ltd 45M. Skipping.
# Processed file already exists for Nestle_India_Ltd 5M. Skipping.
# Processed file already exists for Nestle_India_Ltd 60M. Skipping.
# Processed file already exists for Nifty 10M. Skipping.
# Processed file already exists for Nifty 120M. Skipping.
# Processed file already exists for Nifty 15M. Skipping.
# Processed file already exists for Nifty 180M. Skipping.
# Processed file already exists for Nifty 2M. Skipping.
# Processed file already exists for Nifty 20M. Skipping.
# Processed file already exists for Nifty 240M. Skipping.
# Processed file already exists for Nifty 3M. Skipping.
# Processed file already exists for Nifty 30M. Skipping.
# Processed file already exists for Nifty 45M. Skipping.
# Processed file already exists for Nifty 5M. Skipping.
# Processed file already exists for Nifty 60M. Skipping.
# Processed file already exists for NTPC_Ltd 10M. Skipping.
# Processed file already exists for NTPC_Ltd 120M. Skipping.
# Processed file already exists for NTPC_Ltd 15M. Skipping.
# Processed file already exists for NTPC_Ltd 180M. Skipping.
# Processed file already exists for NTPC_Ltd 2M. Skipping.
# Processed file already exists for NTPC_Ltd 20M. Skipping.
# Processed file already exists for NTPC_Ltd 240M. Skipping.
# Processed file already exists for NTPC_Ltd 3M. Skipping.
# Processed file already exists for NTPC_Ltd 30M. Skipping.
# Processed file already exists for NTPC_Ltd 45M. Skipping.
# Processed file already exists for NTPC_Ltd 5M. Skipping.
# Processed file already exists for NTPC_Ltd 60M. Skipping.
# Processed file already exists for ONGC_Ltd 10M. Skipping.
# Processed file already exists for ONGC_Ltd 120M. Skipping.
# Processed file already exists for ONGC_Ltd 15M. Skipping.
# Processed file already exists for ONGC_Ltd 180M. Skipping.
# Processed file already exists for ONGC_Ltd 2M. Skipping.
# Processed file already exists for ONGC_Ltd 20M. Skipping.
# Processed file already exists for ONGC_Ltd 240M. Skipping.
# Processed file already exists for ONGC_Ltd 3M. Skipping.
# Processed file already exists for ONGC_Ltd 30M. Skipping.
# Processed file already exists for ONGC_Ltd 45M. Skipping.
# Processed file already exists for ONGC_Ltd 5M. Skipping.
# Processed file already exists for ONGC_Ltd 60M. Skipping.
# Processed file already exists for Power_Grid_Corporation_of_India_Ltd 10M. Skipping.
# Processed file already exists for Power_Grid_Corporation_of_India_Ltd 120M. Skipping.
# Processed file already exists for Power_Grid_Corporation_of_India_Ltd 15M. Skipping.
# Processed file already exists for Power_Grid_Corporation_of_India_Ltd 180M. Skipping.
# Processed file already exists for Power_Grid_Corporation_of_India_Ltd 2M. Skipping.
# Processed file already exists for Power_Grid_Corporation_of_India_Ltd 20M. Skipping.
# Processed file already exists for Power_Grid_Corporation_of_India_Ltd 240M. Skipping.
# Processed file already exists for Power_Grid_Corporation_of_India_Ltd 3M. Skipping.
# Processed file already exists for Power_Grid_Corporation_of_India_Ltd 30M. Skipping.
# Processed file already exists for Power_Grid_Corporation_of_India_Ltd 45M. Skipping.
# Processed file already exists for Power_Grid_Corporation_of_India_Ltd 5M. Skipping.
# Processed file already exists for Power_Grid_Corporation_of_India_Ltd 60M. Skipping.
# Processed file already exists for Reliance_Industries_Ltd 10M. Skipping.
# Processed file already exists for Reliance_Industries_Ltd 120M. Skipping.
# Processed file already exists for Reliance_Industries_Ltd 15M. Skipping.
# Processed file already exists for Reliance_Industries_Ltd 180M. Skipping.
# Processed file already exists for Reliance_Industries_Ltd 2M. Skipping.
# Processed file already exists for Reliance_Industries_Ltd 20M. Skipping.
# Processed file already exists for Reliance_Industries_Ltd 240M. Skipping.
# Processed file already exists for Reliance_Industries_Ltd 3M. Skipping.
# Processed file already exists for Reliance_Industries_Ltd 30M. Skipping.
# Processed file already exists for Reliance_Industries_Ltd 45M. Skipping.
# Processed file already exists for Reliance_Industries_Ltd 5M. Skipping.
# Processed file already exists for Reliance_Industries_Ltd 60M. Skipping.
# Processed file already exists for SBI_Life_Insurance_Company_Ltd 10M. Skipping.
# Processed file already exists for SBI_Life_Insurance_Company_Ltd 120M. Skipping.
# Processed file already exists for SBI_Life_Insurance_Company_Ltd 15M. Skipping.
# Processed file already exists for SBI_Life_Insurance_Company_Ltd 180M. Skipping.
# Processed file already exists for SBI_Life_Insurance_Company_Ltd 2M. Skipping.
# Processed file already exists for SBI_Life_Insurance_Company_Ltd 20M. Skipping.
# Processed file already exists for SBI_Life_Insurance_Company_Ltd 240M. Skipping.
# Processed file already exists for SBI_Life_Insurance_Company_Ltd 3M. Skipping.
# Processed file already exists for SBI_Life_Insurance_Company_Ltd 30M. Skipping.
# Processed file already exists for SBI_Life_Insurance_Company_Ltd 45M. Skipping.
# Processed file already exists for SBI_Life_Insurance_Company_Ltd 5M. Skipping.
# Processed file already exists for SBI_Life_Insurance_Company_Ltd 60M. Skipping.
# Processed file already exists for Sensex 10M. Skipping.
# Processed file already exists for Sensex 120M. Skipping.
# Processed file already exists for Sensex 15M. Skipping.
# Processed file already exists for Sensex 180M. Skipping.
# Processed file already exists for Sensex 2M. Skipping.
# Processed file already exists for Sensex 20M. Skipping.
# Processed file already exists for Sensex 240M. Skipping.
# Processed file already exists for Sensex 3M. Skipping.
# Processed file already exists for Sensex 30M. Skipping.
# Processed file already exists for Sensex 45M. Skipping.
# Processed file already exists for Sensex 5M. Skipping.
# Processed file already exists for Sensex 60M. Skipping.
# Processed file already exists for State_Bank_of_India_(SBI)_Ltd 10M. Skipping.
# Processed file already exists for State_Bank_of_India_(SBI)_Ltd 120M. Skipping.
# Processed file already exists for State_Bank_of_India_(SBI)_Ltd 15M. Skipping.
# Processed file already exists for State_Bank_of_India_(SBI)_Ltd 180M. Skipping.
# Processed file already exists for State_Bank_of_India_(SBI)_Ltd 2M. Skipping.
# Processed file already exists for State_Bank_of_India_(SBI)_Ltd 20M. Skipping.
# Processed file already exists for State_Bank_of_India_(SBI)_Ltd 240M. Skipping.
# Processed file already exists for State_Bank_of_India_(SBI)_Ltd 3M. Skipping.
# Processed file already exists for State_Bank_of_India_(SBI)_Ltd 30M. Skipping.
# Processed file already exists for State_Bank_of_India_(SBI)_Ltd 45M. Skipping.
# Processed file already exists for State_Bank_of_India_(SBI)_Ltd 5M. Skipping.
# Processed file already exists for State_Bank_of_India_(SBI)_Ltd 60M. Skipping.
# Processed file already exists for Sun_Pharmaceutical_Industries_Ltd 10M. Skipping.
# Processed file already exists for Sun_Pharmaceutical_Industries_Ltd 120M. Skipping.
# Processed file already exists for Sun_Pharmaceutical_Industries_Ltd 15M. Skipping.
# Processed file already exists for Sun_Pharmaceutical_Industries_Ltd 180M. Skipping.
# Processed file already exists for Sun_Pharmaceutical_Industries_Ltd 2M. Skipping.
# Processed file already exists for Sun_Pharmaceutical_Industries_Ltd 20M. Skipping.
# Processed file already exists for Sun_Pharmaceutical_Industries_Ltd 240M. Skipping.
# Processed file already exists for Sun_Pharmaceutical_Industries_Ltd 3M. Skipping.
# Processed file already exists for Sun_Pharmaceutical_Industries_Ltd 30M. Skipping.
# Processed file already exists for Sun_Pharmaceutical_Industries_Ltd 45M. Skipping.
# Processed file already exists for Sun_Pharmaceutical_Industries_Ltd 5M. Skipping.
# Processed file already exists for Sun_Pharmaceutical_Industries_Ltd 60M. Skipping.
# Processed file already exists for Tata_Consumer_Products_Ltd 10M. Skipping.
# Processed file already exists for Tata_Consumer_Products_Ltd 120M. Skipping.
# Processed file already exists for Tata_Consumer_Products_Ltd 15M. Skipping.
# Processed file already exists for Tata_Consumer_Products_Ltd 180M. Skipping.
# Processed file already exists for Tata_Consumer_Products_Ltd 2M. Skipping.
# Processed file already exists for Tata_Consumer_Products_Ltd 20M. Skipping.
# Processed file already exists for Tata_Consumer_Products_Ltd 240M. Skipping.
# Processed file already exists for Tata_Consumer_Products_Ltd 3M. Skipping.
# Processed file already exists for Tata_Consumer_Products_Ltd 30M. Skipping.
# Processed file already exists for Tata_Consumer_Products_Ltd 45M. Skipping.
# Processed file already exists for Tata_Consumer_Products_Ltd 5M. Skipping.
# Processed file already exists for Tata_Consumer_Products_Ltd 60M. Skipping.
# Processed file already exists for Tata_Motors_Ltd 10M. Skipping.
# Processed file already exists for Tata_Motors_Ltd 120M. Skipping.
# Processed file already exists for Tata_Motors_Ltd 15M. Skipping.
# Processed file already exists for Tata_Motors_Ltd 180M. Skipping.
# Processed file already exists for Tata_Motors_Ltd 2M. Skipping.
# Processed file already exists for Tata_Motors_Ltd 20M. Skipping.
# Processed file already exists for Tata_Motors_Ltd 240M. Skipping.
# Processed file already exists for Tata_Motors_Ltd 3M. Skipping.
# Processed file already exists for Tata_Motors_Ltd 30M. Skipping.
# Processed file already exists for Tata_Motors_Ltd 45M. Skipping.
# Processed file already exists for Tata_Motors_Ltd 5M. Skipping.
# Processed file already exists for Tata_Motors_Ltd 60M. Skipping.
# Processed file already exists for Tata_Steel_Ltd 10M. Skipping.
# Processed file already exists for Tata_Steel_Ltd 120M. Skipping.
# Processed file already exists for Tata_Steel_Ltd 15M. Skipping.
# Processed file already exists for Tata_Steel_Ltd 180M. Skipping.
# Processed file already exists for Tata_Steel_Ltd 2M. Skipping.
# Processed file already exists for Tata_Steel_Ltd 20M. Skipping.
# Processed file already exists for Tata_Steel_Ltd 240M. Skipping.
# Processed file already exists for Tata_Steel_Ltd 3M. Skipping.
# Processed file already exists for Tata_Steel_Ltd 30M. Skipping.
# Processed file already exists for Tata_Steel_Ltd 45M. Skipping.
# Processed file already exists for Tata_Steel_Ltd 5M. Skipping.
# Processed file already exists for Tata_Steel_Ltd 60M. Skipping.
# Processed file already exists for TCS_Ltd 10M. Skipping.
# Processed file already exists for TCS_Ltd 120M. Skipping.
# Processed file already exists for TCS_Ltd 15M. Skipping.
# Processed file already exists for TCS_Ltd 180M. Skipping.
# Processed file already exists for TCS_Ltd 2M. Skipping.
# Processed file already exists for TCS_Ltd 20M. Skipping.
# Processed file already exists for TCS_Ltd 240M. Skipping.
# Processed file already exists for TCS_Ltd 3M. Skipping.
# Processed file already exists for TCS_Ltd 30M. Skipping.
# Processed file already exists for TCS_Ltd 45M. Skipping.
# Processed file already exists for TCS_Ltd 5M. Skipping.
# Processed file already exists for TCS_Ltd 60M. Skipping.
# Processed file already exists for Tech_Mahindra_Ltd 10M. Skipping.
# Processed file already exists for Tech_Mahindra_Ltd 120M. Skipping.
# Processed file already exists for Tech_Mahindra_Ltd 15M. Skipping.
# Processed file already exists for Tech_Mahindra_Ltd 180M. Skipping.
# Processed file already exists for Tech_Mahindra_Ltd 2M. Skipping.
# Processed file already exists for Tech_Mahindra_Ltd 20M. Skipping.
# Processed file already exists for Tech_Mahindra_Ltd 240M. Skipping.
# Processed file already exists for Tech_Mahindra_Ltd 3M. Skipping.
# Processed file already exists for Tech_Mahindra_Ltd 30M. Skipping.
# Processed file already exists for Tech_Mahindra_Ltd 45M. Skipping.
# Processed file already exists for Tech_Mahindra_Ltd 5M. Skipping.
# Processed file already exists for Tech_Mahindra_Ltd 60M. Skipping.
# Processed file already exists for Titan_Company_Ltd 10M. Skipping.
# Processed file already exists for Titan_Company_Ltd 120M. Skipping.
# Processed file already exists for Titan_Company_Ltd 15M. Skipping.
# Processed file already exists for Titan_Company_Ltd 180M. Skipping.
# Processed file already exists for Titan_Company_Ltd 2M. Skipping.
# Processed file already exists for Titan_Company_Ltd 20M. Skipping.
# Processed file already exists for Titan_Company_Ltd 240M. Skipping.
# Processed file already exists for Titan_Company_Ltd 3M. Skipping.
# Processed file already exists for Titan_Company_Ltd 30M. Skipping.
# Processed file already exists for Titan_Company_Ltd 45M. Skipping.
# Processed file already exists for Titan_Company_Ltd 5M. Skipping.
# Processed file already exists for Titan_Company_Ltd 60M. Skipping.
# Processed file already exists for Trent_Ltd 10M. Skipping.
# Processed file already exists for Trent_Ltd 120M. Skipping.
# Processed file already exists for Trent_Ltd 15M. Skipping.
# Processed file already exists for Trent_Ltd 180M. Skipping.
# Processed file already exists for Trent_Ltd 2M. Skipping.
# Processed file already exists for Trent_Ltd 20M. Skipping.
# Processed file already exists for Trent_Ltd 240M. Skipping.
# Processed file already exists for Trent_Ltd 3M. Skipping.
# Processed file already exists for Trent_Ltd 30M. Skipping.
# Processed file already exists for Trent_Ltd 45M. Skipping.
# Processed file already exists for Trent_Ltd 5M. Skipping.
# Processed file already exists for Trent_Ltd 60M. Skipping.
# Processed file already exists for UltraTech_Cement_Ltd 10M. Skipping.
# Processed file already exists for UltraTech_Cement_Ltd 120M. Skipping.
# Processed file already exists for UltraTech_Cement_Ltd 15M. Skipping.
# Processed file already exists for UltraTech_Cement_Ltd 180M. Skipping.
# Processed file already exists for UltraTech_Cement_Ltd 2M. Skipping.
# Processed file already exists for UltraTech_Cement_Ltd 20M. Skipping.
# Processed file already exists for UltraTech_Cement_Ltd 240M. Skipping.
# Processed file already exists for UltraTech_Cement_Ltd 3M. Skipping.
# Processed file already exists for UltraTech_Cement_Ltd 30M. Skipping.
# Processed file already exists for UltraTech_Cement_Ltd 45M. Skipping.
# Processed file already exists for UltraTech_Cement_Ltd 5M. Skipping.
# Processed file already exists for UltraTech_Cement_Ltd 60M. Skipping.
# Processed file already exists for Wipro_Ltd 10M. Skipping.
# Processed file already exists for Wipro_Ltd 120M. Skipping.
# Processed file already exists for Wipro_Ltd 15M. Skipping.
# Processed file already exists for Wipro_Ltd 180M. Skipping.
# Processed file already exists for Wipro_Ltd 2M. Skipping.
# Processed file already exists for Wipro_Ltd 20M. Skipping.
# Processed file already exists for Wipro_Ltd 240M. Skipping.
# Processed file already exists for Wipro_Ltd 3M. Skipping.
# Processed file already exists for Wipro_Ltd 30M. Skipping.
# Processed file already exists for Wipro_Ltd 45M. Skipping.
# Processed file already exists for Wipro_Ltd 5M. Skipping.
# Processed file already exists for Wipro_Ltd 60M. Skipping.

# %%
# Sort by timeframe descending, then by instrument name alphabetically
temp_data_list.sort(key=lambda x: (-x[1], x[0]))

instruments_config = []
for i, (instrument_name, timeframe, csv_path) in enumerate(temp_data_list):
    lot_size = index_mapping[instrument_name]["quantity"]
    dynamic_name = f"{instrument_name.upper()}_{timeframe}M"

    instruments_config.append({
        "name": dynamic_name,
        "file_path": csv_path,
        "lot_size": lot_size,
        "transaction_cost": 20.0  # default brokerage
    })

# %%
# Check if TPU is available using torch_xla.
try:
    import torch_xla.core.xla_model as xm
    # If the TPU device can be retrieved, assume TPU is available.
    use_tpu = True if xm.xla_device() is not None else False
except ImportError:
    use_tpu = False

# Now build the main config dictionary
config = {
    "instruments": instruments_config,
    "window_size": 30,
    "initial_capital": 500000,
    "unrealized_pnl_weight": 0.1,
    "time_penalty_weight": 0.001,
    "volatility_penalty_weight": 0.05,
    "target_bonus": 0.5,
    "sl_penalty": 0.5,
    "misalignment_penalty": 0.5,
    "missed_opportunity_penalty": 0.05,
    "target_proximity_weight": 0.2,
    "sl_proximity_weight": 0.05,
    "max_step_reward": 5,

    # Trailing Stop Parameters
    "enable_trailing_sl": True,
    "trailing_sl_mode": "factor",   # can be "fixed", "percentage", or "factor"
    "trailing_sl_amount": 20.0,
    "trailing_sl_percent": 0.01,
    "trailing_factor": 0.5,

    "initial_cap_multiplier": 10,   # factor for initial capital
    "normalize_data": True,         # whether to normalize data for the agent's observation
    "use_tpu": use_tpu              # flag set based on TPU availability
}

# Margin constants
MARGIN_FRACTION = 0.05
MARGIN_CALL_THRESHOLD = 0.5

# %%
# Print a summary of the dynamically created instruments
print("Final Config Instruments:")
for inst in config["instruments"]:
    print(f"{inst['name']}: lot_size={inst['lot_size']}, brokerage={inst['transaction_cost']}")
# Out:
# Final Config Instruments:
# ADANI_ENTERPRISES_LTD_240M: lot_size=10, brokerage=20.0
# ADANI_PORTS__SEZ_LTD_240M: lot_size=10, brokerage=20.0
# APOLLO_HOSPITALS_ENTERPRISE_LTD_240M: lot_size=10, brokerage=20.0
# ASIAN_PAINTS_LTD_240M: lot_size=10, brokerage=20.0
# AXIS_BANK_LTD_240M: lot_size=10, brokerage=20.0
# BPCL_LTD_240M: lot_size=10, brokerage=20.0
# BAJAJ_AUTO_LTD_240M: lot_size=10, brokerage=20.0
# BAJAJ_FINANCE_LTD_240M: lot_size=10, brokerage=20.0
# BAJAJ_FINSERV_LTD_240M: lot_size=10, brokerage=20.0
# BANK_NIFTY_240M: lot_size=30, brokerage=20.0
# BANKEX_240M: lot_size=15, brokerage=20.0
# BHARAT_ELECTRONICS_LTD_240M: lot_size=10, brokerage=20.0
# BHARTI_AIRTEL_LTD_240M: lot_size=10, brokerage=20.0
# CIPLA_LTD_240M: lot_size=10, brokerage=20.0
# COAL_INDIA_LTD_240M: lot_size=10, brokerage=20.0
# DR_REDDYS_LABORATORIES_LTD_240M: lot_size=10, brokerage=20.0
# EICHER_MOTORS_LTD_240M: lot_size=10, brokerage=20.0
# FINNIFTY_240M: lot_size=40, brokerage=20.0
# GRASIM_INDUSTRIES_LTD_240M: lot_size=10, brokerage=20.0
# HCL_TECHNOLOGIES_LTD_240M: lot_size=10, brokerage=20.0
# HDFC_BANK_LTD_240M: lot_size=10, brokerage=20.0
# HDFC_LIFE_INSURANCE_COMPANY_LTD_240M: lot_size=10, brokerage=20.0
# HERO_MOTOCORP_LTD_240M: lot_size=10, brokerage=20.0
# HINDALCO_INDUSTRIES_LTD_240M: lot_size=10, brokerage=20.0
# HINDUSTAN_UNILEVER_LTD_240M: lot_size=10, brokerage=20.0
# ICICI_BANK_LTD_240M: lot_size=10, brokerage=20.0
# INDIAN_OIL_CORPORATION_LTD_240M: lot_size=10, brokerage=20.0
# INDUSIND_BANK_LTD_240M: lot_size=10, brokerage=20.0
# INFOSYS_LTD_240M: lot_size=10, brokerage=20.0
# JSW_STEEL_LTD_240M: lot_size=10, brokerage=20.0
# KOTAK_MAHINDRA_BANK_LTD_240M: lot_size=10, brokerage=20.0
# LARSEN__TOUBRO_LTD_240M: lot_size=10, brokerage=20.0
# MAHINDRA__MAHINDRA_LTD_240M: lot_size=10, brokerage=20.0
# MARUTI_SUZUKI_INDIA_LTD_240M: lot_size=10, brokerage=20.0
# NTPC_LTD_240M: lot_size=10, brokerage=20.0
# NESTLE_INDIA_LTD_240M: lot_size=10, brokerage=20.0
# NIFTY_240M: lot_size=75, brokerage=20.0
# ONGC_LTD_240M: lot_size=10, brokerage=20.0
# POWER_GRID_CORPORATION_OF_INDIA_LTD_240M: lot_size=10, brokerage=20.0
# RELIANCE_INDUSTRIES_LTD_240M: lot_size=10, brokerage=20.0
# SBI_LIFE_INSURANCE_COMPANY_LTD_240M: lot_size=10, brokerage=20.0
# SENSEX_240M: lot_size=20, brokerage=20.0
# STATE_BANK_OF_INDIA_(SBI)_LTD_240M: lot_size=10, brokerage=20.0
# SUN_PHARMACEUTICAL_INDUSTRIES_LTD_240M: lot_size=10, brokerage=20.0
# TCS_LTD_240M: lot_size=10, brokerage=20.0
# TATA_CONSUMER_PRODUCTS_LTD_240M: lot_size=10, brokerage=20.0
# TATA_MOTORS_LTD_240M: lot_size=10, brokerage=20.0
# TATA_STEEL_LTD_240M: lot_size=10, brokerage=20.0
# TECH_MAHINDRA_LTD_240M: lot_size=10, brokerage=20.0
# TITAN_COMPANY_LTD_240M: lot_size=10, brokerage=20.0
# TRENT_LTD_240M: lot_size=10, brokerage=20.0
# ULTRATECH_CEMENT_LTD_240M: lot_size=10, brokerage=20.0
# WIPRO_LTD_240M: lot_size=10, brokerage=20.0
# ADANI_ENTERPRISES_LTD_180M: lot_size=10, brokerage=20.0
# ADANI_PORTS__SEZ_LTD_180M: lot_size=10, brokerage=20.0
# APOLLO_HOSPITALS_ENTERPRISE_LTD_180M: lot_size=10, brokerage=20.0
# ASIAN_PAINTS_LTD_180M: lot_size=10, brokerage=20.0
# AXIS_BANK_LTD_180M: lot_size=10, brokerage=20.0
# BPCL_LTD_180M: lot_size=10, brokerage=20.0
# BAJAJ_AUTO_LTD_180M: lot_size=10, brokerage=20.0
# BAJAJ_FINANCE_LTD_180M: lot_size=10, brokerage=20.0
# BAJAJ_FINSERV_LTD_180M: lot_size=10, brokerage=20.0
# BANK_NIFTY_180M: lot_size=30, brokerage=20.0
# BANKEX_180M: lot_size=15, brokerage=20.0
# BHARAT_ELECTRONICS_LTD_180M: lot_size=10, brokerage=20.0
# BHARTI_AIRTEL_LTD_180M: lot_size=10, brokerage=20.0
# CIPLA_LTD_180M: lot_size=10, brokerage=20.0
# COAL_INDIA_LTD_180M: lot_size=10, brokerage=20.0
# DR_REDDYS_LABORATORIES_LTD_180M: lot_size=10, brokerage=20.0
# EICHER_MOTORS_LTD_180M: lot_size=10, brokerage=20.0
# FINNIFTY_180M: lot_size=40, brokerage=20.0
# GRASIM_INDUSTRIES_LTD_180M: lot_size=10, brokerage=20.0
# HCL_TECHNOLOGIES_LTD_180M: lot_size=10, brokerage=20.0
# HDFC_BANK_LTD_180M: lot_size=10, brokerage=20.0
# HDFC_LIFE_INSURANCE_COMPANY_LTD_180M: lot_size=10, brokerage=20.0
# HERO_MOTOCORP_LTD_180M: lot_size=10, brokerage=20.0
# HINDALCO_INDUSTRIES_LTD_180M: lot_size=10, brokerage=20.0
# HINDUSTAN_UNILEVER_LTD_180M: lot_size=10, brokerage=20.0
# ICICI_BANK_LTD_180M: lot_size=10, brokerage=20.0
# INDIAN_OIL_CORPORATION_LTD_180M: lot_size=10, brokerage=20.0
# INDUSIND_BANK_LTD_180M: lot_size=10, brokerage=20.0
# INFOSYS_LTD_180M: lot_size=10, brokerage=20.0
# JSW_STEEL_LTD_180M: lot_size=10, brokerage=20.0
# KOTAK_MAHINDRA_BANK_LTD_180M: lot_size=10, brokerage=20.0
# LARSEN__TOUBRO_LTD_180M: lot_size=10, brokerage=20.0
# MAHINDRA__MAHINDRA_LTD_180M: lot_size=10, brokerage=20.0
# MARUTI_SUZUKI_INDIA_LTD_180M: lot_size=10, brokerage=20.0
# NTPC_LTD_180M: lot_size=10, brokerage=20.0
# NESTLE_INDIA_LTD_180M: lot_size=10, brokerage=20.0
# NIFTY_180M: lot_size=75, brokerage=20.0
# ONGC_LTD_180M: lot_size=10, brokerage=20.0
# POWER_GRID_CORPORATION_OF_INDIA_LTD_180M: lot_size=10, brokerage=20.0
# RELIANCE_INDUSTRIES_LTD_180M: lot_size=10, brokerage=20.0
# SBI_LIFE_INSURANCE_COMPANY_LTD_180M: lot_size=10, brokerage=20.0
# SENSEX_180M: lot_size=20, brokerage=20.0
# STATE_BANK_OF_INDIA_(SBI)_LTD_180M: lot_size=10, brokerage=20.0
# SUN_PHARMACEUTICAL_INDUSTRIES_LTD_180M: lot_size=10, brokerage=20.0
# TCS_LTD_180M: lot_size=10, brokerage=20.0
# TATA_CONSUMER_PRODUCTS_LTD_180M: lot_size=10, brokerage=20.0
# TATA_MOTORS_LTD_180M: lot_size=10, brokerage=20.0
# TATA_STEEL_LTD_180M: lot_size=10, brokerage=20.0
# TECH_MAHINDRA_LTD_180M: lot_size=10, brokerage=20.0
# TITAN_COMPANY_LTD_180M: lot_size=10, brokerage=20.0
# TRENT_LTD_180M: lot_size=10, brokerage=20.0
# ULTRATECH_CEMENT_LTD_180M: lot_size=10, brokerage=20.0
# WIPRO_LTD_180M: lot_size=10, brokerage=20.0
# ADANI_ENTERPRISES_LTD_120M: lot_size=10, brokerage=20.0
# ADANI_PORTS__SEZ_LTD_120M: lot_size=10, brokerage=20.0
# APOLLO_HOSPITALS_ENTERPRISE_LTD_120M: lot_size=10, brokerage=20.0
# ASIAN_PAINTS_LTD_120M: lot_size=10, brokerage=20.0
# AXIS_BANK_LTD_120M: lot_size=10, brokerage=20.0
# BPCL_LTD_120M: lot_size=10, brokerage=20.0
# BAJAJ_AUTO_LTD_120M: lot_size=10, brokerage=20.0
# BAJAJ_FINANCE_LTD_120M: lot_size=10, brokerage=20.0
# BAJAJ_FINSERV_LTD_120M: lot_size=10, brokerage=20.0
# BANK_NIFTY_120M: lot_size=30, brokerage=20.0
# BANKEX_120M: lot_size=15, brokerage=20.0
# BHARAT_ELECTRONICS_LTD_120M: lot_size=10, brokerage=20.0
# BHARTI_AIRTEL_LTD_120M: lot_size=10, brokerage=20.0
# CIPLA_LTD_120M: lot_size=10, brokerage=20.0
# COAL_INDIA_LTD_120M: lot_size=10, brokerage=20.0
# DR_REDDYS_LABORATORIES_LTD_120M: lot_size=10, brokerage=20.0
# EICHER_MOTORS_LTD_120M: lot_size=10, brokerage=20.0
# FINNIFTY_120M: lot_size=40, brokerage=20.0
# GRASIM_INDUSTRIES_LTD_120M: lot_size=10, brokerage=20.0
# HCL_TECHNOLOGIES_LTD_120M: lot_size=10, brokerage=20.0
# HDFC_BANK_LTD_120M: lot_size=10, brokerage=20.0
# HDFC_LIFE_INSURANCE_COMPANY_LTD_120M: lot_size=10, brokerage=20.0
# HERO_MOTOCORP_LTD_120M: lot_size=10, brokerage=20.0
# HINDALCO_INDUSTRIES_LTD_120M: lot_size=10, brokerage=20.0
# HINDUSTAN_UNILEVER_LTD_120M: lot_size=10, brokerage=20.0
# ICICI_BANK_LTD_120M: lot_size=10, brokerage=20.0
# INDIAN_OIL_CORPORATION_LTD_120M: lot_size=10, brokerage=20.0
# INDUSIND_BANK_LTD_120M: lot_size=10, brokerage=20.0
# INFOSYS_LTD_120M: lot_size=10, brokerage=20.0
# JSW_STEEL_LTD_120M: lot_size=10, brokerage=20.0
# KOTAK_MAHINDRA_BANK_LTD_120M: lot_size=10, brokerage=20.0
# LARSEN__TOUBRO_LTD_120M: lot_size=10, brokerage=20.0
# MAHINDRA__MAHINDRA_LTD_120M: lot_size=10, brokerage=20.0
# MARUTI_SUZUKI_INDIA_LTD_120M: lot_size=10, brokerage=20.0
# NTPC_LTD_120M: lot_size=10, brokerage=20.0
# NESTLE_INDIA_LTD_120M: lot_size=10, brokerage=20.0
# NIFTY_120M: lot_size=75, brokerage=20.0
# ONGC_LTD_120M: lot_size=10, brokerage=20.0
# POWER_GRID_CORPORATION_OF_INDIA_LTD_120M: lot_size=10, brokerage=20.0
# RELIANCE_INDUSTRIES_LTD_120M: lot_size=10, brokerage=20.0
# SBI_LIFE_INSURANCE_COMPANY_LTD_120M: lot_size=10, brokerage=20.0
# SENSEX_120M: lot_size=20, brokerage=20.0
# STATE_BANK_OF_INDIA_(SBI)_LTD_120M: lot_size=10, brokerage=20.0
# SUN_PHARMACEUTICAL_INDUSTRIES_LTD_120M: lot_size=10, brokerage=20.0
# TCS_LTD_120M: lot_size=10, brokerage=20.0
# TATA_CONSUMER_PRODUCTS_LTD_120M: lot_size=10, brokerage=20.0
# TATA_MOTORS_LTD_120M: lot_size=10, brokerage=20.0
# TATA_STEEL_LTD_120M: lot_size=10, brokerage=20.0
# TECH_MAHINDRA_LTD_120M: lot_size=10, brokerage=20.0
# TITAN_COMPANY_LTD_120M: lot_size=10, brokerage=20.0
# TRENT_LTD_120M: lot_size=10, brokerage=20.0
# ULTRATECH_CEMENT_LTD_120M: lot_size=10, brokerage=20.0
# WIPRO_LTD_120M: lot_size=10, brokerage=20.0
# ADANI_ENTERPRISES_LTD_60M: lot_size=10, brokerage=20.0
# ADANI_PORTS__SEZ_LTD_60M: lot_size=10, brokerage=20.0
# APOLLO_HOSPITALS_ENTERPRISE_LTD_60M: lot_size=10, brokerage=20.0
# ASIAN_PAINTS_LTD_60M: lot_size=10, brokerage=20.0
# AXIS_BANK_LTD_60M: lot_size=10, brokerage=20.0
# BPCL_LTD_60M: lot_size=10, brokerage=20.0
# BAJAJ_AUTO_LTD_60M: lot_size=10, brokerage=20.0
# BAJAJ_FINANCE_LTD_60M: lot_size=10, brokerage=20.0
# BAJAJ_FINSERV_LTD_60M: lot_size=10, brokerage=20.0
# BANK_NIFTY_60M: lot_size=30, brokerage=20.0
# BANKEX_60M: lot_size=15, brokerage=20.0
# BHARAT_ELECTRONICS_LTD_60M: lot_size=10, brokerage=20.0
# BHARTI_AIRTEL_LTD_60M: lot_size=10, brokerage=20.0
# CIPLA_LTD_60M: lot_size=10, brokerage=20.0
# COAL_INDIA_LTD_60M: lot_size=10, brokerage=20.0
# DR_REDDYS_LABORATORIES_LTD_60M: lot_size=10, brokerage=20.0
# EICHER_MOTORS_LTD_60M: lot_size=10, brokerage=20.0
# FINNIFTY_60M: lot_size=40, brokerage=20.0
# GRASIM_INDUSTRIES_LTD_60M: lot_size=10, brokerage=20.0
# HCL_TECHNOLOGIES_LTD_60M: lot_size=10, brokerage=20.0
# HDFC_BANK_LTD_60M: lot_size=10, brokerage=20.0
# HDFC_LIFE_INSURANCE_COMPANY_LTD_60M: lot_size=10, brokerage=20.0
# HERO_MOTOCORP_LTD_60M: lot_size=10, brokerage=20.0
# HINDALCO_INDUSTRIES_LTD_60M: lot_size=10, brokerage=20.0
# HINDUSTAN_UNILEVER_LTD_60M: lot_size=10, brokerage=20.0
# ICICI_BANK_LTD_60M: lot_size=10, brokerage=20.0
# INDIAN_OIL_CORPORATION_LTD_60M: lot_size=10, brokerage=20.0
# INDUSIND_BANK_LTD_60M: lot_size=10, brokerage=20.0
# INFOSYS_LTD_60M: lot_size=10, brokerage=20.0
# JSW_STEEL_LTD_60M: lot_size=10, brokerage=20.0
# KOTAK_MAHINDRA_BANK_LTD_60M: lot_size=10, brokerage=20.0
# LARSEN__TOUBRO_LTD_60M: lot_size=10, brokerage=20.0
# MAHINDRA__MAHINDRA_LTD_60M: lot_size=10, brokerage=20.0
# MARUTI_SUZUKI_INDIA_LTD_60M: lot_size=10, brokerage=20.0
# NTPC_LTD_60M: lot_size=10, brokerage=20.0
# NESTLE_INDIA_LTD_60M: lot_size=10, brokerage=20.0
# NIFTY_60M: lot_size=75, brokerage=20.0
# ONGC_LTD_60M: lot_size=10, brokerage=20.0
# POWER_GRID_CORPORATION_OF_INDIA_LTD_60M: lot_size=10, brokerage=20.0
# RELIANCE_INDUSTRIES_LTD_60M: lot_size=10, brokerage=20.0
# SBI_LIFE_INSURANCE_COMPANY_LTD_60M: lot_size=10, brokerage=20.0
# SENSEX_60M: lot_size=20, brokerage=20.0
# STATE_BANK_OF_INDIA_(SBI)_LTD_60M: lot_size=10, brokerage=20.0
# SUN_PHARMACEUTICAL_INDUSTRIES_LTD_60M: lot_size=10, brokerage=20.0
# TCS_LTD_60M: lot_size=10, brokerage=20.0
# TATA_CONSUMER_PRODUCTS_LTD_60M: lot_size=10, brokerage=20.0
# TATA_MOTORS_LTD_60M: lot_size=10, brokerage=20.0
# TATA_STEEL_LTD_60M: lot_size=10, brokerage=20.0
# TECH_MAHINDRA_LTD_60M: lot_size=10, brokerage=20.0
# TITAN_COMPANY_LTD_60M: lot_size=10, brokerage=20.0
# TRENT_LTD_60M: lot_size=10, brokerage=20.0
# ULTRATECH_CEMENT_LTD_60M: lot_size=10, brokerage=20.0
# WIPRO_LTD_60M: lot_size=10, brokerage=20.0
# ADANI_ENTERPRISES_LTD_45M: lot_size=10, brokerage=20.0
# ADANI_PORTS__SEZ_LTD_45M: lot_size=10, brokerage=20.0
# APOLLO_HOSPITALS_ENTERPRISE_LTD_45M: lot_size=10, brokerage=20.0
# ASIAN_PAINTS_LTD_45M: lot_size=10, brokerage=20.0
# AXIS_BANK_LTD_45M: lot_size=10, brokerage=20.0
# BPCL_LTD_45M: lot_size=10, brokerage=20.0
# BAJAJ_AUTO_LTD_45M: lot_size=10, brokerage=20.0
# BAJAJ_FINANCE_LTD_45M: lot_size=10, brokerage=20.0
# BAJAJ_FINSERV_LTD_45M: lot_size=10, brokerage=20.0
# BANK_NIFTY_45M: lot_size=30, brokerage=20.0
# BANKEX_45M: lot_size=15, brokerage=20.0
# BHARAT_ELECTRONICS_LTD_45M: lot_size=10, brokerage=20.0
# BHARTI_AIRTEL_LTD_45M: lot_size=10, brokerage=20.0
# CIPLA_LTD_45M: lot_size=10, brokerage=20.0
# COAL_INDIA_LTD_45M: lot_size=10, brokerage=20.0
# DR_REDDYS_LABORATORIES_LTD_45M: lot_size=10, brokerage=20.0
# EICHER_MOTORS_LTD_45M: lot_size=10, brokerage=20.0
# FINNIFTY_45M: lot_size=40, brokerage=20.0
# GRASIM_INDUSTRIES_LTD_45M: lot_size=10, brokerage=20.0
# HCL_TECHNOLOGIES_LTD_45M: lot_size=10, brokerage=20.0
# HDFC_BANK_LTD_45M: lot_size=10, brokerage=20.0
# HDFC_LIFE_INSURANCE_COMPANY_LTD_45M: lot_size=10, brokerage=20.0
# HERO_MOTOCORP_LTD_45M: lot_size=10, brokerage=20.0
# HINDALCO_INDUSTRIES_LTD_45M: lot_size=10, brokerage=20.0
# HINDUSTAN_UNILEVER_LTD_45M: lot_size=10, brokerage=20.0
# ICICI_BANK_LTD_45M: lot_size=10, brokerage=20.0
# INDIAN_OIL_CORPORATION_LTD_45M: lot_size=10, brokerage=20.0
# INDUSIND_BANK_LTD_45M: lot_size=10, brokerage=20.0
# INFOSYS_LTD_45M: lot_size=10, brokerage=20.0
# JSW_STEEL_LTD_45M: lot_size=10, brokerage=20.0
# KOTAK_MAHINDRA_BANK_LTD_45M: lot_size=10, brokerage=20.0
# LARSEN__TOUBRO_LTD_45M: lot_size=10, brokerage=20.0
# MAHINDRA__MAHINDRA_LTD_45M: lot_size=10, brokerage=20.0
# MARUTI_SUZUKI_INDIA_LTD_45M: lot_size=10, brokerage=20.0
# NTPC_LTD_45M: lot_size=10, brokerage=20.0
# NESTLE_INDIA_LTD_45M: lot_size=10, brokerage=20.0
# NIFTY_45M: lot_size=75, brokerage=20.0
# ONGC_LTD_45M: lot_size=10, brokerage=20.0
# POWER_GRID_CORPORATION_OF_INDIA_LTD_45M: lot_size=10, brokerage=20.0
# RELIANCE_INDUSTRIES_LTD_45M: lot_size=10, brokerage=20.0
# SBI_LIFE_INSURANCE_COMPANY_LTD_45M: lot_size=10, brokerage=20.0
# SENSEX_45M: lot_size=20, brokerage=20.0
# STATE_BANK_OF_INDIA_(SBI)_LTD_45M: lot_size=10, brokerage=20.0
# SUN_PHARMACEUTICAL_INDUSTRIES_LTD_45M: lot_size=10, brokerage=20.0
# TCS_LTD_45M: lot_size=10, brokerage=20.0
# TATA_CONSUMER_PRODUCTS_LTD_45M: lot_size=10, brokerage=20.0
# TATA_MOTORS_LTD_45M: lot_size=10, brokerage=20.0
# TATA_STEEL_LTD_45M: lot_size=10, brokerage=20.0
# TECH_MAHINDRA_LTD_45M: lot_size=10, brokerage=20.0
# TITAN_COMPANY_LTD_45M: lot_size=10, brokerage=20.0
# TRENT_LTD_45M: lot_size=10, brokerage=20.0
# ULTRATECH_CEMENT_LTD_45M: lot_size=10, brokerage=20.0
# WIPRO_LTD_45M: lot_size=10, brokerage=20.0
# ADANI_ENTERPRISES_LTD_30M: lot_size=10, brokerage=20.0
# ADANI_PORTS__SEZ_LTD_30M: lot_size=10, brokerage=20.0
# APOLLO_HOSPITALS_ENTERPRISE_LTD_30M: lot_size=10, brokerage=20.0
# ASIAN_PAINTS_LTD_30M: lot_size=10, brokerage=20.0
# AXIS_BANK_LTD_30M: lot_size=10, brokerage=20.0
# BPCL_LTD_30M: lot_size=10, brokerage=20.0
# BAJAJ_AUTO_LTD_30M: lot_size=10, brokerage=20.0
# BAJAJ_FINANCE_LTD_30M: lot_size=10, brokerage=20.0
# BAJAJ_FINSERV_LTD_30M: lot_size=10, brokerage=20.0
# BANK_NIFTY_30M: lot_size=30, brokerage=20.0
# BANKEX_30M: lot_size=15, brokerage=20.0
# BHARAT_ELECTRONICS_LTD_30M: lot_size=10, brokerage=20.0
# BHARTI_AIRTEL_LTD_30M: lot_size=10, brokerage=20.0
# CIPLA_LTD_30M: lot_size=10, brokerage=20.0
# COAL_INDIA_LTD_30M: lot_size=10, brokerage=20.0
# DR_REDDYS_LABORATORIES_LTD_30M: lot_size=10, brokerage=20.0
# EICHER_MOTORS_LTD_30M: lot_size=10, brokerage=20.0
# FINNIFTY_30M: lot_size=40, brokerage=20.0
# GRASIM_INDUSTRIES_LTD_30M: lot_size=10, brokerage=20.0
# HCL_TECHNOLOGIES_LTD_30M: lot_size=10, brokerage=20.0
# HDFC_BANK_LTD_30M: lot_size=10, brokerage=20.0
# HDFC_LIFE_INSURANCE_COMPANY_LTD_30M: lot_size=10, brokerage=20.0
# HERO_MOTOCORP_LTD_30M: lot_size=10, brokerage=20.0
# HINDALCO_INDUSTRIES_LTD_30M: lot_size=10, brokerage=20.0
# HINDUSTAN_UNILEVER_LTD_30M: lot_size=10, brokerage=20.0
# ICICI_BANK_LTD_30M: lot_size=10, brokerage=20.0
# INDIAN_OIL_CORPORATION_LTD_30M: lot_size=10, brokerage=20.0
# INDUSIND_BANK_LTD_30M: lot_size=10, brokerage=20.0
# INFOSYS_LTD_30M: lot_size=10, brokerage=20.0
# JSW_STEEL_LTD_30M: lot_size=10, brokerage=20.0
# KOTAK_MAHINDRA_BANK_LTD_30M: lot_size=10, brokerage=20.0
# LARSEN__TOUBRO_LTD_30M: lot_size=10, brokerage=20.0
# MAHINDRA__MAHINDRA_LTD_30M: lot_size=10, brokerage=20.0
# MARUTI_SUZUKI_INDIA_LTD_30M: lot_size=10, brokerage=20.0
# NTPC_LTD_30M: lot_size=10, brokerage=20.0
# NESTLE_INDIA_LTD_30M: lot_size=10, brokerage=20.0
# NIFTY_30M: lot_size=75, brokerage=20.0
# ONGC_LTD_30M: lot_size=10, brokerage=20.0
# POWER_GRID_CORPORATION_OF_INDIA_LTD_30M: lot_size=10, brokerage=20.0
# RELIANCE_INDUSTRIES_LTD_30M: lot_size=10, brokerage=20.0
# SBI_LIFE_INSURANCE_COMPANY_LTD_30M: lot_size=10, brokerage=20.0
# SENSEX_30M: lot_size=20, brokerage=20.0
# STATE_BANK_OF_INDIA_(SBI)_LTD_30M: lot_size=10, brokerage=20.0
# SUN_PHARMACEUTICAL_INDUSTRIES_LTD_30M: lot_size=10, brokerage=20.0
# TCS_LTD_30M: lot_size=10, brokerage=20.0
# TATA_CONSUMER_PRODUCTS_LTD_30M: lot_size=10, brokerage=20.0
# TATA_MOTORS_LTD_30M: lot_size=10, brokerage=20.0
# TATA_STEEL_LTD_30M: lot_size=10, brokerage=20.0
# TECH_MAHINDRA_LTD_30M: lot_size=10, brokerage=20.0
# TITAN_COMPANY_LTD_30M: lot_size=10, brokerage=20.0
# TRENT_LTD_30M: lot_size=10, brokerage=20.0
# ULTRATECH_CEMENT_LTD_30M: lot_size=10, brokerage=20.0
# WIPRO_LTD_30M: lot_size=10, brokerage=20.0
# ADANI_ENTERPRISES_LTD_20M: lot_size=10, brokerage=20.0
# ADANI_PORTS__SEZ_LTD_20M: lot_size=10, brokerage=20.0
# APOLLO_HOSPITALS_ENTERPRISE_LTD_20M: lot_size=10, brokerage=20.0
# ASIAN_PAINTS_LTD_20M: lot_size=10, brokerage=20.0
# AXIS_BANK_LTD_20M: lot_size=10, brokerage=20.0
# BPCL_LTD_20M: lot_size=10, brokerage=20.0
# BAJAJ_AUTO_LTD_20M: lot_size=10, brokerage=20.0
# BAJAJ_FINANCE_LTD_20M: lot_size=10, brokerage=20.0
# BAJAJ_FINSERV_LTD_20M: lot_size=10, brokerage=20.0
# BANK_NIFTY_20M: lot_size=30, brokerage=20.0
# BANKEX_20M: lot_size=15, brokerage=20.0
# BHARAT_ELECTRONICS_LTD_20M: lot_size=10, brokerage=20.0
# BHARTI_AIRTEL_LTD_20M: lot_size=10, brokerage=20.0
# CIPLA_LTD_20M: lot_size=10, brokerage=20.0
# COAL_INDIA_LTD_20M: lot_size=10, brokerage=20.0
# DR_REDDYS_LABORATORIES_LTD_20M: lot_size=10, brokerage=20.0
# EICHER_MOTORS_LTD_20M: lot_size=10, brokerage=20.0
# FINNIFTY_20M: lot_size=40, brokerage=20.0
# GRASIM_INDUSTRIES_LTD_20M: lot_size=10, brokerage=20.0
# HCL_TECHNOLOGIES_LTD_20M: lot_size=10, brokerage=20.0
# HDFC_BANK_LTD_20M: lot_size=10, brokerage=20.0
# HDFC_LIFE_INSURANCE_COMPANY_LTD_20M: lot_size=10, brokerage=20.0
# HERO_MOTOCORP_LTD_20M: lot_size=10, brokerage=20.0
# HINDALCO_INDUSTRIES_LTD_20M: lot_size=10, brokerage=20.0
# HINDUSTAN_UNILEVER_LTD_20M: lot_size=10, brokerage=20.0
# ICICI_BANK_LTD_20M: lot_size=10, brokerage=20.0
# INDIAN_OIL_CORPORATION_LTD_20M: lot_size=10, brokerage=20.0
# INDUSIND_BANK_LTD_20M: lot_size=10, brokerage=20.0
# INFOSYS_LTD_20M: lot_size=10, brokerage=20.0
# JSW_STEEL_LTD_20M: lot_size=10, brokerage=20.0
# KOTAK_MAHINDRA_BANK_LTD_20M: lot_size=10, brokerage=20.0
# LARSEN__TOUBRO_LTD_20M: lot_size=10, brokerage=20.0
# MAHINDRA__MAHINDRA_LTD_20M: lot_size=10, brokerage=20.0
# MARUTI_SUZUKI_INDIA_LTD_20M: lot_size=10, brokerage=20.0
# NTPC_LTD_20M: lot_size=10, brokerage=20.0
# NESTLE_INDIA_LTD_20M: lot_size=10, brokerage=20.0
# NIFTY_20M: lot_size=75, brokerage=20.0
# ONGC_LTD_20M: lot_size=10, brokerage=20.0
# POWER_GRID_CORPORATION_OF_INDIA_LTD_20M: lot_size=10, brokerage=20.0
# RELIANCE_INDUSTRIES_LTD_20M: lot_size=10, brokerage=20.0
# SBI_LIFE_INSURANCE_COMPANY_LTD_20M: lot_size=10, brokerage=20.0
# SENSEX_20M: lot_size=20, brokerage=20.0
# STATE_BANK_OF_INDIA_(SBI)_LTD_20M: lot_size=10, brokerage=20.0
# SUN_PHARMACEUTICAL_INDUSTRIES_LTD_20M: lot_size=10, brokerage=20.0
# TCS_LTD_20M: lot_size=10, brokerage=20.0
# TATA_CONSUMER_PRODUCTS_LTD_20M: lot_size=10, brokerage=20.0
# TATA_MOTORS_LTD_20M: lot_size=10, brokerage=20.0
# TATA_STEEL_LTD_20M: lot_size=10, brokerage=20.0
# TECH_MAHINDRA_LTD_20M: lot_size=10, brokerage=20.0
# TITAN_COMPANY_LTD_20M: lot_size=10, brokerage=20.0
# TRENT_LTD_20M: lot_size=10, brokerage=20.0
# ULTRATECH_CEMENT_LTD_20M: lot_size=10, brokerage=20.0
# WIPRO_LTD_20M: lot_size=10, brokerage=20.0
# ADANI_ENTERPRISES_LTD_15M: lot_size=10, brokerage=20.0
# ADANI_PORTS__SEZ_LTD_15M: lot_size=10, brokerage=20.0
# APOLLO_HOSPITALS_ENTERPRISE_LTD_15M: lot_size=10, brokerage=20.0
# ASIAN_PAINTS_LTD_15M: lot_size=10, brokerage=20.0
# AXIS_BANK_LTD_15M: lot_size=10, brokerage=20.0
# BPCL_LTD_15M: lot_size=10, brokerage=20.0
# BAJAJ_AUTO_LTD_15M: lot_size=10, brokerage=20.0
# BAJAJ_FINANCE_LTD_15M: lot_size=10, brokerage=20.0
# BAJAJ_FINSERV_LTD_15M: lot_size=10, brokerage=20.0
# BANK_NIFTY_15M: lot_size=30, brokerage=20.0
# BANKEX_15M: lot_size=15, brokerage=20.0
# BHARAT_ELECTRONICS_LTD_15M: lot_size=10, brokerage=20.0
# BHARTI_AIRTEL_LTD_15M: lot_size=10, brokerage=20.0
# CIPLA_LTD_15M: lot_size=10, brokerage=20.0
# COAL_INDIA_LTD_15M: lot_size=10, brokerage=20.0
# DR_REDDYS_LABORATORIES_LTD_15M: lot_size=10, brokerage=20.0
# EICHER_MOTORS_LTD_15M: lot_size=10, brokerage=20.0
# FINNIFTY_15M: lot_size=40, brokerage=20.0
# GRASIM_INDUSTRIES_LTD_15M: lot_size=10, brokerage=20.0
# HCL_TECHNOLOGIES_LTD_15M: lot_size=10, brokerage=20.0
# HDFC_BANK_LTD_15M: lot_size=10, brokerage=20.0
# HDFC_LIFE_INSURANCE_COMPANY_LTD_15M: lot_size=10, brokerage=20.0
# HERO_MOTOCORP_LTD_15M: lot_size=10, brokerage=20.0
# HINDALCO_INDUSTRIES_LTD_15M: lot_size=10, brokerage=20.0
# HINDUSTAN_UNILEVER_LTD_15M: lot_size=10, brokerage=20.0
# ICICI_BANK_LTD_15M: lot_size=10, brokerage=20.0
# INDIAN_OIL_CORPORATION_LTD_15M: lot_size=10, brokerage=20.0
# INDUSIND_BANK_LTD_15M: lot_size=10, brokerage=20.0
# INFOSYS_LTD_15M: lot_size=10, brokerage=20.0
# JSW_STEEL_LTD_15M: lot_size=10, brokerage=20.0
# KOTAK_MAHINDRA_BANK_LTD_15M: lot_size=10, brokerage=20.0
# LARSEN__TOUBRO_LTD_15M: lot_size=10, brokerage=20.0
# MAHINDRA__MAHINDRA_LTD_15M: lot_size=10, brokerage=20.0
# MARUTI_SUZUKI_INDIA_LTD_15M: lot_size=10, brokerage=20.0
# NTPC_LTD_15M: lot_size=10, brokerage=20.0
# NESTLE_INDIA_LTD_15M: lot_size=10, brokerage=20.0
# NIFTY_15M: lot_size=75, brokerage=20.0
# ONGC_LTD_15M: lot_size=10, brokerage=20.0
# POWER_GRID_CORPORATION_OF_INDIA_LTD_15M: lot_size=10, brokerage=20.0
# RELIANCE_INDUSTRIES_LTD_15M: lot_size=10, brokerage=20.0
# SBI_LIFE_INSURANCE_COMPANY_LTD_15M: lot_size=10, brokerage=20.0
# SENSEX_15M: lot_size=20, brokerage=20.0
# STATE_BANK_OF_INDIA_(SBI)_LTD_15M: lot_size=10, brokerage=20.0
# SUN_PHARMACEUTICAL_INDUSTRIES_LTD_15M: lot_size=10, brokerage=20.0
# TCS_LTD_15M: lot_size=10, brokerage=20.0
# TATA_CONSUMER_PRODUCTS_LTD_15M: lot_size=10, brokerage=20.0
# TATA_MOTORS_LTD_15M: lot_size=10, brokerage=20.0
# TATA_STEEL_LTD_15M: lot_size=10, brokerage=20.0
# TECH_MAHINDRA_LTD_15M: lot_size=10, brokerage=20.0
# TITAN_COMPANY_LTD_15M: lot_size=10, brokerage=20.0
# TRENT_LTD_15M: lot_size=10, brokerage=20.0
# ULTRATECH_CEMENT_LTD_15M: lot_size=10, brokerage=20.0
# WIPRO_LTD_15M: lot_size=10, brokerage=20.0
# ADANI_ENTERPRISES_LTD_10M: lot_size=10, brokerage=20.0
# ADANI_PORTS__SEZ_LTD_10M: lot_size=10, brokerage=20.0
# APOLLO_HOSPITALS_ENTERPRISE_LTD_10M: lot_size=10, brokerage=20.0
# ASIAN_PAINTS_LTD_10M: lot_size=10, brokerage=20.0
# AXIS_BANK_LTD_10M: lot_size=10, brokerage=20.0
# BPCL_LTD_10M: lot_size=10, brokerage=20.0
# BAJAJ_AUTO_LTD_10M: lot_size=10, brokerage=20.0
# BAJAJ_FINANCE_LTD_10M: lot_size=10, brokerage=20.0
# BAJAJ_FINSERV_LTD_10M: lot_size=10, brokerage=20.0
# BANK_NIFTY_10M: lot_size=30, brokerage=20.0
# BANKEX_10M: lot_size=15, brokerage=20.0
# BHARAT_ELECTRONICS_LTD_10M: lot_size=10, brokerage=20.0
# BHARTI_AIRTEL_LTD_10M: lot_size=10, brokerage=20.0
# CIPLA_LTD_10M: lot_size=10, brokerage=20.0
# COAL_INDIA_LTD_10M: lot_size=10, brokerage=20.0
# DR_REDDYS_LABORATORIES_LTD_10M: lot_size=10, brokerage=20.0
# EICHER_MOTORS_LTD_10M: lot_size=10, brokerage=20.0
# FINNIFTY_10M: lot_size=40, brokerage=20.0
# GRASIM_INDUSTRIES_LTD_10M: lot_size=10, brokerage=20.0
# HCL_TECHNOLOGIES_LTD_10M: lot_size=10, brokerage=20.0
# HDFC_BANK_LTD_10M: lot_size=10, brokerage=20.0
# HDFC_LIFE_INSURANCE_COMPANY_LTD_10M: lot_size=10, brokerage=20.0
# HERO_MOTOCORP_LTD_10M: lot_size=10, brokerage=20.0
# HINDALCO_INDUSTRIES_LTD_10M: lot_size=10, brokerage=20.0
# HINDUSTAN_UNILEVER_LTD_10M: lot_size=10, brokerage=20.0
# ICICI_BANK_LTD_10M: lot_size=10, brokerage=20.0
# INDIAN_OIL_CORPORATION_LTD_10M: lot_size=10, brokerage=20.0
# INDUSIND_BANK_LTD_10M: lot_size=10, brokerage=20.0
# INFOSYS_LTD_10M: lot_size=10, brokerage=20.0
# JSW_STEEL_LTD_10M: lot_size=10, brokerage=20.0
# KOTAK_MAHINDRA_BANK_LTD_10M: lot_size=10, brokerage=20.0
# LARSEN__TOUBRO_LTD_10M: lot_size=10, brokerage=20.0
# MAHINDRA__MAHINDRA_LTD_10M: lot_size=10, brokerage=20.0
# MARUTI_SUZUKI_INDIA_LTD_10M: lot_size=10, brokerage=20.0
# NTPC_LTD_10M: lot_size=10, brokerage=20.0
# NESTLE_INDIA_LTD_10M: lot_size=10, brokerage=20.0
# NIFTY_10M: lot_size=75, brokerage=20.0
# ONGC_LTD_10M: lot_size=10, brokerage=20.0
# POWER_GRID_CORPORATION_OF_INDIA_LTD_10M: lot_size=10, brokerage=20.0
# RELIANCE_INDUSTRIES_LTD_10M: lot_size=10, brokerage=20.0
# SBI_LIFE_INSURANCE_COMPANY_LTD_10M: lot_size=10, brokerage=20.0
# SENSEX_10M: lot_size=20, brokerage=20.0
# STATE_BANK_OF_INDIA_(SBI)_LTD_10M: lot_size=10, brokerage=20.0
# SUN_PHARMACEUTICAL_INDUSTRIES_LTD_10M: lot_size=10, brokerage=20.0
# TCS_LTD_10M: lot_size=10, brokerage=20.0
# TATA_CONSUMER_PRODUCTS_LTD_10M: lot_size=10, brokerage=20.0
# TATA_MOTORS_LTD_10M: lot_size=10, brokerage=20.0
# TATA_STEEL_LTD_10M: lot_size=10, brokerage=20.0
# TECH_MAHINDRA_LTD_10M: lot_size=10, brokerage=20.0
# TITAN_COMPANY_LTD_10M: lot_size=10, brokerage=20.0
# TRENT_LTD_10M: lot_size=10, brokerage=20.0
# ULTRATECH_CEMENT_LTD_10M: lot_size=10, brokerage=20.0
# WIPRO_LTD_10M: lot_size=10, brokerage=20.0
# ADANI_ENTERPRISES_LTD_5M: lot_size=10, brokerage=20.0
# ADANI_PORTS__SEZ_LTD_5M: lot_size=10, brokerage=20.0
# APOLLO_HOSPITALS_ENTERPRISE_LTD_5M: lot_size=10, brokerage=20.0
# ASIAN_PAINTS_LTD_5M: lot_size=10, brokerage=20.0
# AXIS_BANK_LTD_5M: lot_size=10, brokerage=20.0
# BPCL_LTD_5M: lot_size=10, brokerage=20.0
# BAJAJ_AUTO_LTD_5M: lot_size=10, brokerage=20.0
# BAJAJ_FINANCE_LTD_5M: lot_size=10, brokerage=20.0
# BAJAJ_FINSERV_LTD_5M: lot_size=10, brokerage=20.0
# BANK_NIFTY_5M: lot_size=30, brokerage=20.0
# BANKEX_5M: lot_size=15, brokerage=20.0
# BHARAT_ELECTRONICS_LTD_5M: lot_size=10, brokerage=20.0
# BHARTI_AIRTEL_LTD_5M: lot_size=10, brokerage=20.0
# CIPLA_LTD_5M: lot_size=10, brokerage=20.0
# COAL_INDIA_LTD_5M: lot_size=10, brokerage=20.0
# DR_REDDYS_LABORATORIES_LTD_5M: lot_size=10, brokerage=20.0
# EICHER_MOTORS_LTD_5M: lot_size=10, brokerage=20.0
# FINNIFTY_5M: lot_size=40, brokerage=20.0
# GRASIM_INDUSTRIES_LTD_5M: lot_size=10, brokerage=20.0
# HCL_TECHNOLOGIES_LTD_5M: lot_size=10, brokerage=20.0
# HDFC_BANK_LTD_5M: lot_size=10, brokerage=20.0
# HDFC_LIFE_INSURANCE_COMPANY_LTD_5M: lot_size=10, brokerage=20.0
# HERO_MOTOCORP_LTD_5M: lot_size=10, brokerage=20.0
# HINDALCO_INDUSTRIES_LTD_5M: lot_size=10, brokerage=20.0
# HINDUSTAN_UNILEVER_LTD_5M: lot_size=10, brokerage=20.0
# ICICI_BANK_LTD_5M: lot_size=10, brokerage=20.0
# INDIAN_OIL_CORPORATION_LTD_5M: lot_size=10, brokerage=20.0
# INDUSIND_BANK_LTD_5M: lot_size=10, brokerage=20.0
# INFOSYS_LTD_5M: lot_size=10, brokerage=20.0
# JSW_STEEL_LTD_5M: lot_size=10, brokerage=20.0
# KOTAK_MAHINDRA_BANK_LTD_5M: lot_size=10, brokerage=20.0
# LARSEN__TOUBRO_LTD_5M: lot_size=10, brokerage=20.0
# MAHINDRA__MAHINDRA_LTD_5M: lot_size=10, brokerage=20.0
# MARUTI_SUZUKI_INDIA_LTD_5M: lot_size=10, brokerage=20.0
# NTPC_LTD_5M: lot_size=10, brokerage=20.0
# NESTLE_INDIA_LTD_5M: lot_size=10, brokerage=20.0
# NIFTY_5M: lot_size=75, brokerage=20.0
# ONGC_LTD_5M: lot_size=10, brokerage=20.0
# POWER_GRID_CORPORATION_OF_INDIA_LTD_5M: lot_size=10, brokerage=20.0
# RELIANCE_INDUSTRIES_LTD_5M: lot_size=10, brokerage=20.0
# SBI_LIFE_INSURANCE_COMPANY_LTD_5M: lot_size=10, brokerage=20.0
# SENSEX_5M: lot_size=20, brokerage=20.0
# STATE_BANK_OF_INDIA_(SBI)_LTD_5M: lot_size=10, brokerage=20.0
# SUN_PHARMACEUTICAL_INDUSTRIES_LTD_5M: lot_size=10, brokerage=20.0
# TCS_LTD_5M: lot_size=10, brokerage=20.0
# TATA_CONSUMER_PRODUCTS_LTD_5M: lot_size=10, brokerage=20.0
# TATA_MOTORS_LTD_5M: lot_size=10, brokerage=20.0
# TATA_STEEL_LTD_5M: lot_size=10, brokerage=20.0
# TECH_MAHINDRA_LTD_5M: lot_size=10, brokerage=20.0
# TITAN_COMPANY_LTD_5M: lot_size=10, brokerage=20.0
# TRENT_LTD_5M: lot_size=10, brokerage=20.0
# ULTRATECH_CEMENT_LTD_5M: lot_size=10, brokerage=20.0
# WIPRO_LTD_5M: lot_size=10, brokerage=20.0
# ADANI_ENTERPRISES_LTD_3M: lot_size=10, brokerage=20.0
# ADANI_PORTS__SEZ_LTD_3M: lot_size=10, brokerage=20.0
# APOLLO_HOSPITALS_ENTERPRISE_LTD_3M: lot_size=10, brokerage=20.0
# ASIAN_PAINTS_LTD_3M: lot_size=10, brokerage=20.0
# AXIS_BANK_LTD_3M: lot_size=10, brokerage=20.0
# BPCL_LTD_3M: lot_size=10, brokerage=20.0
# BAJAJ_AUTO_LTD_3M: lot_size=10, brokerage=20.0
# BAJAJ_FINANCE_LTD_3M: lot_size=10, brokerage=20.0
# BAJAJ_FINSERV_LTD_3M: lot_size=10, brokerage=20.0
# BANK_NIFTY_3M: lot_size=30, brokerage=20.0
# BANKEX_3M: lot_size=15, brokerage=20.0
# BHARAT_ELECTRONICS_LTD_3M: lot_size=10, brokerage=20.0
# BHARTI_AIRTEL_LTD_3M: lot_size=10, brokerage=20.0
# CIPLA_LTD_3M: lot_size=10, brokerage=20.0
# COAL_INDIA_LTD_3M: lot_size=10, brokerage=20.0
# DR_REDDYS_LABORATORIES_LTD_3M: lot_size=10, brokerage=20.0
# EICHER_MOTORS_LTD_3M: lot_size=10, brokerage=20.0
# FINNIFTY_3M: lot_size=40, brokerage=20.0
# GRASIM_INDUSTRIES_LTD_3M: lot_size=10, brokerage=20.0
# HCL_TECHNOLOGIES_LTD_3M: lot_size=10, brokerage=20.0
# HDFC_BANK_LTD_3M: lot_size=10, brokerage=20.0
# HDFC_LIFE_INSURANCE_COMPANY_LTD_3M: lot_size=10, brokerage=20.0
# HERO_MOTOCORP_LTD_3M: lot_size=10, brokerage=20.0
# HINDALCO_INDUSTRIES_LTD_3M: lot_size=10, brokerage=20.0
# HINDUSTAN_UNILEVER_LTD_3M: lot_size=10, brokerage=20.0
# ICICI_BANK_LTD_3M: lot_size=10, brokerage=20.0
# INDIAN_OIL_CORPORATION_LTD_3M: lot_size=10, brokerage=20.0
# INDUSIND_BANK_LTD_3M: lot_size=10, brokerage=20.0
# INFOSYS_LTD_3M: lot_size=10, brokerage=20.0
# JSW_STEEL_LTD_3M: lot_size=10, brokerage=20.0
# KOTAK_MAHINDRA_BANK_LTD_3M: lot_size=10, brokerage=20.0
# LARSEN__TOUBRO_LTD_3M: lot_size=10, brokerage=20.0
# MAHINDRA__MAHINDRA_LTD_3M: lot_size=10, brokerage=20.0
# MARUTI_SUZUKI_INDIA_LTD_3M: lot_size=10, brokerage=20.0
# NTPC_LTD_3M: lot_size=10, brokerage=20.0
# NESTLE_INDIA_LTD_3M: lot_size=10, brokerage=20.0
# NIFTY_3M: lot_size=75, brokerage=20.0
# ONGC_LTD_3M: lot_size=10, brokerage=20.0
# POWER_GRID_CORPORATION_OF_INDIA_LTD_3M: lot_size=10, brokerage=20.0
# RELIANCE_INDUSTRIES_LTD_3M: lot_size=10, brokerage=20.0
# SBI_LIFE_INSURANCE_COMPANY_LTD_3M: lot_size=10, brokerage=20.0
# SENSEX_3M: lot_size=20, brokerage=20.0
# STATE_BANK_OF_INDIA_(SBI)_LTD_3M: lot_size=10, brokerage=20.0
# SUN_PHARMACEUTICAL_INDUSTRIES_LTD_3M: lot_size=10, brokerage=20.0
# TCS_LTD_3M: lot_size=10, brokerage=20.0
# TATA_CONSUMER_PRODUCTS_LTD_3M: lot_size=10, brokerage=20.0
# TATA_MOTORS_LTD_3M: lot_size=10, brokerage=20.0
# TATA_STEEL_LTD_3M: lot_size=10, brokerage=20.0
# TECH_MAHINDRA_LTD_3M: lot_size=10, brokerage=20.0
# TITAN_COMPANY_LTD_3M: lot_size=10, brokerage=20.0
# TRENT_LTD_3M: lot_size=10, brokerage=20.0
# ULTRATECH_CEMENT_LTD_3M: lot_size=10, brokerage=20.0
# WIPRO_LTD_3M: lot_size=10, brokerage=20.0
# ADANI_ENTERPRISES_LTD_2M: lot_size=10, brokerage=20.0
# ADANI_PORTS__SEZ_LTD_2M: lot_size=10, brokerage=20.0
# APOLLO_HOSPITALS_ENTERPRISE_LTD_2M: lot_size=10, brokerage=20.0
# ASIAN_PAINTS_LTD_2M: lot_size=10, brokerage=20.0
# AXIS_BANK_LTD_2M: lot_size=10, brokerage=20.0
# BPCL_LTD_2M: lot_size=10, brokerage=20.0
# BAJAJ_AUTO_LTD_2M: lot_size=10, brokerage=20.0
# BAJAJ_FINANCE_LTD_2M: lot_size=10, brokerage=20.0
# BAJAJ_FINSERV_LTD_2M: lot_size=10, brokerage=20.0
# BANK_NIFTY_2M: lot_size=30, brokerage=20.0
# BANKEX_2M: lot_size=15, brokerage=20.0
# BHARAT_ELECTRONICS_LTD_2M: lot_size=10, brokerage=20.0
# BHARTI_AIRTEL_LTD_2M: lot_size=10, brokerage=20.0
# CIPLA_LTD_2M: lot_size=10, brokerage=20.0
# COAL_INDIA_LTD_2M: lot_size=10, brokerage=20.0
# DR_REDDYS_LABORATORIES_LTD_2M: lot_size=10, brokerage=20.0
# EICHER_MOTORS_LTD_2M: lot_size=10, brokerage=20.0
# FINNIFTY_2M: lot_size=40, brokerage=20.0
# GRASIM_INDUSTRIES_LTD_2M: lot_size=10, brokerage=20.0
# HCL_TECHNOLOGIES_LTD_2M: lot_size=10, brokerage=20.0
# HDFC_BANK_LTD_2M: lot_size=10, brokerage=20.0
# HDFC_LIFE_INSURANCE_COMPANY_LTD_2M: lot_size=10, brokerage=20.0
# HERO_MOTOCORP_LTD_2M: lot_size=10, brokerage=20.0
# HINDALCO_INDUSTRIES_LTD_2M: lot_size=10, brokerage=20.0
# HINDUSTAN_UNILEVER_LTD_2M: lot_size=10, brokerage=20.0
# ICICI_BANK_LTD_2M: lot_size=10, brokerage=20.0
# INDIAN_OIL_CORPORATION_LTD_2M: lot_size=10, brokerage=20.0
# INDUSIND_BANK_LTD_2M: lot_size=10, brokerage=20.0
# INFOSYS_LTD_2M: lot_size=10, brokerage=20.0
# JSW_STEEL_LTD_2M: lot_size=10, brokerage=20.0
# KOTAK_MAHINDRA_BANK_LTD_2M: lot_size=10, brokerage=20.0
# LARSEN__TOUBRO_LTD_2M: lot_size=10, brokerage=20.0
# MAHINDRA__MAHINDRA_LTD_2M: lot_size=10, brokerage=20.0
# MARUTI_SUZUKI_INDIA_LTD_2M: lot_size=10, brokerage=20.0
# NTPC_LTD_2M: lot_size=10, brokerage=20.0
# NESTLE_INDIA_LTD_2M: lot_size=10, brokerage=20.0
# NIFTY_2M: lot_size=75, brokerage=20.0
# ONGC_LTD_2M: lot_size=10, brokerage=20.0
# POWER_GRID_CORPORATION_OF_INDIA_LTD_2M: lot_size=10, brokerage=20.0
# RELIANCE_INDUSTRIES_LTD_2M: lot_size=10, brokerage=20.0
# SBI_LIFE_INSURANCE_COMPANY_LTD_2M: lot_size=10, brokerage=20.0
# SENSEX_2M: lot_size=20, brokerage=20.0
# STATE_BANK_OF_INDIA_(SBI)_LTD_2M: lot_size=10, brokerage=20.0
# SUN_PHARMACEUTICAL_INDUSTRIES_LTD_2M: lot_size=10, brokerage=20.0
# TCS_LTD_2M: lot_size=10, brokerage=20.0
# TATA_CONSUMER_PRODUCTS_LTD_2M: lot_size=10, brokerage=20.0
# TATA_MOTORS_LTD_2M: lot_size=10, brokerage=20.0
# TATA_STEEL_LTD_2M: lot_size=10, brokerage=20.0
# TECH_MAHINDRA_LTD_2M: lot_size=10, brokerage=20.0
# TITAN_COMPANY_LTD_2M: lot_size=10, brokerage=20.0
# TRENT_LTD_2M: lot_size=10, brokerage=20.0
# ULTRATECH_CEMENT_LTD_2M: lot_size=10, brokerage=20.0
# WIPRO_LTD_2M: lot_size=10, brokerage=20.0

# %%
def get_dataframe_by_name(instrument_name, config):
    # instrument_name is something like "BANKNIFTY_5M", "NIFTY50_15M", etc.
    for instrument in config["instruments"]:
        if instrument["name"] == instrument_name:
            return pd.read_csv(instrument["file_path"], parse_dates=['datetime'], index_col='datetime')
    return None


my_df = get_dataframe_by_name("BANK_NIFTY_5M", config)

my_df
# Out:
#                          open      high       low     close  atr_14  rsi_14  \
# datetime
# 2020-09-30 13:20:00  21360.20  21360.70  21340.90  21353.30   49.23   53.68
# 2020-09-30 13:25:00  21352.70  21378.80  21284.10  21295.80   52.48   45.53
# 2020-09-30 13:30:00  21294.40  21354.20  21277.80  21346.60   54.19   52.40
# 2020-09-30 13:35:00  21347.90  21351.50  21309.10  21319.10   53.35   48.81
# 2020-09-30 13:40:00  21322.80  21334.50  21294.70  21329.50   52.38   50.20
# ...                       ...       ...       ...       ...     ...     ...
# 2024-11-04 15:05:00  51201.05  51235.20  51175.85  51235.20   46.05   62.19
# 2024-11-04 15:10:00  51233.45  51233.45  51206.40  51218.95   44.82   57.90
# 2024-11-04 15:15:00  51218.15  51254.90  51181.15  51233.65   46.89   60.55
# 2024-11-04 15:20:00  51230.75  51253.25  51222.70  51250.85   45.72   63.45
# 2024-11-04 15:25:00  51250.40  51260.80  51205.10  51227.20   46.43   57.22
#
#                      STOCHk_14_3_3  STOCHd_14_3_3  MACD_12_26_9  \
# datetime
# 2020-09-30 13:20:00          64.36          69.07         16.04
# 2020-09-30 13:25:00          56.08          62.38         10.83
# 2020-09-30 13:30:00          51.33          57.25         10.67
# 2020-09-30 13:35:00          39.66          49.02          8.23
# 2020-09-30 13:40:00          41.35          44.11          7.06
# ...                            ...            ...           ...
# 2024-11-04 15:05:00          74.29          71.12         14.35
# 2024-11-04 15:10:00          81.67          74.72         15.09
# 2024-11-04 15:15:00          87.04          81.00         16.67
# 2024-11-04 15:20:00          86.34          85.01         19.09
# 2024-11-04 15:25:00          83.13          85.50         18.89
#
#                      MACDh_12_26_9  ...  upper_wick  lower_wick  hour  \
# datetime                            ...
# 2020-09-30 13:20:00           4.00  ...        0.50       12.40    13
# 2020-09-30 13:25:00          -0.97  ...       26.10       11.70    13
# 2020-09-30 13:30:00          -0.90  ...        7.60       16.60    13
# 2020-09-30 13:35:00          -2.67  ...        3.60       10.00    13
# 2020-09-30 13:40:00          -3.08  ...        5.00       28.10    13
# ...                            ...  ...         ...         ...   ...
# 2024-11-04 15:05:00           4.00  ...        0.00       25.20    15
# 2024-11-04 15:10:00           3.79  ...        0.00       12.55    15
# 2024-11-04 15:15:00           4.30  ...       21.25       37.00    15
# 2024-11-04 15:20:00           5.37  ...        2.40        8.05    15
# 2024-11-04 15:25:00           4.13  ...       10.40       22.10    15
#
#                      day_of_week  month  Target  StopLoss  Signal  \
# datetime
# 2020-09-30 13:20:00            2      9   98.46     49.23     2.0
# 2020-09-30 13:25:00            2      9  104.96     52.48     4.0
# 2020-09-30 13:30:00            2      9  108.38     54.19     4.0
# 2020-09-30 13:35:00            2      9  106.70     53.35     4.0
# 2020-09-30 13:40:00            2      9  104.76     52.38     4.0
# ...                          ...    ...     ...       ...     ...
# 2024-11-04 15:05:00            0     11   92.10     46.05     2.0
# 2024-11-04 15:10:00            0     11   89.64     44.82     0.0
# 2024-11-04 15:15:00            0     11   93.78     46.89     0.0
# 2024-11-04 15:20:00            0     11   91.44     45.72     2.0
# 2024-11-04 15:25:00            0     11   92.86     46.43     0.0
#
#                      candles_to_profit  candles_to_loss
# datetime
# 2020-09-30 13:20:00                0.0              1.0
# 2020-09-30 13:25:00                0.0              1.0
# 2020-09-30 13:30:00                0.0              4.0
# 2020-09-30 13:35:00                0.0              2.0
# 2020-09-30 13:40:00                0.0              1.0
# ...                                ...              ...
# 2024-11-04 15:05:00                0.0              2.0
# 2024-11-04 15:10:00                0.0              0.0
# 2024-11-04 15:15:00                0.0              0.0
# 2024-11-04 15:20:00                0.0              1.0
# 2024-11-04 15:25:00                0.0              0.0
#
# [75756 rows x 30 columns]

# %%
class Position:
    # Holds all necessary info about the current position (long or short).
    def __init__(self):
        self.reset()

    def reset(self):
        self.status = "flat"             # "flat", "long", or "short"
        self.entry_price = None
        self.sl_points = None            # For initial SL
        self.target_points = None
        self.direction = 0               # +1 for long, -1 for short
        self.quantity = 0
        self.time_in_trade = 0
        self.margin_used = 0.0           # Tracks margin used for the current position

        # Trailing SL related
        self.trailing_sl_price = None    # Absolute trailing SL price
        self.highest_price = None        # For tracking highest price since entry (long)
        self.lowest_price = None         # For tracking lowest price since entry (short)

    def update_unrealized_pnl(self, current_price: float) -> float:
        if self.status == "flat":
            return 0.0
        return (current_price - self.entry_price) * self.direction * self.quantity

    def open(self, entry_price: float, sl_points: float, target_points: float,
             direction: int, quantity: int):
        self.status = "long" if direction == 1 else "short"
        self.entry_price = entry_price
        self.sl_points = sl_points
        self.target_points = target_points
        self.direction = direction
        self.quantity = quantity
        self.time_in_trade = 0

        # Initialize trailing stop to the initial SL directly
        if direction == 1:
            self.trailing_sl_price = entry_price - sl_points
            self.highest_price = entry_price
            self.lowest_price = None
        else:
            self.trailing_sl_price = entry_price + sl_points
            self.highest_price = None
            self.lowest_price = entry_price

# %%
class TradingEnv(gym.Env):
    def __init__(self, env_config):
        super(TradingEnv, self).__init__()
        self.config = env_config
        self.total_reward = 0.0

        # Mandatory configuration parameters
        self.window_size = self.config["window_size"]
        self.lot_size = self.config["lot_size"]
        self.transaction_cost = self.config["transaction_cost"]
        self.instrument_name = self.config.get("name", "Unknown")
        self.instrument_id = self.config.get("instrument_id", 0)
        self.normalize_data = self.config.get("normalize_data", False)
        self.csv_path = self.config["file_path"]

        # Flag to determine TPU usage; if using TPU, load the entire CSV directly.
        self.use_tpu = self.config.get("use_tpu", False)

        if self.use_tpu:
            # For TPU: load entire CSV at once for faster training.
            self.data = pd.read_csv(
                self.csv_path,
                parse_dates=['datetime'],
                index_col='datetime'
            )
            self.done_loading = True
            self.total_rows = len(self.data)
            # Process data similarly to chunk loading.
            self.buffer_raw = self.data.drop(
                columns=['Signal', 'candles_to_profit', 'candles_to_loss'], errors='ignore'
            ).copy()
            if 'Signal' in self.data.columns:
                self.buffer_guidance = self.data[['Signal', 'candles_to_profit', 'candles_to_loss']].copy()
            else:
                self.buffer_guidance = pd.DataFrame(index=self.data.index)
            self.buffer_obs = self.buffer_raw.copy()

            # Preprocess buffers: fill missing values
            self.buffer_raw = self.buffer_raw.ffill().bfill()
            self.buffer_guidance = self.buffer_guidance.ffill().bfill()
            self.buffer_obs = self.buffer_obs.ffill().bfill()

            if self.normalize_data:
                self.scaler = StandardScaler()
                self.scaler.fit(self.buffer_obs.values)
                self.buffer_obs = pd.DataFrame(
                    self.scaler.transform(self.buffer_obs.values),
                    columns=self.buffer_obs.columns,
                    index=self.buffer_obs.index
                )
            else:
                self.scaler = None
        else:
            # For GPU/CPU: use chunked reading to save memory.
            self.chunk_size = self.config.get("chunk_size", 10000)
            self.data_iterator = pd.read_csv(
                self.csv_path,
                parse_dates=['datetime'],
                index_col='datetime',
                chunksize=self.chunk_size
            )
            self.done_loading = False
            self._load_next_chunk(initial=True)

        # Initial capital and trading variables
        self.initial_capital = self.config.get("initial_capital")
        self.current_capital = None
        self.current_step = None

        self.position = Position()
        self.trade_log = []

        # Define action and observation spaces (unchanged)
        n_features = self.buffer_obs.shape[1]
        self.action_space = spaces.Discrete(3)
        self.observation_space = spaces.Dict({
            "market": spaces.Box(-np.inf, np.inf, shape=(n_features,), dtype=np.float32),
            "position": spaces.Box(-np.inf, np.inf, shape=(4,), dtype=np.float32),
            "history": spaces.Box(-np.inf, np.inf, shape=(self.window_size, n_features), dtype=np.float32),
            "instrument_info": spaces.Box(-np.inf, np.inf, shape=(2,), dtype=np.float32)
        })

        # Reward shaping parameters (unchanged)
        self.unrealized_pnl_weight = self.config.get("unrealized_pnl_weight", 0.1)
        self.time_penalty_weight = self.config.get("time_penalty_weight", 0.02)
        self.volatility_penalty_weight = self.config.get("volatility_penalty_weight", 0.1)
        self.target_bonus = self.config.get("target_bonus", 0.5)
        self.sl_penalty = self.config.get("sl_penalty", 0.5)
        self.misalignment_penalty = self.config.get("misalignment_penalty", 0.5)
        self.missed_opportunity_penalty = self.config.get("missed_opportunity_penalty", 0.05)
        self.target_proximity_weight = self.config.get("target_proximity_weight", 0.2)
        self.sl_proximity_weight = self.config.get("sl_proximity_weight", 0.05)
        self.max_step_reward = self.config.get("max_step_reward", 5.0)
        self.enable_trailing_sl = False

    def _load_next_chunk(self, initial=False):
        """
        Loads the next chunk of data from the CSV. To preserve continuity,
        if this isn’t the initial load, the last `window_size` rows from the previous
        chunk are kept and prepended to the new chunk.
        This method is used only when not training on TPU.
        """
        try:
            next_chunk = next(self.data_iterator)
        except StopIteration:
            self.done_loading = True
            return

        if not initial:
            # Keep an overlap equal to window_size for continuity
            overlap = self.window_size
            tail = self.data.iloc[-overlap:]
            self.data = pd.concat([tail, next_chunk])
        else:
            self.data = next_chunk

        # Update total rows and buffers based on the new chunk
        self.total_rows = len(self.data)
        self.buffer_raw = self.data.drop(
            columns=['Signal', 'candles_to_profit', 'candles_to_loss'], errors='ignore'
        ).copy()
        if 'Signal' in self.data.columns:
            self.buffer_guidance = self.data[['Signal', 'candles_to_profit', 'candles_to_loss']].copy()
        else:
            self.buffer_guidance = pd.DataFrame(index=self.data.index)
        self.buffer_obs = self.buffer_raw.copy()

        # Preprocess buffers
        self.buffer_raw = self.buffer_raw.ffill().bfill()
        self.buffer_guidance = self.buffer_guidance.ffill().bfill()
        self.buffer_obs = self.buffer_obs.ffill().bfill()

        if self.normalize_data:
            self.scaler = StandardScaler()
            self.scaler.fit(self.buffer_obs.values)
            self.buffer_obs = pd.DataFrame(
                self.scaler.transform(self.buffer_obs.values),
                columns=self.buffer_obs.columns,
                index=self.buffer_obs.index
            )
        else:
            self.scaler = None

    def reset(self, seed=None, options=None):
        """Resets the environment to its initial state."""
        super().reset(seed=seed)
        self.current_step = self.window_size
        if self.current_step >= self.total_rows:
            # If current chunk is too small, try loading the next chunk (only applies for GPU/CPU)
            if not self.use_tpu:
                self._load_next_chunk()
                self.current_step = self.window_size if self.total_rows > self.window_size else 0

        self.position.reset()
        self.current_capital = self.initial_capital
        self.trade_log.clear()
        self.total_reward = 0.0

        obs = self._get_observation()
        return obs, {}

    def step(self, action: int):
        """
        Executes one time step in the environment.
        If we are nearing the end of the current chunk (only for GPU/CPU), attempt to load the next one.
        """
        if not self.use_tpu and self.current_step >= self.total_rows - self.window_size and not self.done_loading:
            self._load_next_chunk()

        current_data = self._get_row(self.buffer_raw, self.current_step)
        guidance_row = self._get_row(self.buffer_guidance, self.current_step)
        reward = 0.0

        # (Rest of the step logic remains the same)
        if self.position.status == "flat":
            reward += self._apply_guidance_reward(action, guidance_row)

        if self.position.status != "flat":
            if self._check_margin_call(current_data['close']):
                reward += self._close_position(current_data, "Margin Call")

        hit_sl, fill_price = self._check_sl_hit(current_data)
        if hit_sl:
            reward += self._close_position(current_data, "SL Hit", override_exit_price=fill_price)
        else:
            hit_target, target_fill_price = self._check_target_hit(current_data)
            if hit_target:
                reward += self._close_position(current_data, "Target Hit", override_exit_price=target_fill_price)

        self._execute_action(action, current_data)

        if self.position.status != "flat":
            self.position.time_in_trade += 1
            unrealized_pnl = self.position.update_unrealized_pnl(current_data['close'])
            reward += self._calculate_reward(unrealized_pnl, current_data)

        self.current_step += 1
        if self.current_step >= self.total_rows or self.current_capital <= 0:
            done = True
            if self.position.status != "flat":
                reward += self._close_position(current_data, "Force Close")
        else:
            done = False

        self.total_reward += reward
        obs = self._get_observation()
        return obs, reward, done, False, {}

    def _execute_action(self, action: int, current_data: pd.Series):
        """Executes the specified action if conditions are met."""
        price = current_data.get('open', 0.0)
        margin_cost = price * self.lot_size * MARGIN_FRACTION

        if action == 1 and self.position.status == "flat":  # Long
            if self.current_capital >= (margin_cost + self.transaction_cost):
                self._open_position("long", current_data)
        elif action == 2 and self.position.status == "flat":  # Short
            if self.current_capital >= (margin_cost + self.transaction_cost):
                self._open_position("short", current_data)
        # action == 0 (hold) does nothing

    def _open_position(self, direction: str, current_data: pd.Series):
        """Opens a new trading position."""
        entry_price = current_data.get('open', 0.0)
        margin_cost = entry_price * self.lot_size * MARGIN_FRACTION
        self.current_capital -= (margin_cost + self.transaction_cost)
        self.position.margin_used = margin_cost

        sl_val = current_data.get('StopLoss', 0.0)
        tg_val = current_data.get('Target', 0.0)
        direction_int = 1 if direction == "long" else -1

        self.position.open(
            entry_price=entry_price,
            sl_points=sl_val,
            target_points=tg_val,
            direction=direction_int,
            quantity=self.lot_size
        )

        self.trade_log.append({
            "entry_time": current_data.name,
            "position": direction,
            "entry_price": entry_price,
            "exit_time": None,
            "exit_price": None,
            "pnl": None,
            "reason": None,
            "initial_capital": self._format_currency(self.initial_capital),
            "points": None,
            "profit": None,
            "win": None,
            "reward": None,
            "time_in_trade": None
        })

    def _close_position(self, current_data: pd.Series, reason: str, override_exit_price=None) -> float:
        """Closes an active position and updates capital and trade log."""
        if self.position.status == "flat":
            return 0.0

        direction = self.position.direction
        exit_price = override_exit_price if override_exit_price is not None else current_data.get('open', 0.0)
        realized_pnl = (exit_price - self.position.entry_price) * direction * self.lot_size
        margin_return = self.position.margin_used
        self.current_capital += (margin_return + realized_pnl - self.transaction_cost)

        trade_return = realized_pnl / self.initial_capital
        total_reward = trade_return
        points = (exit_price - self.position.entry_price) * direction
        formatted_profit = self._format_currency(realized_pnl)
        win = realized_pnl > 0

        for trade in reversed(self.trade_log):
            if trade["exit_time"] is None:
                trade.update({
                    "exit_time": current_data.name,
                    "exit_price": exit_price,
                    "pnl": realized_pnl,
                    "reason": reason,
                    "time_in_trade": self.position.time_in_trade,
                    "points": round(points, 2),
                    "profit": formatted_profit,
                    "win": win,
                    "reward": total_reward
                })
                break

        self.position.reset()
        return total_reward

    def _check_sl_hit(self, current_data: pd.Series):
        """Checks if the stop loss has been hit."""
        if self.position.status == "flat":
            return False, None

        direction = self.position.direction
        entry_price = self.position.entry_price
        current_open = current_data.get('open', 0.0)
        current_high = current_data.get('high', 0.0)
        current_low = current_data.get('low', 0.0)

        if direction == 1:  # Long
            sl_price = entry_price - self.position.sl_points
            if current_open <= sl_price:
                return True, current_open
            elif current_low <= sl_price:
                return True, sl_price
        else:  # Short
            sl_price = entry_price + self.position.sl_points
            if current_open >= sl_price:
                return True, current_open
            elif current_high >= sl_price:
                return True, sl_price
        return False, None

    def _check_target_hit(self, current_data: pd.Series):
        """Checks if the target price has been hit."""
        if self.position.status == "flat":
            return False, None

        direction = self.position.direction
        entry_price = self.position.entry_price
        target_points = self.position.target_points
        current_open = current_data.get('open', 0.0)
        current_high = current_data.get('high', 0.0)
        current_low = current_data.get('low', 0.0)

        if direction == 1:  # Long
            target_price = entry_price + target_points
            if current_open >= target_price:
                return True, current_open
            elif current_high >= target_price:
                return True, target_price
        else:  # Short
            target_price = entry_price - target_points
            if current_open <= target_price:
                return True, current_open
            elif current_low <= target_price:
                return True, target_price
        return False, None

    def _check_margin_call(self, current_price: float) -> bool:
        """Checks if a margin call is triggered."""
        if self.position.status == "flat":
            return False
        maintenance_margin = self.position.margin_used * MARGIN_CALL_THRESHOLD
        unrealized_pnl = self.position.update_unrealized_pnl(current_price)
        equity = self.current_capital + unrealized_pnl
        return equity < maintenance_margin

    def _apply_guidance_reward(self, action, guidance_row):
        """Applies reward based on guidance signals when flat."""
        if guidance_row.empty:
            return 0.0
        signal = guidance_row.get('Signal', 0)
        candles_to_profit = max(guidance_row.get('candles_to_profit', 1.0), 1.0)

        if signal == 1 and action == 1:  # Long signal
            return self.target_bonus / candles_to_profit
        elif signal == 3 and action == 2:  # Short signal
            return self.target_bonus / candles_to_profit
        elif signal in [1, 3] and action != (1 if signal == 1 else 2):
            return -self.misalignment_penalty
        return 0.0

    def _calculate_reward(self, unrealized_pnl: float, current_data: pd.Series) -> float:
        """Calculates step reward for an open position."""
        risk = self.position.sl_points * self.lot_size
        risk_adj_pnl = (unrealized_pnl / risk) * self.unrealized_pnl_weight if risk > 0 else 0.0
        time_penalty = self.time_penalty_weight * (self.position.time_in_trade / 100.0)

        hi, lo, op = current_data.get('high', 0.0), current_data.get('low', 0.0), current_data.get('open', 1.0)
        volatility_penalty = self.volatility_penalty_weight * ((hi - lo) / max(abs(op), 1e-6))

        if self.position.direction == 1:
            sl_price = self.position.entry_price - self.position.sl_points
            sl_distance = max(0, current_data.get('close', 0.0) - sl_price)
            sl_range = self.position.sl_points
        else:
            sl_price = self.position.entry_price + self.position.sl_points
            sl_distance = max(0, sl_price - current_data.get('close', 0.0))
            sl_range = self.position.sl_points
        sl_prox_ratio = min(sl_distance / sl_range, 1.0) if sl_range > 1e-6 else 1.0
        sl_proximity_penalty = self.sl_proximity_weight * (1.0 - sl_prox_ratio)

        target_proximity_bonus = 0.0
        if self.position.target_points > 0:
            target_price = self.position.entry_price + (self.position.direction * self.position.target_points)
            target_range = abs(self.position.target_points)
            close = current_data.get('close', 0.0)
            distance_to_target = max(0, (target_price - close) * self.position.direction)
            if (self.position.direction == 1 and current_data.get('high', 0.0) >= target_price) or \
               (self.position.direction == -1 and current_data.get('low', 0.0) <= target_price):
                target_proximity_bonus -= self.missed_opportunity_penalty
            if target_range > 1e-6:
                target_proximity_bonus += (1.0 - (distance_to_target / target_range)) * self.target_proximity_weight

        total_reward = risk_adj_pnl + target_proximity_bonus - time_penalty - volatility_penalty - sl_proximity_penalty
        return float(np.clip(total_reward, -self.max_step_reward, self.max_step_reward))

    def _get_observation(self) -> dict:
        """Returns the current observation."""
        idx = self.current_step
        row_obs = self._get_row(self.buffer_obs, idx).values.astype(np.float32)
        current_close = self._get_row(self.buffer_raw, idx)['close']
        unrealized_pnl = self.position.update_unrealized_pnl(current_close)
        position_context = np.array([
            1.0 if self.position.status == "long" else 0.0,
            1.0 if self.position.status == "short" else 0.0,
            unrealized_pnl / self.initial_capital,
            self.position.time_in_trade / 100.0
        ], dtype=np.float32)

        history_data = np.array([
            self._get_row(self.buffer_obs, i).values.astype(np.float32) if 0 <= i < self.total_rows
            else np.zeros_like(row_obs)
            for i in range(idx - self.window_size, idx)
        ], dtype=np.float32)

        instrument_info = np.array([self.lot_size / 1000.0, self.transaction_cost / 100.0], dtype=np.float32)
        return {
            "market": row_obs,
            "position": position_context,
            "history": history_data,
            "instrument_info": instrument_info
        }

    def _get_row(self, df: pd.DataFrame, index: int) -> pd.Series:
        """Retrieves a row from a DataFrame by index, handling out-of-bounds cases."""
        if index < 0 or index >= len(df) or df.empty:
            return pd.Series(np.zeros(df.shape[1] if df.shape[1] else 0, dtype=np.float32), index=df.columns if not df.empty else [])
        return df.iloc[index]

    def get_metrics(self) -> dict:
        """Returns performance metrics based on trade log."""
        if not self.trade_log:
            return {"instrument": self.instrument_name, "message": "No trades taken"}

        closed_trades = [t for t in self.trade_log if t['exit_time'] is not None]
        total_trades = len(closed_trades)
        if total_trades == 0:
            return {"instrument": self.instrument_name, "message": "No trades closed yet"}

        winning_trades = [t for t in closed_trades if t['pnl'] > 0]
        losing_trades = [t for t in closed_trades if t['pnl'] <= 0]
        win_rate = (len(winning_trades) / total_trades) * 100.0
        sum_winning = sum(t['pnl'] for t in winning_trades)
        sum_losing = sum(t['pnl'] for t in losing_trades)
        profit_factor = sum_winning / abs(sum_losing) if sum_losing != 0 else float('inf')

        return {
            "instrument": self.instrument_name,
            "initial_capital": self._format_currency(self.initial_capital),
            "final_capital": self._format_currency(self.current_capital),
            "total_trades": total_trades,
            "win_rate": f"{round(win_rate, 2)}%",
            "total_reward": round(self.total_reward, 2),
            "max_drawdown": self._compute_max_drawdown(),
            "profit_factor": profit_factor
        }

    def _compute_max_drawdown(self) -> float:
        """Calculates the maximum drawdown from the equity curve."""
        equity_curve = [self.initial_capital]
        for t in self.trade_log:
            if t['pnl'] is not None:
                equity_curve.append(equity_curve[-1] + t['pnl'])
        equity_curve = np.array(equity_curve, dtype=np.float32)
        if len(equity_curve) < 2:
            return 0.0
        peak = np.maximum.accumulate(equity_curve)
        dd = (peak - equity_curve) / peak
        return float(dd.max())

    def _format_currency(self, value: float) -> str:
        """Formats a value into a currency string with appropriate units."""
        abs_value = abs(value)
        if abs_value >= 1e7:
            return f"₹{value / 1e7:.2f}Cr"
        elif abs_value >= 1e5:
            return f"₹{value / 1e5:.2f}L"
        elif abs_value >= 1e3:
            return f"₹{value / 1e3:.2f}K"
        else:
            return f"₹{value:.2f}"

    def _get_row(self, df: pd.DataFrame, index: int) -> pd.Series:
        """Safely retrieves a row from a DataFrame."""
        if index < 0 or index >= len(df) or df.empty:
            return pd.Series(np.zeros(df.shape[1] if df.shape[1] else 0, dtype=np.float32), index=df.columns if not df.empty else [])
        return df.iloc[index]

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.distributions import Categorical
from tqdm import tqdm

# Comprehensive model configuration with all parameters in one place
model_config = {
    "history_len": config["window_size"],  # Assume config is defined elsewhere
    "n_features": None,  # Will be set after inspecting an env's observation
    
    # CNN parameters
    "cnn_filters": [32, 64, 128],
    "cnn_kernel_sizes": [3, 3, 3],
    "cnn_strides": [1, 1, 1],
    "cnn_paddings": [1, 1, 1],
    "pool_size": 2,
    
    # LSTM parameters
    "lstm_hidden_size": 128,
    "lstm_layers": 2,
    "lstm_dropout": 0.2,
    "bidirectional": True,
    
    # Transformer parameters
    "d_model": 256,
    "n_heads": 8,
    "n_layers": 4,
    "ff_dim": 512,
    "dropout": 0.1,
    
    # Output parameters
    "action_space": 3,  # Assuming 3 actions (buy, hold, sell)
}

class CNNFeatureExtractor(nn.Module):
    def __init__(self, n_features, cnn_filters, cnn_kernel_sizes, cnn_strides, cnn_paddings, pool_size):
        super(CNNFeatureExtractor, self).__init__()
        self.cnn_layers = nn.ModuleList()
        
        in_channels = 1  # Start with 1-channel input (time series)
        for i, (out_channels, kernel_size, stride, padding) in enumerate(
            zip(cnn_filters, cnn_kernel_sizes, cnn_strides, cnn_paddings)):
            
            self.cnn_layers.append(nn.Sequential(
                nn.Conv1d(in_channels, out_channels, kernel_size, stride, padding),
                nn.BatchNorm1d(out_channels),
                nn.ReLU(),
                nn.MaxPool1d(pool_size)
            ))
            in_channels = out_channels
        
        # Calculate CNN output dimension (needed for feed-forward layers)
        self.cnn_output_dim = cnn_filters[-1]
    
    def forward(self, x):
        # x shape: [batch_size, seq_len, features]
        batch_size, seq_len, features = x.shape
        
        # Reshape for CNN: [batch_size, channels, seq_len]
        x = x.view(batch_size, 1, -1)
        
        # Apply CNN layers
        for layer in self.cnn_layers:
            x = layer(x)
        
        return x  # Shape: [batch_size, cnn_output_dim, reduced_seq_len]

class BiLSTMProcessor(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, dropout, bidirectional):
        super(BiLSTMProcessor, self).__init__()
        self.lstm = nn.LSTM(
            input_size=input_size,
            hidden_size=hidden_size,
            num_layers=num_layers,
            batch_first=True,
            dropout=dropout if num_layers > 1 else 0,
            bidirectional=bidirectional
        )
        self.output_dim = hidden_size * 2 if bidirectional else hidden_size
    
    def forward(self, x):
        # x shape from CNN: [batch_size, cnn_output_dim, reduced_seq_len]
        # Transpose for LSTM: [batch_size, reduced_seq_len, cnn_output_dim]
        x = x.transpose(1, 2)
        
        output, (h_n, c_n) = self.lstm(x)
        
        # For bidirectional, concatenate the final hidden states of both directions
        if self.lstm.bidirectional:
            # Concatenate forward and backward final hidden states
            h_n = torch.cat([h_n[-2], h_n[-1]], dim=-1).unsqueeze(0)
        else:
            h_n = h_n[-1].unsqueeze(0)
            
        return output, h_n  # output: [batch_size, seq_len, output_dim], h_n: [1, batch_size, output_dim]

class PositionalEncoding(nn.Module):
    def __init__(self, d_model, max_seq_length=1000):
        super(PositionalEncoding, self).__init__()
        
        # Create positional encoding matrix
        pe = torch.zeros(max_seq_length, d_model)
        position = torch.arange(0, max_seq_length, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-torch.log(torch.tensor(10000.0)) / d_model))
        
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0)
        
        # Register buffer (not a parameter but part of module state)
        self.register_buffer('pe', pe)
        
    def forward(self, x):
        # x: [batch_size, seq_len, d_model]
        return x + self.pe[:, :x.size(1), :]

class TransformerBlock(nn.Module):
    def __init__(self, d_model, n_heads, ff_dim, dropout):
        super(TransformerBlock, self).__init__()
        
        self.attention = nn.MultiheadAttention(d_model, n_heads, dropout=dropout, batch_first=True)
        self.norm1 = nn.LayerNorm(d_model)
        self.norm2 = nn.LayerNorm(d_model)
        
        self.feed_forward = nn.Sequential(
            nn.Linear(d_model, ff_dim),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(ff_dim, d_model),
            nn.Dropout(dropout)
        )
    
    def forward(self, x, mask=None):
        # Self-attention with residual connection and layer normalization
        attn_output, _ = self.attention(x, x, x, attn_mask=mask, need_weights=False)
        x = self.norm1(x + attn_output)
        
        # Feed-forward with residual connection and layer normalization
        ff_output = self.feed_forward(x)
        x = self.norm2(x + ff_output)
        
        return x

class HybridTradingModel(nn.Module):
    def __init__(self, history_len, n_features, cnn_filters, cnn_kernel_sizes, cnn_strides, 
                 cnn_paddings, pool_size, lstm_hidden_size, lstm_layers, lstm_dropout, 
                 bidirectional, d_model, n_heads, n_layers, ff_dim, dropout, action_space):
        super(HybridTradingModel, self).__init__()
        
        # Store configuration
        self.history_len = history_len
        self.n_features = n_features
        
        # Feature extraction from different inputs
        self.market_embed = nn.Linear(n_features, d_model)
        self.position_embed = nn.Linear(4, d_model)  # Position features
        self.instrument_embed = nn.Linear(2, d_model)  # Instrument info
        
        # CNN for temporal feature extraction from history
        self.cnn = CNNFeatureExtractor(
            n_features, cnn_filters, cnn_kernel_sizes, cnn_strides, cnn_paddings, pool_size
        )
        
        # Calculate reduced sequence length after CNN
        reduced_seq_len = history_len
        for _ in range(len(cnn_filters)):
            reduced_seq_len = (reduced_seq_len // pool_size)
        
        # Bi-LSTM for sequential processing
        self.lstm = BiLSTMProcessor(
            cnn_filters[-1], lstm_hidden_size, lstm_layers, lstm_dropout, bidirectional
        )
        
        # Projection for LSTM output to match transformer dimension
        lstm_output_dim = lstm_hidden_size * 2 if bidirectional else lstm_hidden_size
        self.lstm_projection = nn.Linear(lstm_output_dim, d_model)
        
        # Positional encoding for transformer
        self.positional_encoding = PositionalEncoding(d_model)
        
        # Transformer blocks
        self.transformer_blocks = nn.ModuleList([
            TransformerBlock(d_model, n_heads, ff_dim, dropout)
            for _ in range(n_layers)
        ])
        
        # Final output layers
        self.attention_weights = nn.Parameter(torch.randn(d_model, 1))
        self.fc_out = nn.Linear(d_model, action_space)
        self.softmax = nn.Softmax(dim=-1)
    
    def forward(self, obs):
        device = next(self.parameters()).device
        
        # Create tensors on the model's device
        market = torch.tensor(obs["market"], dtype=torch.float32, device=device).unsqueeze(0)
        position = torch.tensor(obs["position"], dtype=torch.float32, device=device).unsqueeze(0)
        history = torch.tensor(obs["history"], dtype=torch.float32, device=device).unsqueeze(0)
        instrument = torch.tensor(obs["instrument_info"], dtype=torch.float32, device=device).unsqueeze(0)
        
        # Process current market data
        market_emb = self.market_embed(market).unsqueeze(1)  # [batch, 1, d_model]
        
        # Process position info
        position_emb = self.position_embed(position).unsqueeze(1)  # [batch, 1, d_model]
        
        # Process instrument info
        instrument_emb = self.instrument_embed(instrument).unsqueeze(1)  # [batch, 1, d_model]
        
        # Process historical data through CNN and Bi-LSTM
        cnn_features = self.cnn(history)  # [batch, cnn_output_dim, reduced_seq_len]
        lstm_output, lstm_hidden = self.lstm(cnn_features)  # lstm_output: [batch, seq, lstm_out]
        
        # Project LSTM outputs to transformer dimension
        batch_size, seq_len, _ = lstm_output.shape
        lstm_proj = self.lstm_projection(lstm_output)  # [batch, seq, d_model]
        
        # Concatenate all inputs for the transformer
        # Market state, position info, instrument info, and LSTM-processed history
        transformer_input = torch.cat([market_emb, position_emb, instrument_emb, lstm_proj], dim=1)
        
        # Add positional encoding
        transformer_input = self.positional_encoding(transformer_input)
        
        # Process through transformer blocks
        transformer_output = transformer_input
        for block in self.transformer_blocks:
            transformer_output = block(transformer_output)
        
        # Attention-weighted pooling
        attention_scores = torch.matmul(transformer_output, self.attention_weights)
        attention_weights = F.softmax(attention_scores, dim=1)
        context_vector = torch.sum(transformer_output * attention_weights, dim=1)
        
        # Final prediction
        action_logits = self.fc_out(context_vector)
        action_probs = self.softmax(action_logits)
        
        return action_probs

def train_worker(rank, world_size, envs, model_config, chunk_size, epochs, lr, checkpoint_path):
    # Use external variable "use_tpu" to determine device and setup
    if use_tpu:
        import torch_xla.core.xla_model as xm
        device = xm.xla_device()
        is_master = xm.is_master_ordinal()
        world_size = xm.xrt_world_size()
    elif torch.cuda.is_available():
        device = torch.device("cuda")
        is_master = True
        world_size = 1
    elif torch.xpu.is_available():
        device = torch.device("xpu")
        is_master = True
        world_size = 1
    else:
        device = torch.device("cpu")
        is_master = True
        world_size = 1

    # Distribute environments across workers
    envs_per_core = len(envs) // world_size
    start_idx = rank * envs_per_core
    end_idx = start_idx + envs_per_core if rank < world_size - 1 else len(envs)
    local_envs = envs[start_idx:end_idx]

    # Initialize model and optimizer
    policy = HybridTradingModel(**model_config).to(device)
    optimizer = optim.Adam(policy.parameters(), lr=lr)
    
    # Add learning rate scheduler for better convergence
    scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=1, gamma=0.95)

    # Load checkpoint if it exists
    if os.path.exists(checkpoint_path):
        checkpoint = torch.load(checkpoint_path, map_location=device)
        policy.load_state_dict(checkpoint['model_state_dict'])
        optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
        if 'scheduler_state_dict' in checkpoint:
            scheduler.load_state_dict(checkpoint['scheduler_state_dict'])
        best_avg_reward = checkpoint['best_avg_reward']
        starting_epoch = checkpoint['epoch']
        if is_master:
            print(f"Loaded checkpoint from epoch {checkpoint['epoch']} with best average reward {checkpoint['best_avg_reward']:.2f}")
    else:
        best_avg_reward = -float("inf")
        starting_epoch = 0

    for epoch in range(starting_epoch, starting_epoch + epochs):
        if is_master:
            print(f"Epoch {epoch + 1}/{starting_epoch + epochs}")
        epoch_rewards = []
        policy.train()

        for i in range(0, len(local_envs), chunk_size):
            chunk_envs = local_envs[i:i + chunk_size]
            total_reward = 0

            # Progress bar only for master process to avoid clutter
            iterator = tqdm(chunk_envs, desc=f"Rank {rank} Chunk {i//chunk_size + 1}") if is_master else chunk_envs

            for env in iterator:
                obs, _ = env.reset()
                done = False
                episode_reward = 0
                log_probs = []
                rewards = []
                entropies = []

                while not done:
                    action_probs = policy(obs).squeeze(0)
                    dist = Categorical(action_probs)
                    
                    # Add entropy for exploration
                    entropy = dist.entropy()
                    
                    action = dist.sample()
                    log_prob = dist.log_prob(action)
                    next_obs, reward, done, _, _ = env.step(action.item())
                    
                    log_probs.append(log_prob)
                    rewards.append(reward)
                    entropies.append(entropy)
                    
                    obs = next_obs
                    episode_reward += reward

                # Compute returns with GAE (Generalized Advantage Estimation)
                returns = []
                advantages = []
                R = 0
                gae = 0
                gamma = 0.99
                lambda_ = 0.95
                
                for r in reversed(rewards):
                    R = r + gamma * R
                    returns.insert(0, R)
                
                returns = torch.tensor(returns, dtype=torch.float32).to(device)
                returns = (returns - returns.mean()) / (returns.std() + 1e-8)

                # Compute policy loss with entropy bonus for exploration
                entropy_bonus = 0.01  # Hyperparameter for entropy weight
                policy_loss = 0
                for log_prob, R, entropy in zip(log_probs, returns, entropies):
                    policy_loss -= log_prob * R + entropy_bonus * entropy
                    
                policy_loss /= len(rewards)

                # Update model parameters
                optimizer.zero_grad()
                policy_loss.backward()
                
                # Gradient clipping to prevent exploding gradients
                nn.utils.clip_grad_norm_(policy.parameters(), max_norm=0.5)
                
                if use_tpu:
                    import torch_xla.core.xla_model as xm
                    xm.optimizer_step(optimizer)  # Syncs gradients across TPU cores
                    xm.mark_step()              # Explicit mark step for better TPU scheduling
                else:
                    optimizer.step()

                total_reward += episode_reward

            avg_reward = total_reward / len(chunk_envs)
            epoch_rewards.append(avg_reward)
            if is_master:
                print(f"Rank {rank} Chunk {i//chunk_size + 1} Avg Reward: {avg_reward:.2f}")
                # Print instrument-specific metrics
                print(f"\nInstrument Metrics for Rank {rank} Chunk {i//chunk_size + 1}")
                for env in chunk_envs:
                    metrics = env.get_metrics()
                    print(f"\nInstrument: {env.instrument_name}")
                    for key, value in metrics.items():
                        print(f"{key}: {value}")

        # Step the learning rate scheduler
        scheduler.step()
        
        # Compute global average reward
        local_avg_reward = sum(epoch_rewards) / len(epoch_rewards) if epoch_rewards else 0
        if use_tpu:
            import torch_xla.core.xla_model as xm
            all_avg_rewards = xm.all_reduce(torch.tensor([local_avg_reward], device=device), reduce_op=xm.REDUCE_SUM)
            global_avg_reward = all_avg_rewards.item() / world_size
        else:
            global_avg_reward = local_avg_reward

        if is_master:
            print(f"Epoch {epoch + 1} Average Reward: {global_avg_reward:.2f}")

            # Save checkpoint if improved
            if global_avg_reward > best_avg_reward:
                best_avg_reward = global_avg_reward
                torch.save({
                    'epoch': epoch + 1,
                    'model_state_dict': policy.state_dict(),
                    'optimizer_state_dict': optimizer.state_dict(),
                    'scheduler_state_dict': scheduler.state_dict(),
                    'best_avg_reward': best_avg_reward,
                }, checkpoint_path)
                print(f"New best model saved with average reward: {best_avg_reward:.2f}")
            
            # Also save a periodic checkpoint for recovery
            if (epoch + 1) % 5 == 0:
                torch.save({
                    'epoch': epoch + 1,
                    'model_state_dict': policy.state_dict(),
                    'optimizer_state_dict': optimizer.state_dict(),
                    'scheduler_state_dict': scheduler.state_dict(),
                    'best_avg_reward': best_avg_reward,
                }, f"checkpoint_epoch_{epoch+1}.pth")

def train_grpo(envs, model_config, chunk_size, epochs=10, lr=1e-4, checkpoint_path="best_checkpoint.pth"):
    """
    Main training function that adapts to TPU, GPU, or CPU.
    The chunk_size parameter should be set externally based on the device:
      - TPU: higher chunk_size for more parallelism,
      - GPU: slightly lower,
      - CPU: even lower.
    """
    if use_tpu:
        import torch_xla.core.xla_model as xm
        import torch_xla.distributed.xla_multiprocessing as xmp
        world_size = xm.xrt_world_size()
        if world_size > 1:
            xmp.spawn(train_worker, args=(world_size, envs, model_config, chunk_size, epochs, lr, checkpoint_path), nprocs=world_size)
        else:
            train_worker(0, 1, envs, model_config, chunk_size, epochs, lr, checkpoint_path)
    else:
        train_worker(0, 1, envs, model_config, chunk_size, epochs, lr, checkpoint_path)

    # Load the best model after training
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    policy = HybridTradingModel(**model_config).to(device)
    if os.path.exists(checkpoint_path):
        checkpoint = torch.load(checkpoint_path, map_location=device)
        policy.load_state_dict(checkpoint['model_state_dict'])
        print(f"Loaded best model with average reward: {checkpoint['best_avg_reward']:.2f}")
    return policy

# Set up environments (assuming config and TradingEnv are defined)
envs = []
for inst in config["instruments"]:
    env_config = config.copy()
    env_config.update(inst)
    env_config.pop("instruments")
    envs.append(TradingEnv(env_config))

# Infer n_features from a sample observation
sample_env = envs[0]
obs, _ = sample_env.reset()
model_config["n_features"] = obs["market"].shape[-1]

# Define checkpoint path
checkpoint_path = "best_hybrid_model.pth"

# Set chunk_size based on the device:
if use_tpu:
    chunk_size = 50   # Higher chunk size for TPU
elif torch.cuda.is_available():
    chunk_size = 10   # Moderate chunk size for CUDA
elif torch.xpu.is_available():
    chunk_size = 10   # Adjust based on performance on Intel GPU
else:
    chunk_size = 5    # Lower chunk size for CPU

trained_policy = train_grpo(envs, model_config, chunk_size=chunk_size, epochs=5, checkpoint_path=checkpoint_path)
# Out:
# Epoch 1/5
# Rank 0 Chunk 1:  20%|██        | 1/5 [06:30<26:02, 390.63s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18652\961796910.py in ?()
#     469     chunk_size = 10   # Adjust based on performance on Intel GPU
#     470 else:
#     471     chunk_size = 5    # Lower chunk size for CPU
#     472
# --> 473 trained_policy = train_grpo(envs, model_config, chunk_size=chunk_size, epochs=5, checkpoint_path=checkpoint_path)
#
# ~\AppData\Local\Temp\ipykernel_18652\961796910.py in ?(envs, model_config, chunk_size, epochs, lr, checkpoint_path)
#     432             xmp.spawn(train_worker, args=(world_size, envs, model_config, chunk_size, epochs, lr, checkpoint_path), nprocs=world_size)
#     433         else:
#     434             train_worker(0, 1, envs, model_config, chunk_size, epochs, lr, checkpoint_path)
#     435     else:
# --> 436         train_worker(0, 1, envs, model_config, chunk_size, epochs, lr, checkpoint_path)
#     437
#     438     # Load the best model after training
#     439     device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#
# ~\AppData\Local\Temp\ipykernel_18652\961796910.py in ?(rank, world_size, envs, model_config, chunk_size, epochs, lr, checkpoint_path)
#     318                     entropy = dist.entropy()
#     319
#     320                     action = dist.sample()
#     321                     log_prob = dist.log_prob(action)
# --> 322                     next_obs, reward, done, _, _ = env.step(action.item())
#     323
#     324                     log_probs.append(log_prob)
#     325                     rewards.append(reward)
#
# ~\AppData\Local\Temp\ipykernel_18652\1164847665.py in ?(self, action)
#     202         else:
#     203             done = False
#     204
#     205         self.total_reward += reward
# --> 206         obs = self._get_observation()
#     207         return obs, reward, done, False, {}
#
# ~\AppData\Local\Temp\ipykernel_18652\1164847665.py in ?(self)
#     411             unrealized_pnl / self.initial_capital,
#     412             self.position.time_in_trade / 100.0
#     413         ], dtype=np.float32)
#     414
# --> 415         history_data = np.array([
#     416             self._get_row(self.buffer_obs, i).values.astype(np.float32) if 0 <= i < self.total_rows
#     417             else np.zeros_like(row_obs)
#     418             for i in range(idx - self.window_size, idx)
#
# ~\AppData\Local\Temp\ipykernel_18652\1164847665.py in ?(.0)
#     415     def _get_observation(self) -> dict:
# --> 416         """Returns the current observation."""
#     417         idx = self.current_step
#     418         row_obs = self._get_row(self.buffer_obs, idx).values.astype(np.float32)
#     419         current_close = self._get_row(self.buffer_raw, idx)['close']
#
# ~\AppData\Local\Temp\ipykernel_18652\1164847665.py in ?(self, df, index)
#     488     def _get_row(self, df: pd.DataFrame, index: int) -> pd.Series:
#     489         """Safely retrieves a row from a DataFrame."""
#     490         if index < 0 or index >= len(df) or df.empty:
#     491             return pd.Series(np.zeros(df.shape[1] if df.shape[1] else 0, dtype=np.float32), index=df.columns if not df.empty else [])
# --> 492         return df.iloc[index]
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexing.py in ?(self, key)
#    1187             axis = self.axis or 0
#    1188
#    1189             maybe_callable = com.apply_if_callable(key, self.obj)
#    1190             maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191             return self._getitem_axis(maybe_callable, axis=axis)
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexing.py in ?(self, key, axis)
#    1750
#    1751             # validate the location
#    1752             self._validate_integer(key, axis)
#    1753
# -> 1754             return self.obj._ixs(key, axis=axis)
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py in ?(self, i, axis)
#    3998             # if we are a copy, mark as such
#    3999             copy = isinstance(new_mgr.array, np.ndarray) and new_mgr.array.base is None
#    4000             result = self._constructor_sliced_from_mgr(new_mgr, axes=new_mgr.axes)
#    4001             result._name = self.index[i]
# -> 4002             result = result.__finalize__(self)
#    4003             result._set_is_copy(self, copy=copy)
#    4004             return result
#    4005
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\generic.py in ?(self, other, method, **kwargs)
#    6260                 self.attrs = deepcopy(other.attrs)
#    6261
#    6262             self.flags.allows_duplicate_labels = other.flags.allows_duplicate_labels
#    6263             # For subclasses using _metadata.
# -> 6264             for name in set(self._metadata) & set(other._metadata):
#    6265                 assert isinstance(name, str)
#    6266                 object.__setattr__(self, name, getattr(other, name, None))
#    6267
#
# KeyboardInterrupt:

# %%
print("\nEnvironment Metrics:")
for env in envs:
    metrics = env.get_metrics()
    print("\nInstrument Metrics:")
    for key, value in metrics.items():
        print(f"{key}: {value}")
