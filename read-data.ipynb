# %%
import pandas as pd

pd.read_csv('data/final/final_Bank_Nifty_5.csv').head(50)
# Out:
#         open      high       low     close  volume     sma_5     ema_5  \
# 0   48577.05  48618.35  48560.35  48600.25     0.0  48571.71  48575.97
# 1   48597.90  48615.40  48582.30  48606.85     0.0  48583.74  48586.26
# 2   48606.35  48609.10  48586.25  48595.25     0.0  48590.04  48589.26
# 3   48593.25  48595.25  48559.10  48581.75     0.0  48592.16  48586.75
# 4   48580.65  48629.25  48577.85  48611.30     0.0  48599.08  48594.94
# 5   48611.55  48620.95  48589.75  48595.20     0.0  48598.07  48595.02
# 6   48595.40  48656.85  48576.50  48655.30     0.0  48607.76  48615.12
# 7   48653.85  48685.80  48643.90  48677.55     0.0  48624.22  48635.93
# 8   48678.85  48729.15  48667.05  48718.70     0.0  48651.61  48663.52
# 9   48716.55  48749.40  48703.05  48738.50     0.0  48677.05  48688.51
# 10  48735.95  48927.90  48735.95  48907.35     0.0  48739.48  48761.46
# 11  48907.45  48980.30  48907.45  48949.30     0.0  48798.28  48824.07
# ...
